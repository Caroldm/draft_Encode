# %%
library(GeneOverlap)

# %%
# Load library
library(GeneOverlap)

# Read in R tables
#encodeA <- read.table('/Users/Carol/Desktop/porra/ENCODE2016_UPDATE_PRONTO_FIM_transposed.csv',sep=',', header=TRUE)
#correspondente no pc lab
encodeA <- read.table('/Users/lab/Desktop/encodes/arquivoNovo/encode/ENCODE2016_UPDATE_PRONTO_FIM_transposed.csv')

encodeB <- read.table('/Users/Carol/Desktop/porra/ENCODE_TF_ChIP-seq_2015_trabalhado_overlap2016_transposed.csv',sep=',', header=TRUE)

gobject <- read.table('/Users/Carol/Desktop/tfA/gobject.csv',sep=',', header=TRUE)

# summary(gobject)
#nrow(gobject)

sapply(encodeA,length)
sapply(encodeB,length)

genome = 20805 # RefSeq Hg19
# Out:
# Warning message in file(file, "rt"):
# “cannot open file '/Users/Carol/Desktop/porra/ENCODE2016_UPDATE_PRONTO_FIM_transposed.csv': Permission denied”
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. read.table("/Users/Carol/Desktop/porra/ENCODE2016_UPDATE_PRONTO_FIM_transposed.csv",
#  .     sep = ",", header = TRUE)
# 2. file(file, "rt")

# %%
#print(gobject)

# %%
# List of overlap comparisons. Ufahhhh...

for (i in gobject) {
  b <- paste(sprintf('(%s,%s,genome.size=20805),',gobject$A,gobject$B))
  print(b)
 # write.table(b, "enc15vs16freeOverlapMap2.csv", quote=FALSE, row.names=F, col.names=FALSE, sep="\t")
  }
# Out:
#   [1] "(go.obj <- newGeneOverlap(encodeA$REST_H1hESC_hg19,encodeB$REST_H1hESC_hg19,genome.size=20805),"
#   [2] "(go.obj <- newGeneOverlap(encodeA$TAF1_HeLaS3_hg19,encodeB$TAF1_HeLaS3_hg19,genome.size=20805),"
#   [3] "(go.obj <- newGeneOverlap(encodeA$REST_HepG2_hg19,encodeB$REST_HepG2_hg19,genome.size=20805),"
#   [4] "(go.obj <- newGeneOverlap(encodeA$ZBTB7A_K562_hg19,encodeB$ZBTB7A_K562_hg19,genome.size=20805),"
#   [5] "(go.obj <- newGeneOverlap(encodeA$SIX5_K562_hg19,encodeB$SIX5_K562_hg19,genome.size=20805),"
#   [6] "(go.obj <- newGeneOverlap(encodeA$SIN3A_SKNSH_hg19,encodeB$SIN3A_SKNSH_hg19,genome.size=20805),"
#   [7] "(go.obj <- newGeneOverlap(encodeA$CBX3_K562_hg19,encodeB$CBX3_K562_hg19,genome.size=20805),"
#   [8] "(go.obj <- newGeneOverlap(encodeA$TRIM28_K562_hg19,encodeB$TRIM28_K562_hg19,genome.size=20805),"
#   [9] "(go.obj <- newGeneOverlap(encodeA$JUND_SKNSH_hg19,encodeB$JUND_SKNSH_hg19,genome.size=20805),"
# ...

# %%
golist <-list(go.obj <- newGeneOverlap(encodeA$REST_H1hESC_hg19,encodeB$REST_H1hESC_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TAF1_HeLaS3_hg19,encodeB$TAF1_HeLaS3_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$REST_HepG2_hg19,encodeB$REST_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZBTB7A_K562_hg19,encodeB$ZBTB7A_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SIX5_K562_hg19,encodeB$SIX5_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SIN3A_SKNSH_hg19,encodeB$SIN3A_SKNSH_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CBX3_K562_hg19,encodeB$CBX3_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TRIM28_K562_hg19,encodeB$TRIM28_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$JUND_SKNSH_hg19,encodeB$JUND_SKNSH_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$JUND
HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZKSCAN1_HepG2_hg19,encodeB$ZKSCAN1_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$KDM5B_H1hESC_hg19,encodeB$KDM5B_H1hESC_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SMARCE1_K562_hg19,encodeB$SMARCE1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF518A_HEK293_hg19,encodeB$eGFPZNF518A_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGATF1_K562_hg19,encodeB$FLAGATF1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPDIDO1_K562_hg19,encodeB$eGFPDIDO1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZNF316_K562_hg19,encodeB$ZNF316_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$NR2F2_liver_hg19,encodeB$NR2F2_liver_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FOXK2_HepG2_hg19,encodeB$FOXK2_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGZNF580_HepG2_hg19,encodeB$FLAGZNF580_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZSCAN29_K562_hg19,encodeB$ZSCAN29_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$JUN_MCF7_hg19,encodeB$JUN_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPCUX1_K562_hg19,encodeB$eGFPCUX1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGZBTB26_HepG2_hg19,encodeB$FLAGZBTB26_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF341_HEK293_hg19,encodeB$eGFPZNF341_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SMAD2_K562_hg19,encodeB$SMAD2_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZBTB40_GM12878_hg19,encodeB$ZBTB40_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF766_K562_hg19,encodeB$eGFPZNF766_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$HDGF_K562_hg19,encodeB$HDGF_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SREBF1_MCF7_hg19,encodeB$SREBF1_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$EED_GM12878_hg19,encodeB$EED_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$HDGF_MCF7_hg19,encodeB$HDGF_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGNFIL3_HepG2_hg19,encodeB$FLAGNFIL3_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ATF3_liver_hg19,encodeB$ATF3_liver_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$YBX1_GM12878_hg19,encodeB$YBX1_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZBED1_GM12878_hg19,encodeB$ZBED1_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF391_HEK293_hg19,encodeB$eGFPZNF391_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPGLI4_HEK293_hg19,encodeB$eGFPGLI4_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TOE1_K562_hg19,encodeB$TOE1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TRIM25_K562_hg19,encodeB$TRIM25_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF8_HEK293_hg19,encodeB$eGFPZNF8_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPATF2_HEK293_hg19,encodeB$eGFPATF2_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF697_HEK293_hg19,encodeB$eGFPZNF697_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPTSHZ1_HEK293_hg19,encodeB$eGFPTSHZ1_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$DEK_HeLaS3_hg19,encodeB$DEK_HeLaS3_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$GTF2F1_HepG2_hg19,encodeB$GTF2F1_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPPRDM10_HEK293_hg19,encodeB$eGFPPRDM10_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TFDP1_K562_hg19,encodeB$TFDP1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF121_HEK293_hg19,encodeB$eGFPZNF121_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGNFIA_HepG2_isoform1,encodeB$FLAGNFIA_HepG2_isoform1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF292_HEK293_hg19,encodeB$eGFPZNF292_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZBTB26_HEK293_hg19,encodeB$eGFPZBTB26_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ARID3A_MCF7_hg19,encodeB$ARID3A_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZBTB33_MCF7_hg19,encodeB$ZBTB33_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$PKNOX1_HEK293T_hg19,encodeB$PKNOX1_HEK293T_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$DPF2_MCF7_hg19,encodeB$DPF2_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CTBP1_HEK293T_hg19,encodeB$CTBP1_HEK293T_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZBTB40_K562_hg19,encodeB$ZBTB40_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SMAD5_GM12878_hg19,encodeB$SMAD5_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CTCF_hepatocyte_hg19,encodeB$CTCF_hepatocyte_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGATF1_HepG2_hg19,encodeB$FLAGATF1_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF83_K562_hg19,encodeB$eGFPZNF83_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGMBD1_HepG2_isoform2,encodeB$FLAGMBD1_HepG2_isoform2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MNT_HepG2_hg19,encodeB$MNT_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPPBX2_K562_hg19,encodeB$eGFPPBX2_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$POU5F1_inducedpluripotentstemcell_hg19,encodeB$POU5F1_inducedpluripotentstemcell_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CBX8_GM12878_hg19,encodeB$CBX8_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPKLF4_MCF7_hg19,encodeB$eGFPKLF4_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FOXA1_HepG2_hg19,encodeB$FOXA1_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLA
K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CSDE1_K562_hg19,encodeB$CSDE1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZHX2_HepG2_hg19,encodeB$ZHX2_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPPYGO2_K562_hg19,encodeB$eGFPPYGO2_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$WHSC1_GM12878_hg19,encodeB$WHSC1_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SUZ12_K562_hg19,encodeB$SUZ12_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$RUNX1_K562_hg19,encodeB$RUNX1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGZNF48_HepG2_hg19,encodeB$FLAGZNF48_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPCEBPB_K562_hg19,encodeB$eGFPCEBPB_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZEB2_HEK293_hg19,encodeB$eGFPZEB2_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF692_HEK293_hg19,encodeB$eGFPZNF692_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$KDM1A_H1hESC_hg19,encodeB$KDM1A_H1hESC_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$IRF3_SKNSH_hg19,encodeB$IRF3_SKNSH_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$GATA3_MCF7_hg19.1,encodeB$GATA3_MCF7_hg19.1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MIER1_K562_hg19,encodeB$MIER1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MLLT1_MCF7_hg19,encodeB$MLLT1_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGTHRB_HepG2_hg19,encodeB$FLAGTHRB_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF239_HEK293_hg19,encodeB$eGFPZNF239_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPADNP_K562_hg19,encodeB$eGFPADNP_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGMXD4_HepG2_hg19,encodeB$FLAGMXD4_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TCF7_HepG2_hg19,encodeB$TCF7_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPGFI1B_HEK293_hg19,encodeB$eGFPGFI1B_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$DDX20_K562_hg19,encodeB$DDX20_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF558_HEK293_hg19,encodeB$eGFPZNF558_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZKSCAN8_K562_hg19,encodeB$eGFPZKSCAN8_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZKSCAN1_MCF7_hg19,encodeB$ZKSCAN1_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF280D_HEK293_hg19,encodeB$eGFPZNF280D_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGRCOR2_HepG2_hg19,encodeB$FLAGRCOR2_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$EZH2phosphoT487_MCF7_hg19,encodeB$EZH2phosphoT487_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF501_HEK293_hg19,encodeB$eGFPZNF501_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF101_HEK293_hg19,encodeB$eGFPZNF101_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGGABPB1_HepG2_isoform2,encodeB$FLAGGABPB1_HepG2_isoform2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF140_HEK293_hg19,encodeB$eGFPZNF140_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FOXK2_MCF7_hg19,encodeB$FOXK2_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPSP7_HEK293_hg19,encodeB$eGFPSP7_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SIN3A_MCF7_hg19,encodeB$SIN3A_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CBX2_A549_hg19,encodeB$CBX2_A549_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$BMI1_GM12878_hg19,encodeB$BMI1_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ESRRA_A549_hg19,encodeB$ESRRA_A549_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPELF1_MCF7_hg19,encodeB$eGFPELF1_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZBTB8A_HEK293_hg19,encodeB$eGFPZBTB8A_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SMC3_A549_hg19,encodeB$SMC3_A549_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPGLIS1_HEK293_hg19,encodeB$eGFPGLIS1_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$RAD51_GM12878_hg19,encodeB$RAD51_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ESRRA_K562_hg19,encodeB$ESRRA_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGZFP64_HepG2_hg19,encodeB$FLAGZFP64_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$NFE2L2_HepG2_hg19,encodeB$NFE2L2_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZC3H8_K562_hg19,encodeB$ZC3H8_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGTEAD1_HepG2_hg19,encodeB$FLAGTEAD1_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGRARA_HepG2_hg19,encodeB$FLAGRARA_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TCF7_GM12878_hg19,encodeB$TCF7_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGZNF652_HepG2_hg19,encodeB$FLAGZNF652_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF654_HEK293_hg19,encodeB$eGFPZNF654_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPE2F4_MCF7_hg19,encodeB$eGFPE2F4_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SIN3A_A549_hg19,encodeB$SIN3A_A549_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZBTB33_liver_hg19,encodeB$ZBTB33_liver_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF48_HEK293_hg19,encodeB$eGFPZNF48_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$NR2F6_HepG2_hg19,encodeB$NR2F6_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF264_HEK293_hg19,encodeB$eGFPZNF264_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$
_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGRFX3_HepG2_isoform1,encodeB$FLAGRFX3_HepG2_isoform1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$UBTF_HeLaS3_hg19,encodeB$UBTF_HeLaS3_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPTEAD2_K562_hg19,encodeB$eGFPTEAD2_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CTBP1_MCF7_hg19,encodeB$CTBP1_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$KDM1A_A549_hg19,encodeB$KDM1A_A549_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGCEBPG_HepG2_hg19,encodeB$FLAGCEBPG_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$KDM4B_K562_hg19,encodeB$KDM4B_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPMEF2D_K562_hg19,encodeB$eGFPMEF2D_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPILK_K562_hg19,encodeB$eGFPILK_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CHD7_GM12878_hg19,encodeB$CHD7_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGSLC30A9_HepG2_hg19,encodeB$FLAGSLC30A9_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGHHEX_HepG2_hg19,encodeB$FLAGHHEX_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$NFRKB_K562_hg19,encodeB$NFRKB_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$HDAC2_A549_hg19,encodeB$HDAC2_A549_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGNR2F1_HepG2_hg19,encodeB$FLAGNR2F1_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MNT_MCF7_hg19,encodeB$MNT_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ELK1_IMR90_hg19,encodeB$ELK1_IMR90_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGTEAD3_HepG2_hg19,encodeB$FLAGTEAD3_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF580_HEK293_hg19,encodeB$eGFPZNF580_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGATF4_HepG2_hg19,encodeB$FLAGATF4_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGDMAP1_HepG2_hg19,encodeB$FLAGDMAP1_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPTAF7_K562_hg19,encodeB$eGFPTAF7_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF792_HEK293_hg19,encodeB$eGFPZNF792_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CEBPB_GM12878_hg19,encodeB$CEBPB_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZNF207_HepG2_hg19,encodeB$ZNF207_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF610_HEK293_hg19,encodeB$eGFPZNF610_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$HCFC1_MCF7_hg19,encodeB$HCFC1_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGRAD21_MCF7_hg19,encodeB$FLAGRAD21_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGZGPAT_HepG2_hg19,encodeB$FLAGZGPAT_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZSCAN23_HEK293_hg19,encodeB$eGFPZSCAN23_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZBTB11_K562_hg19,encodeB$eGFPZBTB11_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPMYNN_HEK293_hg19,encodeB$eGFPMYNN_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$NFE2L2_HeLaS3_hg19,encodeB$NFE2L2_HeLaS3_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$NR2F6_K562_hg19,encodeB$NR2F6_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPE2F5_K562_hg19,encodeB$eGFPE2F5_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF837_HEK293_hg19,encodeB$eGFPZNF837_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$PKNOX1_GM12878_hg19,encodeB$PKNOX1_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGZSCAN9_HepG2_hg19,encodeB$FLAGZSCAN9_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPPRDM2_HEK293_hg19,encodeB$eGFPPRDM2_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF664_HEK293_hg19,encodeB$eGFPZNF664_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ETV4_HepG2_hg19,encodeB$ETV4_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$DPF2_K562_hg19,encodeB$DPF2_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGSOX13_HepG2_isoform1,encodeB$FLAGSOX13_HepG2_isoform1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF644_K562_hg19,encodeB$eGFPZNF644_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SP1_MCF7_hg19,encodeB$SP1_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF788_HEK293_hg19,encodeB$eGFPZNF788_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MYNN_K562_hg19,encodeB$MYNN_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TBX21_GM12878_hg19,encodeB$TBX21_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$WDR5_A549_hg19,encodeB$WDR5_A549_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPBACH1_K562_hg19,encodeB$eGFPBACH1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SUZ12_GM12878_hg19,encodeB$SUZ12_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGGMEB2_HepG2_hg19,encodeB$FLAGGMEB2_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPNR2C2_K562_hg19,encodeB$eGFPNR2C2_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CHD4_GM12878_hg19,encodeB$CHD4_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TARDBP_HEK293T_hg19,encodeB$TARDBP_HEK293T_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGKLF6_HepG2_isoform2,encodeB$FLAGKLF6_HepG2_isoform2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$HMBOX1_K562_hg19,encodeB$HMBOX1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGBCL6_HepG2_isoform1,encodeB$FLAGBCL6_HepG2_isoform1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPPRDM12_HEK293_hg19,encodeB$eGFPPRDM12_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$KLF16_K562_hg19,encodeB$KLF16_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGDRAP1_HepG2_hg19,encodeB$FLAGDRAP1_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF324_HEK293_hg19,encodeB$eGFPZNF324_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPOVOL3_HEK293_hg19,encodeB$eGFPOVOL3_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPAEBP2_HEK293_hg19,encodeB$eGFPAEBP2_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGELF3_HepG2_hg19,encodeB$FLAGELF3_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPBCL11B_HEK293_hg19,encodeB$eGFPBCL11B_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SUZ12_HepG2_hg19,encodeB$SUZ12_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CBX8_H1hESC_hg19,encodeB$CBX8_H1hESC_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPRELA_K562_hg19,encodeB$eGFPRELA_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZBTB7A_HEK293_hg19,encodeB$eGFPZBTB7A_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CBX2_H1hESC_hg19,encodeB$CBX2_H1hESC_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF781_HEK293_hg19,encodeB$eGFPZNF781_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZZZ3_K562_hg19,encodeB$ZZZ3_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$BMI1_K562_hg19,encodeB$BMI1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$RNF2_H1hESC_hg19,encodeB$RNF2_H1hESC_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CTCF_neutrophil_hg19,encodeB$CTCF_neutrophil_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPTSC22D4_K562_hg19,encodeB$eGFPTSC22D4_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$BHLHE40_HEK293T_hg19,encodeB$BHLHE40_HEK293T_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$JUNB_K562_hg19,encodeB$JUNB_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$RNF2_A549_hg19,encodeB$RNF2_A549_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGNR2F6_HepG2_hg19,encodeB$FLAGNR2F6_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$YBX1_HepG2_hg19,encodeB$YBX1_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$HNF1A_HepG2_hg19,encodeB$HNF1A_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPGTF2A2_K562_hg19,encodeB$eGFPGTF2A2_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPHIC1_HEK293_hg19,encodeB$eGFPHIC1_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPSP2_HEK293_hg19,encodeB$eGFPSP2_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$BCOR_K562_hg19,encodeB$BCOR_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGZKSCAN8_HepG2_hg19,encodeB$FLAGZKSCAN8_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CBX5_H1hESC_hg19,encodeB$CBX5_H1hESC_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$BRD4_H1hESC_hg19,encodeB$BRD4_H1hESC_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SREBF1_K562_hg19,encodeB$SREBF1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CHD7_A549_hg19,encodeB$CHD7_A549_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPMAFG_K562_hg19,encodeB$eGFPMAFG_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MYB_GM12878_hg19,encodeB$MYB_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FOXA1_K562_hg19,encodeB$FOXA1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CBX1_HepG2_hg19,encodeB$CBX1_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ARID1B_K562_hg19,encodeB$ARID1B_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGRFXANK_HepG2_hg19,encodeB$FLAGRFXANK_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGSMAD4_HepG2_isoform1,encodeB$FLAGSMAD4_HepG2_isoform1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPFEZF1_HEK293_hg19,encodeB$eGFPFEZF1_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TRIM22_GM12878_hg19,encodeB$TRIM22_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SMARCA4_bipolarspindleneuron_hg19,encodeB$SMARCA4_bipolarspindleneuron_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CREM_GM12878_hg19,encodeB$CREM_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF639_K562_hg19,encodeB$eGFPZNF639_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPFOXJ2_K562_hg19,encodeB$eGFPFOXJ2_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZMYM3_HepG2_hg19,encodeB$ZMYM3_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGPBX2_HepG2_hg19,encodeB$FLAGPBX2_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$WDR5_H1hESC_hg19,encodeB$WDR5_H1hESC_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF707_HEK293_hg19,encodeB$eGFPZNF707_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPKLF1_HEK293_hg19,encodeB$eGFPKLF1_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CBFB_GM12878_hg19,encodeB$CBFB_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$L3MBTL2_HEK293T_hg19,encodeB$L3MBTL2_HEK293T_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TCF7_K562_hg19,encodeB$TCF7_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$YBX1_MCF7_hg19,encodeB$YBX1_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZSCAN16_HEK293_hg19,encodeB$eGFPZSCAN16_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$THRAP3_K562_hg19,encodeB$THRAP3_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FOXK2_HEK293T_hg19,encodeB$FOXK2_HEK293T_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZBTB33_K562_hg19,encodeB$ZBTB33_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZHX2_MCF7_hg19,encodeB$ZHX2_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$RING1_H1hESC_hg19,encodeB$RING1_H1hESC_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZKSCAN1_K562_hg19,encodeB$ZKSCAN1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZNF384_HEK293T_hg19,encodeB$ZNF384_HEK293T_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZBTB11_HEK293_hg19,encodeB$eGFPZBTB11_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$EZH2phosphoT487_bipolarspindleneuron_hg19,encodeB$EZH2phosphoT487_bipolarspindleneuron_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZHX1_HeLaS3_hg19,encodeB$ZHX1_HeLaS3_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TCF7L2_K562_hg19,encodeB$TCF7L2_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$REST_A549_hg19,encodeB$REST_A549_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SUPT5H_K562_hg19,encodeB$SUPT5H_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$KDM6A_H1hESC_hg19,encodeB$KDM6A_H1hESC_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SMARCA5_K562_hg19,encodeB$SMARCA5_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPREST_HEK293_hg19,encodeB$eGFPREST_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$JUNB_GM12878_hg19,encodeB$JUNB_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SREBF1_A549_hg19,encodeB$SREBF1_A549_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZNF687_MCF7_hg19,encodeB$ZNF687_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CREM_HepG2_hg19,encodeB$CREM_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$EZH2_MCF7_hg19,encodeB$EZH2_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TRIM24_K562_hg19,encodeB$TRIM24_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGMXD3_HepG2_isoform1,encodeB$FLAGMXD3_HepG2_isoform1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZEB1_HEK293_hg19,encodeB$eGFPZEB1_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF547_HEK293_hg19,encodeB$eGFPZNF547_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$NONO_MCF7_hg19,encodeB$NONO_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$RAD21_liver_hg19,encodeB$RAD21_liver_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPEGR2_HEK293_hg19,encodeB$eGFPEGR2_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZFX_K562_hg19,encodeB$eGFPZFX_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGGATAD2A_HepG2_hg19,encodeB$FLAGGATAD2A_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGHMG20B_HepG2_isoform2,encodeB$FLAGHMG20B_HepG2_isoform2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPIRF9_K562_hg19,encodeB$eGFPIRF9_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZBTB1_HEK293_hg19,encodeB$eGFPZBTB1_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$NCOA1_K562_hg19,encodeB$NCOA1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$KDM5A_A549_hg19,encodeB$KDM5A_A549_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGKLF9_HepG2_hg19,encodeB$FLAGKLF9_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MBD2_MCF7_hg19,encodeB$MBD2_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CBX1_K562_hg19,encodeB$CBX1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGKAT8_HepG2_hg19,encodeB$FLAGKAT8_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ESRRA_MCF7_hg19,encodeB$ESRRA_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$BHLHE40_IMR90_hg19,encodeB$BHLHE40_IMR90_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGSAP130_HepG2_hg19,encodeB$FLAGSAP130_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ATF2_GM12878_hg19,encodeB$ATF2_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGSOX5_HepG2_hg19,encodeB$FLAGSOX5_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPWT1_HEK293_hg19,encodeB$eGFPWT1_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGMIXL1_HepG2_hg19,encodeB$FLAGMIXL1_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPPATZ1_HEK293_hg19,encodeB$eGFPPATZ1_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$NR2F1_K562_hg19,encodeB$NR2F1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPELF1_K562_hg19,encodeB$eGFPELF1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF18_HEK293_hg19,encodeB$eGFPZNF18_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$KDM5A_GM12878_hg19,encodeB$KDM5A_GM12878_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF24_HEK293_hg19,encodeB$eGFPZNF24_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$PKNOX1_MCF7_hg19,encodeB$PKNOX1_MCF7_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGARID4B_HepG2_hg19,encodeB$FLAGARID4B_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGRERE_HepG2_hg19,encodeB$FLAGRERE_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MCM3_K562_hg19,encodeB$MCM3_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SP1_K562_hg19,encodeB$SP1_K562_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FLAGTGIF2_HepG2_hg19,encodeB$FLAGTGIF2_HepG2_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$JUN_A549_hg19,encodeB$JUN_A549_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$eGFPZNF202_HEK293_hg19,encodeB$eGFPZNF202_HEK293_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$NFRKB_HEK293T_hg19,encodeB$NFRKB_HEK293T_hg19,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CEBPB_myocyte_mm9,encodeB$CEBPB_myocyte_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MYOG_myocyte_mm9,encodeB$MYOG_myocyte_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$USF1_myocyte_mm9,encodeB$USF1_myocyte_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MYOG_C2C12_mm9,encodeB$MYOG_C2C12_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MYOD1_C2C12_mm9,encodeB$MYOD1_C2C12_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MYOD1_myocyte_mm9,encodeB$MYOD1_myocyte_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$E2F4_myocyte_mm9,encodeB$E2F4_myocyte_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CTCF_C2C12_mm9,encodeB$CTCF_C2C12_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$FOSL1_C2C12_mm9,encodeB$FOSL1_C2C12_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MAX_myocyte_mm9,encodeB$MAX_myocyte_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SRF_myocyte_mm9,encodeB$SRF_myocyte_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TCF12_myocyte_mm9,encodeB$TCF12_myocyte_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MAX_C2C12_mm9,encodeB$MAX_C2C12_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TCF3_myocyte_mm9,encodeB$TCF3_myocyte_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$USF1_C2C12_mm9,encodeB$USF1_C2C12_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$REST_myocyte_mm9,encodeB$REST_myocyte_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CEBPB_C2C12_mm9,encodeB$CEBPB_C2C12_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$POLR2A_myocyte_mm9,encodeB$POLR2A_myocyte_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZNF384_CH12.LX_mm9,encodeB$ZNF384_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZMIZ1_CH12.LX_mm9,encodeB$ZMIZ1_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZC3H11A_CH12.LX_mm9,encodeB$ZC3H11A_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$HCFC1_CH12.LX_mm9,encodeB$HCFC1_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$GABPA_CH12.LX_mm9,encodeB$GABPA_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MAZ_CH12.LX_mm9,encodeB$MAZ_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$KAT2A_CH12.LX_mm9,encodeB$KAT2A_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CHD1_CH12.LX_mm9,encodeB$CHD1_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZKSCAN1_CH12.LX_mm9,encodeB$ZKSCAN1_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$UBTF_CH12.LX_mm9,encodeB$UBTF_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SIN3A_CH12.LX_mm9,encodeB$SIN3A_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$RCOR1_CH12.LX_mm9,encodeB$RCOR1_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ETS1_CH12.LX_mm9,encodeB$ETS1_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MAFK_CH12.LX_mm9,encodeB$MAFK_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$BHLHE40_CH12.LX_mm9,encodeB$BHLHE40_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$NELFE_CH12.LX_mm9,encodeB$NELFE_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MXI1_CH12.LX_mm9,encodeB$MXI1_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CHD2_CH12.LX_mm9,encodeB$CHD2_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SMC3_CH12.LX_mm9,encodeB$SMC3_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$EP300_CH12.LX_mm9,encodeB$EP300_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$USF2_CH12.LX_mm9,encodeB$USF2_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$RAD21_CH12.LX_mm9,encodeB$RAD21_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MAX_CH12.LX_mm9,encodeB$MAX_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CTCF_CH12.LX_mm9,encodeB$CTCF_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MYC_CH12.LX_mm9,encodeB$MYC_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$JUN_CH12.LX_mm9,encodeB$JUN_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TBP_CH12.LX_mm9,encodeB$TBP_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$POLR2A_CH12.LX_mm9,encodeB$POLR2A_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$JUND_CH12.LX_mm9,encodeB$JUND_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$E2F4_CH12.LX_mm9,encodeB$E2F4_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZNF384_ESE14_mm9,encodeB$ZNF384_ESE14_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZC3H11A_ESE14_mm9,encodeB$ZC3H11A_ESE14_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$HCFC1_ESE14_mm9,encodeB$HCFC1_ESE14_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZNF384_MELcellline_mm9,encodeB$ZNF384_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZMIZ1_MELcellline_mm9,encodeB$ZMIZ1_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$HCFC1_MELcellline_mm9,encodeB$HCFC1_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$RCOR1_MELcellline_mm9,encodeB$RCOR1_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CHD1_MELcellline_mm9,encodeB$CHD1_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ZKSCAN1_MELcellline_mm9,encodeB$ZKSCAN1_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ETS1_MELcellline_mm9,encodeB$ETS1_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SIN3A_MELcellline_mm9,encodeB$SIN3A_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$USF2_MELcellline_mm9,encodeB$USF2_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MAFK_MELcellline_mm9,encodeB$MAFK_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$SMC3_MELcellline_mm9,encodeB$SMC3_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MXI1_MELcellline_mm9,encodeB$MXI1_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CHD2_MELcellline_mm9,encodeB$CHD2_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$EP300_MELcellline_mm9,encodeB$EP300_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CTCF_MELcellline_mm9,encodeB$CTCF_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MYB_MELcellline_mm9,encodeB$MYB_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$RAD21_MELcellline_mm9,encodeB$RAD21_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$NELFE_MELcellline_mm9,encodeB$NELFE_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MAX_MELcellline_mm9,encodeB$MAX_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$E2F4_MELcellline_mm9,encodeB$E2F4_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$JUND_MELcellline_mm9,encodeB$JUND_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MYC_MELcellline_mm9,encodeB$MYC_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TBP_MELcellline_mm9,encodeB$TBP_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$POLR2A_MELcellline_mm9,encodeB$POLR2A_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$GATA1_MELcellline_mm9,encodeB$GATA1_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$NRF1_MELcellline_mm9,encodeB$NRF1_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$ELF1_CH12.LX_mm9,encodeB$ELF1_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TCF12_MELcellline_mm9,encodeB$TCF12_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CHD2_ESE14_mm9,encodeB$CHD2_ESE14_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MAFK_ESE14_mm9,encodeB$MAFK_ESE14_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$USF1_MELcellline_mm9,encodeB$USF1_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$IRF4_CH12.LX_mm9,encodeB$IRF4_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MEF2A_CH12.LX_mm9,encodeB$MEF2A_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$MEF2A_MELcellline_mm9,encodeB$MEF2A_MELcellline_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$TCF12_CH12.LX_mm9,encodeB$TCF12_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$USF1_CH12.LX_mm9,encodeB$USF1_CH12.LX_mm9,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$NRF1_CH12.LX_mm9,encodeB$NRF1_CH12.LX_mm9,genome.size=20805))



for (go.obj in golist)
    print(testGeneOverlap(go.obj))
# Out:
# Detailed information about this GeneOverlap object:
# listA size=2000, e.g. LINC01420 POLR2K ZNF528
# listB size=1681, e.g. HEXIM1 CKMT1B CACNA2D1
# Intersection size=175, e.g. NPPA NME1-NME2 PUS3
# Union size=3506, e.g. LINC01420 POLR2K ZNF528
# Genome size=20805
# # Contingency Table:
#       notA  inA
# notB 17299 1825
# inB   1506  175
# Overlapping p-value=0.13
# Odds ratio=1.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=2000, e.g. POLK MMEL1 PPP2R3C
# listB size=1174, e.g. ANKFY1 NGDN CACNA2D1
# Intersection size=98, e.g. EIF4E2 SNHG12 CASP8
# Union size=3076, e.g. POLK MMEL1 PPP2R3C
# Genome size=20805
# # Contingency Table:
#       notA  inA
# notB 17729 1902
# inB   1076   98
# Overlapping p-value=0.94
# Odds ratio=0.8
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# ...
