# %%
library(GeneOverlap)

# %%
# Load library
library(GeneOverlap)

# Read in R tables
# encode2015
encodeB <- read.table('/Users/Carol/Desktop/arquivoNovo/ENCODE_2015_correction.csv',sep=',', header=TRUE)

#na verdade e' o creeds
encodeA <- read.table('/Users/Carol/Desktop/arquivoNovo/creeds_down.csv',sep=',', header=TRUE)

#creedsup <- 'Users/Carol/Desktop/arquivoNovo/creeds_full_up_gene_pronto_p_ir_list_overlap.csv' 
#creedsdn <- 'Users/Carol/Desktop/arquivoNovo/creeds_full_dn_gene_pronto_p_ir_list_overlap.csv' 

gobject <- read.table('/Users/Carol/Desktop/arquivoNovo/gobjectD.csv',sep=',', header=TRUE)

# summary(gobject)
#nrow(gobject)

sapply(encodeA,length);
sapply(encodeB,length);
# Out:
#  gene_508  gene_509 gene_2349 gene_2348 gene_2343  gene_501  gene_502 gene_2340
#       600       600       600       600       600       600       600       600
#  gene_504  gene_506 gene_2344 gene_1928 gene_1926 gene_1927 gene_2342 gene_2341
#       600       600       600       600       600       600       600       600
# gene_2347 gene_2581 gene_2580 gene_2583 gene_2582 gene_2585 gene_2584 gene_2587
#       600       600       600       600       600       600       600       600
# gene_2586 gene_2589 gene_2588 gene_1852 gene_1853 gene_1850 gene_1851 gene_1854
#       600       600       600       600       600       600       600       600
# gene_1855 gene_2747 gene_2746 gene_2745 gene_2743 gene_2742 gene_2741 gene_2740
#       600       600       600       600       600       600       600       600
#  gene_892  gene_893  gene_890  gene_891  gene_897  gene_898  gene_899 gene_2792
#       600       600       600       600       600       600       600       600
# gene_1134 gene_1131   gene_68 gene_1132 gene_2752  gene_879  gene_870   gene_62
#       600       600       600       600       600       600       600       600
#  gene_872  gene_875   gene_60 gene_1428 gene_1324 gene_1325 gene_1320 gene_1321
#       600       600       600       600       600       600       600       600
# gene_1322 gene_1323 gene_1328 gene_1329   gene_34   gene_37   gene_36 gene_1108
#       600       600       600       600       600       600       600       600
# gene_1109   gene_32 gene_1456 gene_1457 gene_1106 gene_1107 gene_1452 gene_1453
#       600       600       600       600       600       600       600       600
# gene_1450 gene_1451 gene_1698 gene_1699 gene_1694 gene_1695 gene_1696 gene_1697
#       600       600       600       600       600       600       600       600
# gene_1691 gene_1692 gene_1218 gene_1219 gene_1210 gene_1211 gene_1212 gene_1213
#       600       600       600       600       600       600       600       600
# gene_1217 gene_2004 gene_2005 gene_2006 gene_2007 gene_2000 gene_2001 gene_2002
#       600       600       600       600       600       600       600       600
# gene_2003 gene_2008 gene_2009 gene_1070 gene_1071 gene_1072 gene_1074 gene_1075
#       600       600       600       600       600       600       600       600
# gene_1076 gene_1077 gene_1078 gene_1079 gene_1553  gene_649  gene_648  gene_647
#       600       600       600       600       600       600       600       600
#  gene_643  gene_642  gene_641  gene_640 gene_3112  gene_467 gene_2179  gene_465
#       600       600       600       600       600       600       600       600
#  gene_464  gene_463  gene_462  gene_461  gene_460 gene_2170 gene_2172 gene_2173
#       600       600       600       600       600       600       600       600
#  gene_469  gene_468 gene_3118 gene_2369  gene_261  gene_260  gene_263  gene_262
#       600       600       600       600       600       600       600       600
#  gene_265  gene_264  gene_267  gene_266  gene_268  gene_519  gene_518 gene_2358
#       600       600       600       600       600       600       600       600
# gene_2359 gene_2354 gene_2355 gene_2356  gene_510  gene_517  gene_516  gene_515
#       600       600       600       600       600       600       600       600
#  gene_514 gene_1913 gene_1912 gene_1911 gene_1910 gene_2748 gene_2813 gene_2764
#       600       600       600       600       600       600       600       600
# gene_3108 gene_2592 gene_2593 gene_2590 gene_2596 gene_2468 gene_2594 gene_2469
#       600       600       600       600       600       600       600       600
# gene_1867 gene_1866 gene_1865 gene_1862 gene_2756 gene_2757 gene_2758 gene_2759
#       600       600       600       600       600       600       600       600
# gene_1869 gene_1868  gene_885  gene_881  gene_880  gene_883 gene_1141  gene_888
#       600       600       600       600       600       600       600       600
# gene_2916  gene_869  gene_868  gene_863  gene_862  gene_861  gene_860  gene_867
#       600       600       600       600       600       600       600       600
#  gene_866  gene_865 gene_2968 gene_3050 gene_2965 gene_1462 gene_2964 gene_1467
#       600       600       600       600       600       600       600       600
# gene_1466   gene_24 gene_1464   gene_28   gene_29 gene_2962 gene_1660 gene_1664
#       600       600       600       600       600       600       600       600
# gene_1667 gene_1666 gene_1669 gene_1668 gene_2960 gene_2911 gene_1267 gene_1266
#       600       600       600       600       600       600       600       600
# gene_1261 gene_1260 gene_1263 gene_1262  gene_184  gene_187  gene_180  gene_181
#       600       600       600       600       600       600       600       600
#  gene_182  gene_183  gene_188  gene_189 gene_3028 gene_1004 gene_1007 gene_1001
#       600       600       600       600       600       600       600       600
# gene_1000 gene_1003 gene_1008  gene_672  gene_673  gene_671  gene_676  gene_677
#       600       600       600       600       600       600       600       600
#  gene_674  gene_675  gene_678  gene_679 gene_1454  gene_698  gene_699 gene_2108
#       600       600       600       600       600       600       600       600
#  gene_690  gene_691  gene_692  gene_693  gene_694  gene_695  gene_696  gene_697
#       600       600       600       600       600       600       600       600
# gene_1719 gene_1718 gene_1711 gene_1710 gene_1713 gene_1712 gene_1714 gene_1717
#       600       600       600       600       600       600       600       600
# gene_1481 gene_1480 gene_1483 gene_1482 gene_1485 gene_1484 gene_1486  gene_215
#       600       600       600       600       600       600       600       600
#  gene_216  gene_217  gene_210  gene_211  gene_212 gene_2261  gene_528  gene_529
#       600       600       600       600       600       600       600       600
#  gene_524  gene_522  gene_523  gene_520  gene_521 gene_1904 gene_1905 gene_1906
#       600       600       600       600       600       600       600       600
# gene_1907 gene_1900 gene_1901 gene_1902 gene_1903 gene_2619 gene_1908 gene_1909
#       600       600       600       600       600       600       600       600
# gene_2825  gene_328  gene_329  gene_458  gene_459  gene_452  gene_453  gene_450
#       600       600       600       600       600       600       600       600
# gene_2296  gene_456  gene_457  gene_326  gene_455 gene_1879 gene_2812 gene_1870
#       600       600       600       600       600       600       600       600
# gene_1871 gene_1872 gene_1873 gene_2811 gene_1876 gene_1877 gene_2724 gene_2823
#       600       600       600       600       600       600       600       600
# gene_2726 gene_2720 gene_2723 gene_2814 gene_2439 gene_2438 gene_2431 gene_2430
#       600       600       600       600       600       600       600       600
# gene_2433 gene_2432 gene_2435 gene_2434 gene_2437 gene_2436  gene_984  gene_985
#       600       600       600       600       600       600       600       600
#  gene_986  gene_987  gene_980  gene_981  gene_982  gene_983 gene_2497 gene_2364
#       600       600       600       600       600       600       600       600
# gene_2248 gene_2249 gene_2361 gene_2492 gene_2363 gene_2490 gene_2714 gene_2715
#       600       600       600       600       600       600       600       600
# gene_2240 gene_2241  gene_858  gene_859  gene_857  gene_852  gene_853  gene_851
#       600       600       600       600       600       600       600       600
# gene_2712 gene_2713 gene_2907 gene_2906   gene_44   gene_46 gene_2828   gene_40
#       600       600       600       600       600       600       600       600
#   gene_41 gene_1474 gene_1475 gene_1477 gene_1471 gene_1472 gene_1473 gene_1157
#       600       600       600       600       600       600       600       600
# gene_1158 gene_1478 gene_1479 gene_2829 gene_1672 gene_1673 gene_1670 gene_1671
#       600       600       600       600       600       600       600       600
# gene_1676 gene_1677 gene_1674 gene_1156 gene_1678 gene_1679  gene_296   gene_48
#       600       600       600       600       600       600       600       600
# gene_1274 gene_1275 gene_1272 gene_1273 gene_1270 gene_1271  gene_196  gene_195
#       600       600       600       600       600       600       600       600
#  gene_194  gene_193  gene_192  gene_191  gene_190  gene_199  gene_198 gene_1016
#       600       600       600       600       600       600       600       600
# gene_1017 gene_1013 gene_1018 gene_1019  gene_665  gene_664  gene_667  gene_666
#       600       600       600       600       600       600       600       600
#  gene_661  gene_660  gene_663  gene_662  gene_668  gene_688  gene_683  gene_681
#       600       600       600       600       600       600       600       600
#  gene_680  gene_687  gene_686  gene_685  gene_684 gene_1708 gene_1709 gene_1701
#       600       600       600       600       600       600       600       600
# gene_1706 gene_1707 gene_1704 gene_1705 gene_1498 gene_1499 gene_1492 gene_1493
#       600       600       600       600       600       600       600       600
# gene_1490 gene_1491 gene_1496 gene_1497 gene_1494 gene_1495  gene_207  gene_206
#       600       600       600       600       600       600       600       600
#  gene_205  gene_204  gene_203  gene_202  gene_201  gene_200  gene_209  gene_208
#       600       600       600       600       600       600       600       600
#  gene_531  gene_533  gene_534  gene_537  gene_539  gene_538 gene_2603 gene_2606
#       600       600       600       600       600       600       600       600
# gene_2607 gene_2604 gene_2605 gene_2608 gene_2609 gene_2491 gene_2909  gene_338
#       600       600       600       600       600       600       600       600
#  gene_449  gene_448 gene_2288 gene_2289  gene_333  gene_444  gene_447  gene_446
#       600       600       600       600       600       600       600       600
#  gene_441  gene_440  gene_443 gene_2281 gene_3082 gene_3080 gene_3087 gene_3085
#       600       600       600       600       600       600       600       600
# gene_2908  gene_689 gene_1809 gene_1808 gene_1805 gene_1804 gene_1807 gene_1806
#       600       600       600       600       600       600       600       600
# gene_1800 gene_1803 gene_1802 gene_2736 gene_2737 gene_2734 gene_2735 gene_2732
#       600       600       600       600       600       600       600       600
# gene_2733 gene_2730 gene_2731 gene_2738 gene_2739  gene_356 gene_2768 gene_2839
#       600       600       600       600       600       600       600       600
# gene_2428 gene_2429 gene_2422 gene_2423 gene_2420 gene_2421 gene_2426 gene_2424
#       600       600       600       600       600       600       600       600
# gene_2425 gene_3044 gene_1603  gene_998  gene_997  gene_996  gene_995  gene_994
#       600       600       600       600       600       600       600       600
#  gene_993  gene_992  gene_990 gene_1606 gene_3069 gene_3068 gene_2705 gene_3061
#       600       600       600       600       600       600       600       600
# gene_3060 gene_3063 gene_3062 gene_3064 gene_3067 gene_3066 gene_2058  gene_845
#       600       600       600       600       600       600       600       600
#  gene_847  gene_848 gene_1054 gene_2971 gene_1395 gene_1397 gene_1396 gene_1642
#       600       600       600       600       600       600       600       600
# gene_1393 gene_1640 gene_1399 gene_1398 gene_1243 gene_1242 gene_1241 gene_1240
#       600       600       600       600       600       600       600       600
# gene_1247 gene_1245 gene_1244 gene_1249 gene_1248 gene_1029 gene_1023 gene_1022
#       600       600       600       600       600       600       600       600
# gene_1020 gene_1027 gene_1026 gene_1025 gene_1024 gene_2238 gene_2976 gene_2233
#       600       600       600       600       600       600       600       600
# gene_2943 gene_2230  gene_434 gene_2236 gene_2235 gene_1739 gene_1738 gene_1737
#       600       600       600       600       600       600       600       600
# gene_1736 gene_1735 gene_1734 gene_1733 gene_1732 gene_1731 gene_1730 gene_3079
#       600       600       600       600       600       600       600       600
# gene_2387  gene_545  gene_546  gene_547  gene_541  gene_542  gene_543  gene_548
#       600       600       600       600       600       600       600       600
#  gene_549 gene_2389 gene_2388   gene_31  gene_308  gene_309  gene_306  gene_307
#       600       600       600       600       600       600       600       600
#  gene_304  gene_305  gene_302  gene_303  gene_300 gene_3094 gene_3095 gene_1455
#       600       600       600       600       600       600       600       600
# gene_3090 gene_3091 gene_2841 gene_3093   gene_39 gene_3098 gene_3099 gene_2259
#       600       600       600       600       600       600       600       600
# gene_2258 gene_2709 gene_2708 gene_1818 gene_1819 gene_1816 gene_1817 gene_1814
#       600       600       600       600       600       600       600       600
# gene_1815 gene_1812 gene_1813 gene_1810 gene_1811 gene_2842 gene_2285 gene_2419
#       600       600       600       600       600       600       600       600
# gene_2418 gene_2417 gene_2416 gene_2415 gene_2414 gene_2413 gene_2412 gene_2411
#       600       600       600       600       600       600       600       600
# gene_2410 gene_2938 gene_2845 gene_2939 gene_2286  gene_332 gene_2846  gene_331
#       600       600       600       600       600       600       600       600
# gene_3078  gene_330 gene_3072  gene_337 gene_3070 gene_3071 gene_3077 gene_2283
#       600       600       600       600       600       600       600       600
# gene_2280 gene_1193  gene_837  gene_831  gene_838 gene_1191 gene_3089  gene_948
#       600       600       600       600       600       600       600       600
#  gene_949  gene_940  gene_941  gene_942  gene_943  gene_944  gene_945  gene_946
#       600       600       600       600       600       600       600       600
#  gene_947 gene_1658 gene_1386 gene_1387 gene_1385 gene_1380 gene_1381 gene_1388
#       600       600       600       600       600       600       600       600
# gene_1389 gene_1256 gene_1257 gene_1251 gene_1252 gene_1253 gene_1258 gene_1259
#       600       600       600       600       600       600       600       600
# gene_1039 gene_1034 gene_1035 gene_1036 gene_1037 gene_1030 gene_1031 gene_1032
#       600       600       600       600       600       600       600       600
# gene_1033 gene_2697 gene_1720 gene_1721 gene_1722 gene_1723 gene_1724 gene_1725
#       600       600       600       600       600       600       600       600
# gene_1726 gene_1727 gene_1728 gene_1729  gene_224  gene_226  gene_221  gene_220
#       600       600       600       600       600       600       600       600
#  gene_223  gene_222 gene_2818 gene_2628  gene_556  gene_555  gene_554  gene_553
#       600       600       600       600       600       600       600       600
#  gene_552  gene_551  gene_550 gene_2620 gene_2622 gene_2623 gene_2624 gene_2625
#       600       600       600       600       600       600       600       600
#  gene_559 gene_2627  gene_311  gene_310  gene_313  gene_312  gene_315  gene_314
#       600       600       600       600       600       600       600       600
#  gene_317  gene_316  gene_319  gene_318 gene_1823 gene_1822 gene_1821 gene_1820
#       600       600       600       600       600       600       600       600
# gene_1827 gene_1826 gene_1825 gene_1824 gene_2242 gene_2243 gene_1829 gene_1828
#       600       600       600       600       600       600       600       600
# gene_2246 gene_2247 gene_2244 gene_2245 gene_2398 gene_2390 gene_2391 gene_2392
#       600       600       600       600       600       600       600       600
# gene_2393 gene_2396 gene_2400 gene_2401 gene_2403 gene_2404 gene_2405 gene_2406
#       600       600       600       600       600       600       600       600
# gene_2407 gene_2408 gene_2409 gene_2178 gene_2917 gene_2779 gene_2914 gene_2676
#       600       600       600       600       600       600       600       600
# gene_2675 gene_3049 gene_3048 gene_3047 gene_3046 gene_2858 gene_3043 gene_3042
#       600       600       600       600       600       600       600       600
# gene_3041 gene_3040 gene_2855 gene_2854 gene_2853 gene_2859 gene_2934 gene_2852
#       600       600       600       600       600       600       600       600
# gene_2851 gene_2919  gene_827  gene_826  gene_825  gene_824  gene_823  gene_821
#       600       600       600       600       600       600       600       600
#  gene_820 gene_2935 gene_2936 gene_1231  gene_839  gene_959 gene_2937  gene_953
#       600       600       600       600       600       600       600       600
#  gene_952  gene_951  gene_957  gene_956  gene_955  gene_954 gene_1629 gene_1628
#       600       600       600       600       600       600       600       600
# gene_1625 gene_1624 gene_1627 gene_1626 gene_1621 gene_1620 gene_1623 gene_1622
#       600       600       600       600       600       600       600       600
# gene_2931 gene_1421 gene_2985 gene_2495 gene_2986 gene_2981 gene_2958 gene_2980
#       600       600       600       600       600       600       600       600
# gene_1531 gene_1530 gene_1533 gene_1532 gene_1535 gene_1534 gene_1537 gene_1288
#       600       600       600       600       600       600       600       600
# gene_1287 gene_1286 gene_1285 gene_1283 gene_1282 gene_1281 gene_2809 gene_2910
#       600       600       600       600       600       600       600       600
# gene_2493 gene_1755 gene_1754 gene_1757 gene_1756 gene_1750 gene_1753 gene_1752
#       600       600       600       600       600       600       600       600
# gene_1759 gene_1758  gene_782  gene_783  gene_780  gene_781  gene_786  gene_787
#       600       600       600       600       600       600       600       600
#  gene_784  gene_785  gene_788  gene_789  gene_140  gene_141  gene_142  gene_143
#       600       600       600       600       600       600       600       600
#  gene_144  gene_146  gene_147  gene_148  gene_149 gene_2879 gene_2878 gene_2659
#       600       600       600       600       600       600       600       600
# gene_2658 gene_2655 gene_2654 gene_2657 gene_2656 gene_2651  gene_494 gene_2098
#       600       600       600       600       600       600       600       600
# gene_2093 gene_2097 gene_2096  gene_364  gene_365  gene_366  gene_495  gene_360
#       600       600       600       600       600       600       600       600
#  gene_361  gene_490  gene_363  gene_369 gene_2806 gene_2357 gene_2350 gene_2351
#       600       600       600       600       600       600       600       600
# gene_1834 gene_1835 gene_1836 gene_1837 gene_1830 gene_1831 gene_1832 gene_1833
#       600       600       600       600       600       600       600       600
# gene_2277 gene_2276 gene_2275 gene_2274 gene_1838 gene_1839 gene_2271 gene_2270
#       600       600       600       600       600       600       600       600
# gene_2837  gene_568  gene_569  gene_562  gene_563  gene_560  gene_566  gene_567
#       600       600       600       600       600       600       600       600
#  gene_565 gene_2951 gene_2475 gene_2474 gene_2477 gene_2476 gene_2471 gene_2470
#       600       600       600       600       600       600       600       600
# gene_2473 gene_2472 gene_2479 gene_2478 gene_2956 gene_2509 gene_3051 gene_3054
#       600       600       600       600       600       600       600       600
# gene_3055 gene_3056 gene_3057 gene_3058 gene_2500 gene_2503 gene_2502 gene_2504
#       600       600       600       600       600       600       600       600
# gene_2507 gene_2954 gene_1536 gene_2955 gene_1539  gene_818 gene_1538  gene_813
#       600       600       600       600       600       600       600       600
#  gene_811  gene_817  gene_815 gene_2923 gene_1410  gene_969  gene_966  gene_967
#       600       600       600       600       600       600       600       600
#  gene_964  gene_965  gene_963  gene_960  gene_961 gene_2921 gene_1638 gene_1639
#       600       600       600       600       600       600       600       600
# gene_1636 gene_1637 gene_1634 gene_1635 gene_1633 gene_1630 gene_1631 gene_1416
#       600       600       600       600       600       600       600       600
# gene_2927 gene_1522 gene_1523 gene_1520 gene_1521 gene_1526 gene_1527 gene_1524
#       600       600       600       600       600       600       600       600
# gene_1298 gene_1299 gene_1529 gene_2926 gene_3102 gene_3103 gene_3100 gene_2925
#       600       600       600       600       600       600       600       600
#   gene_92   gene_91   gene_90   gene_97   gene_96   gene_94 gene_1415 gene_2924
#       600       600       600       600       600       600       600       600
# gene_1746 gene_1747 gene_1744 gene_1745 gene_1742 gene_1743 gene_1740 gene_1741
#       600       600       600       600       600       600       600       600
# gene_2451 gene_1748 gene_1749  gene_795  gene_794 gene_2886  gene_796  gene_791
#       600       600       600       600       600       600       600       600
#  gene_790  gene_793  gene_792 gene_2457 gene_2888 gene_2456  gene_153  gene_152
#       600       600       600       600       600       600       600       600
#  gene_151  gene_150  gene_157  gene_156  gene_155  gene_154 gene_2454 gene_2750
#       600       600       600       600       600       600       600       600
#  gene_779  gene_778 gene_2648 gene_2862 gene_2647 gene_2860 gene_2861  gene_777
#       600       600       600       600       600       600       600       600
#  gene_776  gene_775  gene_774 gene_2081  gene_489  gene_488  gene_480  gene_483
#       600       600       600       600       600       600       600       600
#  gene_482  gene_485  gene_484  gene_487  gene_486  gene_377  gene_376  gene_374
#       600       600       600       600       600       600       600       600
#  gene_373  gene_372  gene_371  gene_370 gene_2693  gene_379  gene_378 gene_2692
#       600       600       600       600       600       600       600       600
# gene_2695 gene_2694  gene_391 gene_2262 gene_2263 gene_2264 gene_2265 gene_2266
#       600       600       600       600       600       600       600       600
# gene_2267 gene_2268 gene_2269 gene_2696 gene_2941  gene_394  gene_578  gene_575
#       600       600       600       600       600       600       600       600
#  gene_574  gene_577  gene_571  gene_570  gene_573  gene_572 gene_2893 gene_2833
#       600       600       600       600       600       600       600       600
# gene_2892 gene_2810 gene_2891 gene_3111 gene_3110 gene_2890 gene_3117 gene_3116
#       600       600       600       600       600       600       600       600
# gene_3119 gene_2897 gene_2466 gene_1999 gene_2895 gene_2460 gene_2461 gene_1991
#       600       600       600       600       600       600       600       600
# gene_1990 gene_1995 gene_1994  gene_621 gene_2899 gene_2898 gene_3025 gene_3024
#       600       600       600       600       600       600       600       600
# gene_2518 gene_2519 gene_2945 gene_3020 gene_3023 gene_3022 gene_2510 gene_2511
#       600       600       600       600       600       600       600       600
# gene_2516 gene_2517 gene_2514 gene_2515 gene_2944 gene_2383  gene_805  gene_807
#       600       600       600       600       600       600       600       600
#  gene_806  gene_803 gene_2947 gene_2946 gene_2970 gene_2795 gene_2972 gene_2974
#       600       600       600       600       600       600       600       600
# gene_2975  gene_970  gene_973  gene_972  gene_974  gene_976  gene_979  gene_978
#       600       600       600       600       600       600       600       600
# gene_2977 gene_2871 gene_2870 gene_2873 gene_1351 gene_1350 gene_1353 gene_1352
#       600       600       600       600       600       600       600       600
# gene_1355 gene_1354 gene_1357 gene_1356 gene_2875 gene_2874 gene_3030 gene_3031
#       600       600       600       600       600       600       600       600
# gene_1517 gene_1516 gene_1515 gene_1510 gene_3039 gene_1519 gene_1518   gene_80
#       600       600       600       600       600       600       600       600
#   gene_81   gene_82   gene_83   gene_84   gene_85   gene_86   gene_87   gene_88
#       600       600       600       600       600       600       600       600
#   gene_89 gene_1199 gene_1198 gene_2872 gene_1779 gene_1778 gene_1773 gene_1771
#       600       600       600       600       600       600       600       600
# gene_1777 gene_1776 gene_1775 gene_1774 gene_1179 gene_1171 gene_1170 gene_1173
#       600       600       600       600       600       600       600       600
# gene_1172 gene_1174 gene_1177 gene_1176 gene_1645  gene_166  gene_164 gene_1644
#       600       600       600       600       600       600       600       600
#  gene_163  gene_160  gene_168  gene_169 gene_2673 gene_2672 gene_2671 gene_2677
#       600       600       600       600       600       600       600       600
# gene_1641  gene_748 gene_2674 gene_2857  gene_747 gene_2679 gene_2678  gene_742
#       600       600       600       600       600       600       600       600
#  gene_743  gene_740  gene_741 gene_2071 gene_2075 gene_2076  gene_496  gene_348
#       600       600       600       600       600       600       600       600
#  gene_349 gene_2989 gene_2988  gene_497  gene_342 gene_2984 gene_2987  gene_341
#       600       600       600       600       600       600       600       600
#  gene_346  gene_347  gene_344 gene_2982  gene_367  gene_493  gene_362  gene_491
#       600       600       600       600       600       600       600       600
# gene_2215 gene_2214 gene_2217 gene_2216 gene_2211 gene_2210 gene_2212 gene_2219
#       600       600       600       600       600       600       600       600
# gene_2218 gene_2187 gene_2186  gene_580  gene_581  gene_582  gene_583  gene_584
#       600       600       600       600       600       600       600       600
#  gene_585  gene_586 gene_2803 gene_2329 gene_2328 gene_2459 gene_2458 gene_3106
#       600       600       600       600       600       600       600       600
# gene_3107 gene_3104 gene_3105 gene_2321 gene_2452 gene_2323 gene_2322 gene_2325
#       600       600       600       600       600       600       600       600
# gene_2324 gene_2327 gene_2326 gene_2699 gene_2698 gene_1985 gene_1986 gene_1987
#       600       600       600       600       600       600       600       600
# gene_1980 gene_1981 gene_1982 gene_1983 gene_3036 gene_3037 gene_3034 gene_3035
#       600       600       600       600       600       600       600       600
# gene_3033 gene_2529 gene_2528 gene_2527 gene_2526 gene_2525 gene_2524 gene_2522
#       600       600       600       600       600       600       600       600
# gene_3038 gene_2520 gene_2372 gene_2279 gene_2278 gene_2273 gene_2272 gene_2379
#       600       600       600       600       600       600       600       600
# gene_1021  gene_904  gene_905  gene_906  gene_907  gene_900  gene_901  gene_902
#       600       600       600       600       600       600       600       600
# gene_1413  gene_908 gene_1142 gene_1411 gene_1144 gene_1614 gene_1343 gene_1340
#       600       600       600       600       600       600       600       600
# gene_1617 gene_1610 gene_1146 gene_1344 gene_1345 gene_1348 gene_1147 gene_1618
#       600       600       600       600       600       600       600       600
# gene_1619 gene_1149 gene_1419 gene_1500 gene_1501 gene_1502 gene_1503 gene_1505
#       600       600       600       600       600       600       600       600
# gene_1506 gene_1507 gene_1185 gene_1186 gene_1187 gene_1180 gene_1181 gene_1182
#       600       600       600       600       600       600       600       600
# gene_1188 gene_1189 gene_1768 gene_1765 gene_1767 gene_1760 gene_1761 gene_1763
#       600       600       600       600       600       600       600       600
#   gene_56 gene_1168 gene_1169   gene_50 gene_1162 gene_1160 gene_1167 gene_1164
#       600       600       600       600       600       600       600       600
# gene_1165  gene_179  gene_178  gene_171  gene_173  gene_172  gene_175  gene_174
#       600       600       600       600       600       600       600       600
#  gene_177  gene_176  gene_751  gene_750  gene_753  gene_752 gene_2844  gene_754
#       600       600       600       600       600       600       600       600
# gene_2662 gene_2663 gene_2848 gene_2668 gene_2669 gene_2063 gene_2067 gene_2064
#       600       600       600       600       600       600       600       600
#  gene_359  gene_358 gene_2998 gene_2999  gene_355  gene_354  gene_357  gene_903
#       600       600       600       600       600       600       600       600
#  gene_351 gene_2993  gene_353  gene_352 gene_2827 gene_2824  gene_909 gene_2206
#       600       600       600       600       600       600       600       600
# gene_2207 gene_2204 gene_2205 gene_2202 gene_2203 gene_2200 gene_2201 gene_2208
#       600       600       600       600       600       600       600       600
# gene_2209 gene_2197 gene_2194 gene_2195 gene_2190 gene_2199  gene_593  gene_591
#       600       600       600       600       600       600       600       600
#  gene_590  gene_599  gene_598 gene_2778 gene_2338 gene_2339 gene_2448 gene_2046
#       600       600       600       600       600       600       600       600
# gene_2444 gene_2333 gene_2330 gene_2331 gene_2336 gene_2337 gene_2334 gene_2335
#       600       600       600       600       600       600       600       600
# gene_1975 gene_1977 gene_1976 gene_1979 gene_2680 gene_2681 gene_2686 gene_2685
#       600       600       600       600       600       600       600       600
# gene_1342 gene_1615 gene_1616 gene_3009 gene_1341 gene_2618 gene_3002 gene_3001
#       600       600       600       600       600       600       600       600
# gene_3000 gene_3006 gene_3005 gene_1347 gene_2530 gene_2531 gene_2534 gene_2537
#       600       600       600       600       600       600       600       600
# gene_2538 gene_2539 gene_1613 gene_1884 gene_1887 gene_1886 gene_1881 gene_1889
#       600       600       600       600       600       600       600       600
# gene_1888 gene_1349 gene_2447  gene_916  gene_915  gene_914  gene_913  gene_912
#       600       600       600       600       600       600       600       600
#  gene_911  gene_910  gene_918 gene_2718 gene_1377 gene_1376 gene_1375 gene_1374
#       600       600       600       600       600       600       600       600
# gene_3109 gene_1379 gene_1378 gene_2894 gene_2719 gene_1576 gene_2385 gene_2384
#       600       600       600       600       600       600       600       600
#  gene_540 gene_2382 gene_2380 gene_2952 gene_2953 gene_2950 gene_1791 gene_1790
#       600       600       600       600       600       600       600       600
# gene_1793 gene_1792 gene_1795 gene_1794 gene_1797 gene_1796 gene_1799 gene_1798
#       600       600       600       600       600       600       600       600
# gene_2957 gene_1401   gene_45 gene_1403   gene_47  gene_298  gene_299 gene_1159
#       600       600       600       600       600       600       600       600
# gene_1406 gene_1409 gene_1408 gene_1155 gene_1154 gene_1153   gene_49 gene_1151
#       600       600       600       600       600       600       600       600
#  gene_108  gene_105  gene_106  gene_107  gene_100  gene_101 gene_2835 gene_2834
#       600       600       600       600       600       600       600       600
#  gene_726 gene_2836 gene_2831  gene_722 gene_2717 gene_2838 gene_2057 gene_2056
#       600       600       600       600       600       600       600       600
# gene_2055 gene_2052 gene_2050   gene_27 gene_2690 gene_1465 gene_2710  gene_615
#       600       600       600       600       600       600       600       600
#  gene_616  gene_617  gene_619 gene_2949  gene_439 gene_2239 gene_1468  gene_430
#       600       600       600       600       600       600       600       600
# gene_2940 gene_2231  gene_433   gene_42  gene_435  gene_436 gene_2234 gene_3121
#       600       600       600       600       600       600       600       600
# gene_3123 gene_3125 gene_3127 gene_2309 gene_2307 gene_2306 gene_2305 gene_2304
#       600       600       600       600       600       600       600       600
# gene_2300 gene_1960 gene_1961 gene_1966 gene_1964 gene_1965 gene_2884 gene_3021
#       600       600       600       600       600       600       600       600
# gene_3019 gene_3014 gene_3016 gene_3010 gene_3011 gene_3012 gene_3013 gene_2545
#       600       600       600       600       600       600       600       600
# gene_2544 gene_2547 gene_2546 gene_2541 gene_2540 gene_2543 gene_2542 gene_2453
#       600       600       600       600       600       600       600       600
# gene_2549 gene_1896 gene_1897 gene_1894 gene_1895 gene_1892 gene_1890 gene_1891
#       600       600       600       600       600       600       600       600
# gene_1898 gene_1899 gene_3097 gene_2887 gene_3092 gene_2880 gene_2450  gene_928
#       600       600       600       600       600       600       600       600
#  gene_929  gene_922 gene_2881  gene_920  gene_926  gene_927  gene_924  gene_925
#       600       600       600       600       600       600       600       600
# gene_2251 gene_2250 gene_2253 gene_2455 gene_2252 gene_2707 gene_2254 gene_2257
#       600       600       600       600       600       600       600       600
# gene_2704 gene_1562 gene_2287   gene_55 gene_1369   gene_54 gene_1360 gene_1361
#       600       600       600       600       600       600       600       600
# gene_1362 gene_1363 gene_1783 gene_1780 gene_1781 gene_1787 gene_1784 gene_1785
#       600       600       600       600       600       600       600       600
# gene_2284 gene_1788 gene_1789 gene_1412   gene_70   gene_73   gene_72   gene_75
#       600       600       600       600       600       600       600       600
# gene_1417   gene_77   gene_76   gene_79   gene_78 gene_1418  gene_284  gene_283
#       600       600       600       600       600       600       600       600
#  gene_282  gene_281  gene_280 gene_2703  gene_118  gene_117  gene_116  gene_115
#       600       600       600       600       600       600       600       600
#   gene_59 gene_1098 gene_1099 gene_1096 gene_1097 gene_1093 gene_2702 gene_2826
#       600       600       600       600       600       600       600       600
#  gene_736  gene_735  gene_734 gene_2822 gene_2282 gene_2820 gene_2821 gene_2041
#       600       600       600       600       600       600       600       600
# gene_2042 gene_2043  gene_739  gene_738 gene_2701  gene_602  gene_601  gene_600
#       600       600       600       600       600       600       600       600
#  gene_605  gene_604 gene_2700  gene_429 gene_2959 gene_2229 gene_2224 gene_2225
#       600       600       600       600       600       600       600       600
# gene_2226 gene_2227 gene_2220 gene_2221 gene_2222 gene_2223 gene_2807 gene_2706
#       600       600       600       600       600       600       600       600
# gene_2352 gene_2311 gene_2312 gene_2313 gene_2314 gene_2315 gene_2316 gene_2318
#       600       600       600       600       600       600       600       600
# gene_2319 gene_2353 gene_1957 gene_1956 gene_1955 gene_1953 gene_1951 gene_1950
#       600       600       600       600       600       600       600       600
# gene_1959 gene_1958 gene_2664 gene_2665 gene_2666 gene_2667 gene_2661 gene_2557
#       600       600       600       600       600       600       600       600
# gene_2554 gene_2555 gene_2552 gene_2553 gene_2551 gene_2558 gene_2559 gene_2106
#       600       600       600       600       600       600       600       600
#  gene_939  gene_938  gene_935  gene_937  gene_936  gene_931  gene_930  gene_932
#       600       600       600       600       600       600       600       600
#  gene_295 gene_2449 gene_2996 gene_2997 gene_2994 gene_1221 gene_1220 gene_1551
#       600       600       600       600       600       600       600       600
# gene_1222 gene_1225 gene_1224 gene_1227 gene_1554 gene_1229 gene_1228 gene_1559
#       600       600       600       600       600       600       600       600
# gene_1558 gene_2990 gene_2991 gene_1319 gene_1318 gene_1314 gene_1317 gene_1316
#       600       600       600       600       600       600       600       600
# gene_1311 gene_1313 gene_1312 gene_1427 gene_1426 gene_1137 gene_1424 gene_1423
#       600       600       600       600       600       600       600       600
# gene_1422 gene_1133 gene_1420   gene_66   gene_67   gene_64   gene_65 gene_1139
#       600       600       600       600       600       600       600       600
#   gene_63 gene_1429   gene_61  gene_122  gene_123  gene_120  gene_121  gene_126
#       600       600       600       600       600       600       600       600
#  gene_127  gene_124  gene_125  gene_128  gene_129 gene_2297 gene_2039 gene_2038
#       600       600       600       600       600       600       600       600
# gene_2035 gene_2034 gene_2037 gene_2036 gene_2031 gene_2033 gene_2032 gene_1048
#       600       600       600       600       600       600       600       600
# gene_1041 gene_1047  gene_386  gene_387  gene_385  gene_382  gene_383  gene_380
#       600       600       600       600       600       600       600       600
#  gene_381  gene_388  gene_637  gene_634  gene_635  gene_633  gene_630  gene_639
#       600       600       600       600       600       600       600       600
# gene_2782 gene_2781 gene_2780 gene_2787 gene_2786 gene_2785 gene_2784  gene_417
#       600       600       600       600       600       600       600       600
# gene_2789  gene_415 gene_2963  gene_413  gene_411 gene_2290 gene_2143 gene_2142
#       600       600       600       600       600       600       600       600
# gene_2147 gene_2146 gene_2148 gene_2611 gene_2610 gene_2613  gene_258  gene_259
#       600       600       600       600       600       600       600       600
# gene_2819 gene_2612 gene_3073  gene_702  gene_703  gene_700  gene_701 gene_2817
#       600       600       600       600       600       600       600       600
# gene_2816 gene_2815 gene_2614 gene_2616 gene_2365 gene_1949 gene_2367 gene_2366
#       600       600       600       600       600       600       600       600
# gene_2360 gene_2362 gene_1940 gene_1941 gene_1944 gene_2368 gene_1946 gene_2498
#       600       600       600       600       600       600       600       600
# gene_1113 gene_1111 gene_2569 gene_2568 gene_1115 gene_2563 gene_2562 gene_2561
#       600       600       600       600       600       600       600       600
# gene_2560 gene_2567 gene_2564 gene_1290 gene_1291 gene_2762 gene_2765 gene_1292
#       600       600       600       600       600       600       600       600
# gene_2767 gene_2766 gene_1293 gene_1294 gene_1295 gene_1296 gene_2995 gene_3004
#       600       600       600       600       600       600       600       600
#  gene_320  gene_321  gene_322 gene_2291  gene_325  gene_454 gene_2292 gene_2237
#       600       600       600       600       600       600       600       600
# gene_1232 gene_1233 gene_1546 gene_1547 gene_1540 gene_1541 gene_1234 gene_1543
#       600       600       600       600       600       600       600       600
# gene_1238 gene_1239 gene_1548 gene_1308 gene_1307 gene_1302 gene_1303 gene_1301
#       600       600       600       600       600       600       600       600
# gene_1438 gene_1439 gene_1430 gene_1431 gene_1432 gene_1434 gene_1435 gene_1436
#       600       600       600       600       600       600       600       600
# gene_1437 gene_1126 gene_1127 gene_1124 gene_1125 gene_1122 gene_1123 gene_1120
#       600       600       600       600       600       600       600       600
# gene_2445 gene_2446 gene_1128 gene_1129  gene_135  gene_134  gene_137  gene_136
#       600       600       600       600       600       600       600       600
#  gene_131  gene_130  gene_133  gene_132 gene_2440  gene_139  gene_138 gene_2441
#       600       600       600       600       600       600       600       600
# gene_2442 gene_2443 gene_2028 gene_2026 gene_2025 gene_2023  gene_399  gene_398
#       600       600       600       600       600       600       600       600
# gene_1052 gene_1053 gene_1050 gene_1051 gene_1057  gene_397 gene_1055  gene_629
#       600       600       600       600       600       600       600       600
#  gene_628  gene_620  gene_623  gene_622  gene_625  gene_624 gene_2682 gene_2794
#       600       600       600       600       600       600       600       600
#  gene_400 gene_2796 gene_2973 gene_2790 gene_2791  gene_407 gene_2793 gene_2978
#       600       600       600       600       600       600       600       600
# gene_2979 gene_2798 gene_2799 gene_2152 gene_2153 gene_2150 gene_2151 gene_2156
#       600       600       600       600       600       600       600       600
# gene_2154 gene_2158 gene_2159 gene_2808  gene_718 gene_2804 gene_2805  gene_717
#       600       600       600       600       600       600       600       600
#  gene_716 gene_2800 gene_2801 gene_2802  gene_712 gene_2488 gene_2489 gene_2885
#       600       600       600       600       600       600       600       600
# gene_2480 gene_2482 gene_2483 gene_2485 gene_2487 gene_2376 gene_2377 gene_2375
#       600       600       600       600       600       600       600       600
# gene_1939 gene_1938 gene_2370 gene_2371 gene_1934 gene_1937 gene_1931 gene_1930
#       600       600       600       600       600       600       600       600
# gene_1933 gene_1932 gene_2882 gene_2883 gene_2578 gene_2574 gene_2575 gene_2576
#       600       600       600       600       600       600       600       600
# gene_2577 gene_2570 gene_2571 gene_2573 gene_1841 gene_1840 gene_1843 gene_1842
#       600       600       600       600       600       600       600       600
# gene_1845 gene_1844 gene_1847 gene_1846 gene_2772 gene_2770 gene_2771 gene_2776
#       600       600       600       600       600       600       600       600
# gene_2777 gene_2774 gene_3008 gene_2905 gene_2904 gene_2868 gene_3003 gene_2869
#       600       600       600       600       600       600       600       600
# gene_2901 gene_2900 gene_2903 gene_2863 gene_2711 gene_2866 gene_2867 gene_2864
#       600       600       600       600       600       600       600       600
# gene_2865 gene_1207 gene_1206 gene_1205 gene_1204 gene_1203 gene_1202 gene_1200
#       600       600       600       600       600       600       600       600
# gene_1209 gene_1208 gene_1550 gene_1557 gene_1556 gene_1555 gene_1333 gene_1332
#       600       600       600       600       600       600       600       600
# gene_1331 gene_1330 gene_1337 gene_1336 gene_1335 gene_1334 gene_1339 gene_1338
#       600       600       600       600       600       600       600       600
# gene_1119 gene_1118 gene_1449 gene_1448 gene_1445 gene_1444 gene_1447 gene_1446
#       600       600       600       600       600       600       600       600
# gene_1117 gene_1440 gene_1443 gene_1442 gene_1689 gene_1688 gene_1683 gene_1682
#       600       600       600       600       600       600       600       600
# gene_1681 gene_1680 gene_1687 gene_1685 gene_1684 gene_2013 gene_2011 gene_2010
#       600       600       600       600       600       600       600       600
# gene_2015 gene_2014 gene_1062 gene_1061 gene_1060  gene_658  gene_659  gene_654
#       600       600       600       600       600       600       600       600
#  gene_655  gene_656  gene_657  gene_650  gene_651  gene_474  gene_475  gene_476
#       600       600       600       600       600       600       600       600
#  gene_477  gene_470  gene_471  gene_472  gene_473  gene_478  gene_479 gene_2167
#       600       600       600       600       600       600       600       600
# gene_2166 gene_2165 gene_2164 gene_2163 gene_2162 gene_2160 gene_2169 gene_2168
#       600       600       600       600       600       600       600       600
#  gene_278  gene_279  gene_276  gene_277  gene_272  gene_273  gene_270  gene_271
#       600       600       600       600       600       600       600       600
#                     POLR2AphosphoS2_MELcellline_mm9
#                                                6920
#                                   STAT1_HeLaS3_hg19
#                                                6920
#                                      MAX_HepG2_hg19
#                                                6920
#                                    CREB1_HepG2_hg19
#                                                6920
#                  CTCF_fibroblastofupperlegskin_hg19
#                                                6920
#                                    TRIM28_U2OS_hg19
#                                                6920
#                                JUND_MELcellline_mm9
#                                                6920
#                              EZH2_keratinocyte_hg19
#                                                6920
#                                     MYOD1_C2C12_mm9
#                                                6920
#                                   CEBPB_HeLaS3_hg19
#                                                6920
#                                   CREB1_H1hESC_hg19
#                                                6920
#                                     GABPA_K562_hg19
#                                                6920
#                                     CREB1_A549_hg19
#                                                6920
#                                 POLR2A_GM18505_hg19
#                                                6920
#                                       SRF_MCF7_hg19
#                                                6920
#                                   KDM5A_H1hESC_hg19
#                                                6920
#                                   SIX5_GM12878_hg19
#                                                6920
#                                      MYOG_C2C12_mm9
#                                                6920
#                                  BHLHE40_HepG2_hg19
#                                                6920
#                                    GATA1_G1EER4_mm9
#                                                6920
#                                      TAF7_K562_hg19
#                                                6920
#                                       GATA2_G1E_mm9
#                                                6920
#                                     RFX5_IMR90_hg19
#                                                6920
#                                   RFX5_GM12878_hg19
#                                                6920
#                              CTCF_keratinocyte_hg19
#                                                6920
#                              FLI1_megakaryocyte_mm9
#                                                6920
#                                   HDAC6_H1hESC_hg19
#                                                6920
#                                     MAX_H1hESC_hg19
#                                                6920
#                                      E2F6_K562_hg19
#                                                6920
#                          POLR2AphosphoS5_SKNMC_hg19
#                                                6920
#                                     TAL1_G1EER4_mm9
#                                                6920
#                                     NR4A1_K562_hg19
#                                                6920
#                                    FOXA1_HepG2_hg19
#                                                6920
#                                     STAT1_K562_hg19
#                                                6920
#                          POLR2AphosphoS5_Panc1_hg19
#                                                6920
#                                     ELF1_SKNSH_hg19
#                                                6920
#                                 CTCF_astrocyte_hg19
#                                                6920
# ...
#                                                6920
#                                   CTCF_GM12875_hg19
#                                                6920
#                                   TBL1XR1_K562_hg19
#                                                6920
#                                 SMARCC1_HeLaS3_hg19
#                                                6920
#                                  STAT1_GM12878_hg19
#                                                6920
#                                    RAD21_IMR90_hg19
#                                                6920
#                                    JUND_K562_hg19.1
#                                                6920
#                                    POLR3A_K562_hg19
#                                                6920
#                                      SIX5_K562_hg19
#                                                6920
#                                  CTCF_pancreas_hg19
#                                                6920
#                                    HAE2F1_MCF7_hg19
#                                                6920
#                        POLR2AphosphoS5_GM12891_hg19
#                                                6920
#                                   CHD1_GM12878_hg19
#                                                6920
#                                     NR2F2_K562_hg19
#                                                6920
#                                     JUN_HeLaS3_hg19
#                                                6920
#                                  FOXM1_GM12878_hg19
#                                                6920
#                                      USF1_C2C12_mm9
#                                                6920
#                                   RELA_GM18505_hg19
#                                                6920
#                                     MBD4_HepG2_hg19
#                                                6920
#                                      SIX5_A549_hg19
#                                                6920
#                                   EP300_CH12.LX_mm9
#                                                6920
#                                    RAD21_HepG2_hg19
#                                                6920
#                 CTCF_epithelialcellofesophagus_hg19
#                                                6920
#                                     GTF2B_K562_hg19
#                                                6920
#                                      MAFK_ESE14_mm9
#                                                6920
#                                   RELA_GM15510_hg19
#                                                6920
#                                    SIX5_H1hESC_hg19
#                                                6920
#                                 POLR2A_GM15510_hg19
#                                                6920
#                                   MXI1_GM12878_hg19
#                                                6920
#                                    IRF3_HeLaS3_hg19
#                                                6920
#                                 CTCF_cerebellum_mm9
#                                                6920
#                                    STAT5A_K562_hg19
#                                                6920
#                             CTCF_smallintestine_mm9
#                                                6920
#                                    RCOR1_HepG2_hg19
#                                                6920
#                                     MAX_myocyte_mm9
#                                                6920
#                                     ZEB1_HepG2_hg19
#                                                6920
#                                     CEBPB_C2C12_mm9
#                                                6920
#                                    MAFK_HeLaS3_hg19
#                                                6920
#                                     MYC_CH12.LX_mm9
#                                                6920
#                                    E2F4_myocyte_mm9
#                                                6920
#                                        MAX_NB4_hg19
#                                                6920
#                                   NFIC_GM12878_hg19
#                                                6920
#                                   ETS1_GM12878_hg19
#                                                6920
#                       CTCF_fibroblastofgingiva_hg19
#                                                6920
#                                     CCNT2_K562_hg19
#                                                6920
#                                        TAL1_G1E_mm9
#                                                6920
#                                   RELA_GM18526_hg19
#                                                6920
# POLR2AphosphoS5_endothelialcellofumbilicalvein_hg19
#                                                6920
#                                      ELF1_A549_hg19
#                                                6920
#                                     MEF2A_K562_hg19
#                                                6920
#                                     YY1_H1hESC_hg19
#                                                6920
#                                   RELA_GM12878_hg19
#                                                6920
#                                    E2F6_HeLaS3_hg19
#                                                6920
#                                 ZNF143_GM12878_hg19
#                                                6920
#                                      NFE2_K562_hg19
#                                                6920
#                                   RCOR1_HeLaS3_hg19
#                                                6920
#                                    TEAD4_SKNSH_hg19
#                                                6920
#                                     CTCF_spleen_mm9
#                                                6920
#                                   MAFK_GM12878_hg19
#                                                6920
#                                 STAT5A_GM12878_hg19
#                                                6920
#                                       PML_MCF7_hg19
#                                                6920
#                                   CTCF_GM19240_hg19
#                                                6920
#                                       MAX_C2C12_mm9
#                                                6920
#                                     JUN_CH12.LX_mm9
#                                                6920
#                                   TCF3_GM12878_hg19
#                                                6920
#                                CTCF_osteoblast_hg19
#                                                6920
#                                   TCF12_myocyte_mm9
#                                                6920
#                                  POLR2A_CH12.LX_mm9
#                                                6920
#                                    BCLAF1_K562_hg19
#                                                6920
#                                    FOS_GM12878_hg19
#                                                6920
#                                 BHLHE40_CH12.LX_mm9
#                                                6920
#                            CTCF_skinfibroblast_hg19
#                                                6920
#                                     BACH1_K562_hg19
#                                                6920
#                                   FOSL1_H1hESC_hg19
#                                                6920
#                                     NR2C2_K562_hg19
#                                                6920
#                                     JUN_H1hESC_hg19
#                                                6920
#                                     USF1_HepG2_hg19
#                                                6920
#                                       CTCF_lung_mm9
#                                                6920
#                                     CEBPB_ECC1_hg19
#                                                6920
#                                   CEBPB_HCT116_hg19
#                                                6920
#                                    NRF1_HeLaS3_hg19
#                                                6920
#                                    ZZZ3_HeLaS3_hg19
#                                                6920
#           CTCF_fibroblastoftheaorticadventitia_hg19
#                                                6920
#                                  NR2C2_GM12878_hg19
#                                                6920
#                                    BRCA1_HepG2_hg19
#                                                6920
#                                    HDAC2_HepG2_hg19
#                                                6920
#                                    GABPA_HepG2_hg19
#                                                6920
#                                      ETS1_A549_hg19
#                                                6920
#                                      JUND_MCF7_hg19
#                                                6920
#                                      SMC3_K562_hg19
#                                                6920
#                                    TCF7L2_MCF7_hg19
#                                                6920
#                                    MAX_GM12878_hg19
#                                                6920
#                               KAT2A_MELcellline_mm9
#                                                6920
#                                    ZBTB33_K562_hg19
#                                                6920
#                                     SRF_H1hESC_hg19
#                                                6920
#                                     SUZ12_K562_hg19
#                                                6920
#                                      JUND_A549_hg19
#                                                6920
#                                      CHD2_K562_hg19
#                                                6920
#                                 SMARCC2_HeLaS3_hg19
#                                                6920
#                                    MXI1_H1hESC_hg19
#                                                6920
#                                E2F4_MELcellline_mm9
#                                                6920
#                                      JUND_T47D_hg19
#                                                6920
#                                   TAF1_GM12878_hg19
#                                                6920
#                           POLR2AphosphoS5_HL60_hg19
#                                                6920
#                                     HDAC2_MCF7_hg19
#                                                6920
#                                     RXRA_HepG2_hg19
#                                                6920
#                                        MYC_NB4_hg19
#                                                6920
#                                    REST_myocyte_mm9
#                                                6920
#                                     EP300_A549_hg19
#                                                6920
#                                   POLR2A_kidney_mm9
#                                                6920
#                                      BCL3_A549_hg19
#                                                6920
#                                       SRF_K562_hg19
#                                                6920
#                                   SAP30_H1hESC_hg19
#                                                6920
#                                     RAD21_ECC1_hg19
#                                                6920
#                                  CREB1_GM12878_hg19
#                                                6920
#                                     SRF_HCT116_hg19
#                                                6920
#                                    SMC3_HeLaS3_hg19
#                                                6920
#                                     POLR2A_NB4_hg19
#                                                6920
#                                    MAFK_CH12.LX_mm9
#                                                6920
#                                    E2F1_HeLaS3_hg19
#                                                6920
#                             ZKSCAN1_MELcellline_mm9
#                                                6920
#                                      USF2_K562_hg19
#                                                6920
#                                    ZNF384_K562_hg19
#                                                6920
#                                 SMARCB1_HeLaS3_hg19
#                                                6920
#                                   CTCF_GM06990_hg19
#                                                6920
#                                   KAT2A_CH12.LX_mm9
#                                                6920
#                                   MTA3_GM12878_hg19
#                                                6920
#                                    ESRRA_HepG2_hg19
#                                                6920
#                                  HAE2F1_HeLaS3_hg19
#                                                6920
#                                   E2F4_GM12878_hg19
#                                                6920
#                                  TFAP2A_HeLaS3_hg19
#                                                6920
#                                     MAFF_HepG2_hg19
#                                                6920
#                                  ZNF263_HEK293_hg19
#                                                6920
#                                     HMGN3_K562_hg19
#                                                6920
#                                   CTCF_GM12865_hg19
#                                                6920
#                                       SP2_K562_hg19
#                                                6920
#                                     TAF1_HepG2_hg19
#                                                6920
#                                     GABPA_HL60_hg19
#                                                6920
#                                 MAX_MELcellline_mm9
#                                                6920
#                                   KDM4A_H1hESC_hg19
#                                                6920
#                                  GTF2F1_H1hESC_hg19
#                                                6920
#                                   CTCF_GM12874_hg19
#                                                6920
#                                   GABPA_HeLaS3_hg19
#                                                6920
#                                   ZZZ3_GM12878_hg19
#                                                6920
#                         POLR2AphosphoS2_CH12.LX_mm9
#                                                6920
#                                     SRF_myocyte_mm9
#                                                6920
#                                 ZBTB33_GM12878_hg19
#                                                6920
#                                   CTCF_GM13977_hg19
#                                                6920
#                                 SUPT20H_HeLaS3_hg19
#                                                6920
#                                BHLHE40_GM12878_hg19
#                                                6920
#                                     TAF1_PFSK1_hg19
#                                                6920

# %%
# List of overlap comparisons. Ufahhhh...

for (i in gobject) {
  b <- paste(sprintf('%s,%s,genome.size=20805),',gobject$A,gobject$B))
  print(b)
  write.table(b, "enc15vs16freeOverlapMap2.csv", quote=FALSE, row.names=F, col.names=FALSE, sep="\t")
  }
# Out:
#   [1] "go.obj <- newGeneOverlap(encodeA$gene_2034,encodeB$TRIM28_U2OS,genome.size=20805),"
#   [2] "go.obj <- newGeneOverlap(encodeA$gene_2034,encodeB$TRIM28_HEK293,genome.size=20805),"
#   [3] "go.obj <- newGeneOverlap(encodeA$gene_2034,encodeB$TRIM28_K562,genome.size=20805),"
#   [4] "go.obj <- newGeneOverlap(encodeA$gene_2033,encodeB$TRIM28_U2OS,genome.size=20805),"
#   [5] "go.obj <- newGeneOverlap(encodeA$gene_2033,encodeB$TRIM28_HEK293,genome.size=20805),"
#   [6] "go.obj <- newGeneOverlap(encodeA$gene_2033,encodeB$TRIM28_K562,genome.size=20805),"
#   [7] "go.obj <- newGeneOverlap(encodeA$gene_2032,encodeB$TRIM28_U2OS,genome.size=20805),"
#   [8] "go.obj <- newGeneOverlap(encodeA$gene_2032,encodeB$TRIM28_HEK293,genome.size=20805),"
#   [9] "go.obj <- newGeneOverlap(encodeA$gene_2032,encodeB$TRIM28_K562,genome.size=20805),"
#  [10] "go.obj <- newGeneOverlap(encodeA$gene_2430,encodeB$ESR1_T47D,genome.size=20805),"
#  [11] "go.obj <- newGeneOverlap(encodeA$gene_2430,encodeB$ESR1_ECC1,genome.size=20805),"
#  [12] "go.obj <- newGeneOverlap(encodeA$gene_2898,encodeB$ESR1_T47D,genome.size=20805),"
#  [13] "go.obj <- newGeneOverlap(encodeA$gene_2898,encodeB$ESR1_ECC1,genome.size=20805),"
#  [14] "go.obj <- newGeneOverlap(encodeA$gene_2714,encodeB$NR2C2_HepG2,genome.size=20805),"
#  [15] "go.obj <- newGeneOverlap(encodeA$gene_2714,encodeB$NR2C2_HeLaS3,genome.size=20805),"
#  [16] "go.obj <- newGeneOverlap(encodeA$gene_2714,encodeB$NR2C2_K562,genome.size=20805),"
#  [17] "go.obj <- newGeneOverlap(encodeA$gene_2714,encodeB$NR2C2_GM12878,genome.size=20805),"
#  [18] "go.obj <- newGeneOverlap(encodeA$gene_2200,encodeB$NR2C2_HepG2,genome.size=20805),"
#  [19] "go.obj <- newGeneOverlap(encodeA$gene_2200,encodeB$NR2C2_HeLaS3,genome.size=20805),"
#  [20] "go.obj <- newGeneOverlap(encodeA$gene_2200,encodeB$NR2C2_K562,genome.size=20805),"
#  [21] "go.obj <- newGeneOverlap(encodeA$gene_2200,encodeB$NR2C2_GM12878,genome.size=20805),"
#  [22] "go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_MCF7,genome.size=20805),"
#  [23] "go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_HepG2,genome.size=20805),"
#  [24] "go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_ECC1,genome.size=20805),"
#  [25] "go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_GM12878,genome.size=20805),"
#  [26] "go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_H1hESC,genome.size=20805),"
#  [27] "go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_K562,genome.size=20805),"
#  [28] "go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_HCT116,genome.size=20805),"
#  [29] "go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_myocyte,genome.size=20805),"
#  [30] "go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_MCF7,genome.size=20805),"
#  [31] "go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_HepG2,genome.size=20805),"
#  [32] "go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_ECC1,genome.size=20805),"
#  [33] "go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_GM12878,genome.size=20805),"
#  [34] "go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_H1hESC,genome.size=20805),"
#  [35] "go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_K562,genome.size=20805),"
#  [36] "go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_HCT116,genome.size=20805),"
#  [37] "go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_myocyte,genome.size=20805),"
#  [38] "go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_MCF7,genome.size=20805),"
#  [39] "go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_HepG2,genome.size=20805),"
#  [40] "go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_ECC1,genome.size=20805),"
#  [41] "go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_GM12878,genome.size=20805),"
#  [42] "go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_H1hESC,genome.size=20805),"
#  [43] "go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_K562,genome.size=20805),"
#  [44] "go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_HCT116,genome.size=20805),"
#  [45] "go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_myocyte,genome.size=20805),"
#  [46] "go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_MCF7,genome.size=20805),"
#  [47] "go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_HepG2,genome.size=20805),"
#  [48] "go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_ECC1,genome.size=20805),"
#  [49] "go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_GM12878,genome.size=20805),"
#  [50] "go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_H1hESC,genome.size=20805),"
#  [51] "go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_K562,genome.size=20805),"
#  [52] "go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_HCT116,genome.size=20805),"
#  [53] "go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_myocyte,genome.size=20805),"
#  [54] "go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_MCF7,genome.size=20805),"
#  [55] "go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_HepG2,genome.size=20805),"
#  [56] "go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_ECC1,genome.size=20805),"
#  [57] "go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_GM12878,genome.size=20805),"
#  [58] "go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_H1hESC,genome.size=20805),"
#  [59] "go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_K562,genome.size=20805),"
#  [60] "go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_HCT116,genome.size=20805),"
#  [61] "go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_myocyte,genome.size=20805),"
#  [62] "go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_MCF7,genome.size=20805),"
#  [63] "go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_HepG2,genome.size=20805),"
#  [64] "go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_ECC1,genome.size=20805),"
#  [65] "go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_GM12878,genome.size=20805),"
#  [66] "go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_H1hESC,genome.size=20805),"
#  [67] "go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_K562,genome.size=20805),"
#  [68] "go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_HCT116,genome.size=20805),"
#  [69] "go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_myocyte,genome.size=20805),"
#  [70] "go.obj <- newGeneOverlap(encodeA$gene_195,encodeB$HNF4A_HepG2,genome.size=20805),"
#  [71] "go.obj <- newGeneOverlap(encodeA$gene_200,encodeB$HNF4A_HepG2,genome.size=20805),"
#  [72] "go.obj <- newGeneOverlap(encodeA$gene_2360,encodeB$HNF4A_HepG2,genome.size=20805),"
#  [73] "go.obj <- newGeneOverlap(encodeA$gene_1490,encodeB$TFAP2C_HeLaS3,genome.size=20805),"
#  [74] "go.obj <- newGeneOverlap(encodeA$gene_537,encodeB$PML_K562,genome.size=20805),"
#  [75] "go.obj <- newGeneOverlap(encodeA$gene_537,encodeB$PML_GM12878,genome.size=20805),"
#  [76] "go.obj <- newGeneOverlap(encodeA$gene_537,encodeB$PML_MCF7,genome.size=20805),"
#  [77] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_keratinocyte,genome.size=20805),"
#  [78] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_astrocyte,genome.size=20805),"
#  [79] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_mammaryepithelialcell,genome.size=20805),"
#  [80] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_myotube,genome.size=20805),"
#  [81] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_K562,genome.size=20805),"
#  [82] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_Tcellacutelymphoblasticleukemia,genome.size=20805),"
#  [83] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_skeletalmusclemyoblast,genome.size=20805),"
#  [84] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_fibroblastofdermis,genome.size=20805),"
#  [85] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_fibroblastoflung,genome.size=20805),"
#  [86] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_endothelialcellofumbilicalvein,genome.size=20805),"
#  [87] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_H1hESC,genome.size=20805),"
#  [88] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_HepG2,genome.size=20805),"
#  [89] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_GM12878,genome.size=20805),"
#  [90] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_HeLaS3,genome.size=20805),"
#  [91] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_Bcell,genome.size=20805),"
#  [92] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_keratinocyte,genome.size=20805),"
#  [93] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_astrocyte,genome.size=20805),"
#  [94] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_mammaryepithelialcell,genome.size=20805),"
#  [95] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_myotube,genome.size=20805),"
#  [96] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_K562,genome.size=20805),"
#  [97] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_Tcellacutelymphoblasticleukemia,genome.size=20805),"
#  [98] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_skeletalmusclemyoblast,genome.size=20805),"
#  [99] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_fibroblastofdermis,genome.size=20805),"
# [100] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_fibroblastoflung,genome.size=20805),"
# [101] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_endothelialcellofumbilicalvein,genome.size=20805),"
# [102] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_H1hESC,genome.size=20805),"
# [103] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_HepG2,genome.size=20805),"
# [104] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_GM12878,genome.size=20805),"
# [105] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_HeLaS3,genome.size=20805),"
# [106] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_Bcell,genome.size=20805),"
# [107] "go.obj <- newGeneOverlap(encodeA$gene_31,encodeB$SETDB1_K562,genome.size=20805),"
# [108] "go.obj <- newGeneOverlap(encodeA$gene_31,encodeB$SETDB1_U2OS,genome.size=20805),"
# [109] "go.obj <- newGeneOverlap(encodeA$gene_2205,encodeB$SETDB1_K562,genome.size=20805),"
# [110] "go.obj <- newGeneOverlap(encodeA$gene_2205,encodeB$SETDB1_U2OS,genome.size=20805),"
# [111] "go.obj <- newGeneOverlap(encodeA$gene_2412,encodeB$NR2F2_MCF7,genome.size=20805),"
# [112] "go.obj <- newGeneOverlap(encodeA$gene_2412,encodeB$NR2F2_HepG2,genome.size=20805),"
# [113] "go.obj <- newGeneOverlap(encodeA$gene_2412,encodeB$NR2F2_K562,genome.size=20805),"
# [114] "go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_GM12878,genome.size=20805),"
# [115] "go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_ECC1,genome.size=20805),"
# [116] "go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_K562,genome.size=20805),"
# [117] "go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_MCF7,genome.size=20805),"
# [118] "go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_HCT116,genome.size=20805),"
# [119] "go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_H1hESC,genome.size=20805),"
# [120] "go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_GM12878,genome.size=20805),"
# [121] "go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_ECC1,genome.size=20805),"
# [122] "go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_K562,genome.size=20805),"
# [123] "go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_MCF7,genome.size=20805),"
# [124] "go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_HCT116,genome.size=20805),"
# [125] "go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_H1hESC,genome.size=20805),"
# [126] "go.obj <- newGeneOverlap(encodeA$gene_559,encodeB$HDAC6_H1hESC,genome.size=20805),"
# [127] "go.obj <- newGeneOverlap(encodeA$gene_559,encodeB$HDAC6_K562,genome.size=20805),"
# [128] "go.obj <- newGeneOverlap(encodeA$gene_399,encodeB$HDAC6_H1hESC,genome.size=20805),"
# [129] "go.obj <- newGeneOverlap(encodeA$gene_399,encodeB$HDAC6_K562,genome.size=20805),"
# [130] "go.obj <- newGeneOverlap(encodeA$gene_2476,encodeB$STAT1_HeLaS3,genome.size=20805),"
# [131] "go.obj <- newGeneOverlap(encodeA$gene_2476,encodeB$STAT1_K562,genome.size=20805),"
# [132] "go.obj <- newGeneOverlap(encodeA$gene_2476,encodeB$STAT1_GM12878,genome.size=20805),"
# [133] "go.obj <- newGeneOverlap(encodeA$gene_1529,encodeB$STAT1_HeLaS3,genome.size=20805),"
# [134] "go.obj <- newGeneOverlap(encodeA$gene_1529,encodeB$STAT1_K562,genome.size=20805),"
# [135] "go.obj <- newGeneOverlap(encodeA$gene_1529,encodeB$STAT1_GM12878,genome.size=20805),"
# [136] "go.obj <- newGeneOverlap(encodeA$gene_1519,encodeB$STAT1_HeLaS3,genome.size=20805),"
# [137] "go.obj <- newGeneOverlap(encodeA$gene_1519,encodeB$STAT1_K562,genome.size=20805),"
# [138] "go.obj <- newGeneOverlap(encodeA$gene_1519,encodeB$STAT1_GM12878,genome.size=20805),"
# [139] "go.obj <- newGeneOverlap(encodeA$gene_2479,encodeB$STAT3_HeLaS3,genome.size=20805),"
# [140] "go.obj <- newGeneOverlap(encodeA$gene_2479,encodeB$STAT3_GM12878,genome.size=20805),"
# [141] "go.obj <- newGeneOverlap(encodeA$gene_2479,encodeB$STAT3_MCF10A,genome.size=20805),"
# [142] "go.obj <- newGeneOverlap(encodeA$gene_1522,encodeB$BATF_GM12878,genome.size=20805),"
# [143] "go.obj <- newGeneOverlap(encodeA$gene_1523,encodeB$BATF_GM12878,genome.size=20805),"
# [144] "go.obj <- newGeneOverlap(encodeA$gene_1527,encodeB$IRF4_GM12878,genome.size=20805),"
# [145] "go.obj <- newGeneOverlap(encodeA$gene_2774,encodeB$IRF4_GM12878,genome.size=20805),"
# [146] "go.obj <- newGeneOverlap(encodeA$gene_94,encodeB$HDAC1_K562,genome.size=20805),"
# [147] "go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_K562,genome.size=20805),"
# [148] "go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_HepG2,genome.size=20805),"
# [149] "go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_endothelialcellofumbilicalvein,genome.size=20805),"
# [150] "go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_HeLaS3,genome.size=20805),"
# [151] "go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_CH12.LX,genome.size=20805),"
# [152] "go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_H1hESC,genome.size=20805),"
# [153] "go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_K562,genome.size=20805),"
# [154] "go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_HepG2,genome.size=20805),"
# [155] "go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_endothelialcellofumbilicalvein,genome.size=20805),"
# [156] "go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_HeLaS3,genome.size=20805),"
# [157] "go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_CH12.LX,genome.size=20805),"
# [158] "go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_H1hESC,genome.size=20805),"
# [159] "go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_K562,genome.size=20805),"
# [160] "go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_HepG2,genome.size=20805),"
# [161] "go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_endothelialcellofumbilicalvein,genome.size=20805),"
# [162] "go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_HeLaS3,genome.size=20805),"
# [163] "go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_CH12.LX,genome.size=20805),"
# [164] "go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_H1hESC,genome.size=20805),"
# [165] "go.obj <- newGeneOverlap(encodeA$gene_1765,encodeB$RNF2_K562,genome.size=20805),"
# [166] "go.obj <- newGeneOverlap(encodeA$gene_1162,encodeB$GATA3_MCF7,genome.size=20805),"
# [167] "go.obj <- newGeneOverlap(encodeA$gene_1162,encodeB$GATA3_T47D,genome.size=20805),"
# [168] "go.obj <- newGeneOverlap(encodeA$gene_1162,encodeB$GATA3_SHSY5Y,genome.size=20805),"
# [169] "go.obj <- newGeneOverlap(encodeA$gene_1162,encodeB$GATA3_A549,genome.size=20805),"
# [170] "go.obj <- newGeneOverlap(encodeA$gene_1162,encodeB$GATA3_SKNSH,genome.size=20805),"
# [171] "go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_CH12.LX,genome.size=20805),"
# [172] "go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_HeLaS3,genome.size=20805),"
# [173] "go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_K562,genome.size=20805),"
# [174] "go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_MCF10A,genome.size=20805),"
# [175] "go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_myocyte,genome.size=20805),"
# [176] "go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_MELcellline,genome.size=20805),"
# [177] "go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_GM12878,genome.size=20805),"
# [178] "go.obj <- newGeneOverlap(encodeA$gene_2844,encodeB$HDAC2_H1hESC,genome.size=20805),"
# [179] "go.obj <- newGeneOverlap(encodeA$gene_2844,encodeB$HDAC2_K562,genome.size=20805),"
# [180] "go.obj <- newGeneOverlap(encodeA$gene_2844,encodeB$HDAC2_HepG2,genome.size=20805),"
# [181] "go.obj <- newGeneOverlap(encodeA$gene_2844,encodeB$HDAC2_MCF7,genome.size=20805),"
# [182] "go.obj <- newGeneOverlap(encodeA$gene_2197,encodeB$MYB_MELcellline,genome.size=20805),"
# [183] "go.obj <- newGeneOverlap(encodeA$gene_2380,encodeB$ZBTB7A_HepG2,genome.size=20805),"
# [184] "go.obj <- newGeneOverlap(encodeA$gene_2380,encodeB$ZBTB7A_ECC1,genome.size=20805),"
# [185] "go.obj <- newGeneOverlap(encodeA$gene_2380,encodeB$ZBTB7A_K562,genome.size=20805),"
# [186] "go.obj <- newGeneOverlap(encodeA$gene_430,encodeB$FOSL1_HCT116,genome.size=20805),"
# [187] "go.obj <- newGeneOverlap(encodeA$gene_430,encodeB$FOSL1_C2C12,genome.size=20805),"
# [188] "go.obj <- newGeneOverlap(encodeA$gene_430,encodeB$FOSL1_K562,genome.size=20805),"
# [189] "go.obj <- newGeneOverlap(encodeA$gene_430,encodeB$FOSL1_H1hESC,genome.size=20805),"
# [190] "go.obj <- newGeneOverlap(encodeA$gene_429,encodeB$FOSL1_HCT116,genome.size=20805),"
# [191] "go.obj <- newGeneOverlap(encodeA$gene_429,encodeB$FOSL1_C2C12,genome.size=20805),"
# [192] "go.obj <- newGeneOverlap(encodeA$gene_429,encodeB$FOSL1_K562,genome.size=20805),"
# [193] "go.obj <- newGeneOverlap(encodeA$gene_429,encodeB$FOSL1_H1hESC,genome.size=20805),"
# [194] "go.obj <- newGeneOverlap(encodeA$gene_3014,encodeB$NR3C1_HepG2,genome.size=20805),"
# [195] "go.obj <- newGeneOverlap(encodeA$gene_3014,encodeB$NR3C1_A549,genome.size=20805),"
# [196] "go.obj <- newGeneOverlap(encodeA$gene_3014,encodeB$NR3C1_ECC1,genome.size=20805),"
# [197] "go.obj <- newGeneOverlap(encodeA$gene_2544,encodeB$ATF2_H1hESC,genome.size=20805),"
# [198] "go.obj <- newGeneOverlap(encodeA$gene_2544,encodeB$ATF2_GM12878,genome.size=20805),"
# [199] "go.obj <- newGeneOverlap(encodeA$gene_2547,encodeB$IKZF1_GM12878,genome.size=20805),"
# [200] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_ECC1,genome.size=20805),"
# [201] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_HCT116,genome.size=20805),"
# [202] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_K562,genome.size=20805),"
# [203] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_SKNSH,genome.size=20805),"
# [204] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_HepG2,genome.size=20805),"
# [205] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_GM12878,genome.size=20805),"
# [206] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_NT2D1,genome.size=20805),"
# [207] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_GM12892,genome.size=20805),"
# [208] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_GM12891,genome.size=20805),"
# [209] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_A549,genome.size=20805),"
# [210] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_H1hESC,genome.size=20805),"
# [211] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_MELcellline,genome.size=20805),"
# [212] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_K562,genome.size=20805),"
# [213] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_endothelialcellofumbilicalvein,genome.size=20805),"
# [214] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_H1hESC,genome.size=20805),"
# [215] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_MCF7,genome.size=20805),"
# [216] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_A549,genome.size=20805),"
# [217] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_HeLaS3,genome.size=20805),"
# [218] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_GM12878,genome.size=20805),"
# [219] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_MCF10A,genome.size=20805),"
# [220] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_HepG2,genome.size=20805),"
# [221] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_CH12.LX,genome.size=20805),"
# [222] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_NB4,genome.size=20805),"
# [223] "go.obj <- newGeneOverlap(encodeA$gene_380,encodeB$CBX2_K562,genome.size=20805),"
# [224] "go.obj <- newGeneOverlap(encodeA$gene_381,encodeB$CBX2_K562,genome.size=20805),"
# [225] "go.obj <- newGeneOverlap(encodeA$gene_2143,encodeB$HSF1_HepG2,genome.size=20805),"
# [226] "go.obj <- newGeneOverlap(encodeA$gene_2613,encodeB$ESRRA_GM12878,genome.size=20805),"
# [227] "go.obj <- newGeneOverlap(encodeA$gene_2613,encodeB$ESRRA_HepG2,genome.size=20805),"
# [228] "go.obj <- newGeneOverlap(encodeA$gene_2159,encodeB$ESRRA_GM12878,genome.size=20805),"
# [229] "go.obj <- newGeneOverlap(encodeA$gene_2159,encodeB$ESRRA_HepG2,genome.size=20805),"
# [230] "go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_K562,genome.size=20805),"
# [231] "go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_GM12878,genome.size=20805),"
# [232] "go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_HepG2,genome.size=20805),"
# [233] "go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_H1hESC,genome.size=20805),"
# [234] "go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_SKNSH,genome.size=20805),"
# [235] "go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_HeLaS3,genome.size=20805),"
# [236] "go.obj <- newGeneOverlap(encodeA$gene_1332,encodeB$SUZ12_H1hESC,genome.size=20805),"
# [237] "go.obj <- newGeneOverlap(encodeA$gene_1332,encodeB$SUZ12_NT2D1,genome.size=20805),"
# [238] "go.obj <- newGeneOverlap(encodeA$gene_1332,encodeB$SUZ12_K562,genome.size=20805),"
# [239] "go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_G1EER4,genome.size=20805),"
# [240] "go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_erythroblast,genome.size=20805),"
# [241] "go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_MELcellline,genome.size=20805),"
# [242] "go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_megakaryocyte,genome.size=20805),"
# [243] "go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_K562,genome.size=20805),"
# [244] "go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_G1E,genome.size=20805),"
# [245] "go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_G1EER4,genome.size=20805),"
# [246] "go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_MELcellline,genome.size=20805),"
# [247] "go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_erythroblast,genome.size=20805),"
# [248] "go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_megakaryocyte,genome.size=20805),"
# [249] "go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_erythroblast,genome.size=20805),"
# [250] "go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_K562,genome.size=20805),"
# [251] "go.obj <- newGeneOverlap(encodeA$gene_2167,encodeB$TCF3_myocyte,genome.size=20805),"
# [252] "go.obj <- newGeneOverlap(encodeA$gene_2167,encodeB$TCF3_GM12878,genome.size=20805),"
# [253] "go.obj <- newGeneOverlap(encodeA$gene_2169,encodeB$TCF3_myocyte,genome.size=20805),"
# [254] "go.obj <- newGeneOverlap(encodeA$gene_2169,encodeB$TCF3_GM12878,genome.size=20805),"
# [255] "go.obj <- newGeneOverlap(encodeA$gene_2166,encodeB$FOXA2_HepG2,genome.size=20805),"
# [256] "go.obj <- newGeneOverlap(encodeA$gene_2166,encodeB$FOXA2_A549,genome.size=20805),"
# [257] "go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_H1hESC,genome.size=20805),"
# [258] "go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_MCF7,genome.size=20805),"
# [259] "go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_SKNSH,genome.size=20805),"
# [260] "go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_ECC1,genome.size=20805),"
# [261] "go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_A549,genome.size=20805),"
# [262] "go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_GM12878,genome.size=20805),"
# [263] "go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_myocyte,genome.size=20805),"
#   [1] "go.obj <- newGeneOverlap(encodeA$gene_2034,encodeB$TRIM28_U2OS,genome.size=20805),"
#   [2] "go.obj <- newGeneOverlap(encodeA$gene_2034,encodeB$TRIM28_HEK293,genome.size=20805),"
#   [3] "go.obj <- newGeneOverlap(encodeA$gene_2034,encodeB$TRIM28_K562,genome.size=20805),"
#   [4] "go.obj <- newGeneOverlap(encodeA$gene_2033,encodeB$TRIM28_U2OS,genome.size=20805),"
#   [5] "go.obj <- newGeneOverlap(encodeA$gene_2033,encodeB$TRIM28_HEK293,genome.size=20805),"
#   [6] "go.obj <- newGeneOverlap(encodeA$gene_2033,encodeB$TRIM28_K562,genome.size=20805),"
#   [7] "go.obj <- newGeneOverlap(encodeA$gene_2032,encodeB$TRIM28_U2OS,genome.size=20805),"
#   [8] "go.obj <- newGeneOverlap(encodeA$gene_2032,encodeB$TRIM28_HEK293,genome.size=20805),"
#   [9] "go.obj <- newGeneOverlap(encodeA$gene_2032,encodeB$TRIM28_K562,genome.size=20805),"
#  [10] "go.obj <- newGeneOverlap(encodeA$gene_2430,encodeB$ESR1_T47D,genome.size=20805),"
#  [11] "go.obj <- newGeneOverlap(encodeA$gene_2430,encodeB$ESR1_ECC1,genome.size=20805),"
#  [12] "go.obj <- newGeneOverlap(encodeA$gene_2898,encodeB$ESR1_T47D,genome.size=20805),"
#  [13] "go.obj <- newGeneOverlap(encodeA$gene_2898,encodeB$ESR1_ECC1,genome.size=20805),"
#  [14] "go.obj <- newGeneOverlap(encodeA$gene_2714,encodeB$NR2C2_HepG2,genome.size=20805),"
#  [15] "go.obj <- newGeneOverlap(encodeA$gene_2714,encodeB$NR2C2_HeLaS3,genome.size=20805),"
#  [16] "go.obj <- newGeneOverlap(encodeA$gene_2714,encodeB$NR2C2_K562,genome.size=20805),"
#  [17] "go.obj <- newGeneOverlap(encodeA$gene_2714,encodeB$NR2C2_GM12878,genome.size=20805),"
#  [18] "go.obj <- newGeneOverlap(encodeA$gene_2200,encodeB$NR2C2_HepG2,genome.size=20805),"
#  [19] "go.obj <- newGeneOverlap(encodeA$gene_2200,encodeB$NR2C2_HeLaS3,genome.size=20805),"
#  [20] "go.obj <- newGeneOverlap(encodeA$gene_2200,encodeB$NR2C2_K562,genome.size=20805),"
#  [21] "go.obj <- newGeneOverlap(encodeA$gene_2200,encodeB$NR2C2_GM12878,genome.size=20805),"
#  [22] "go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_MCF7,genome.size=20805),"
#  [23] "go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_HepG2,genome.size=20805),"
#  [24] "go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_ECC1,genome.size=20805),"
#  [25] "go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_GM12878,genome.size=20805),"
#  [26] "go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_H1hESC,genome.size=20805),"
#  [27] "go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_K562,genome.size=20805),"
#  [28] "go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_HCT116,genome.size=20805),"
#  [29] "go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_myocyte,genome.size=20805),"
#  [30] "go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_MCF7,genome.size=20805),"
#  [31] "go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_HepG2,genome.size=20805),"
#  [32] "go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_ECC1,genome.size=20805),"
#  [33] "go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_GM12878,genome.size=20805),"
#  [34] "go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_H1hESC,genome.size=20805),"
#  [35] "go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_K562,genome.size=20805),"
#  [36] "go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_HCT116,genome.size=20805),"
#  [37] "go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_myocyte,genome.size=20805),"
#  [38] "go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_MCF7,genome.size=20805),"
#  [39] "go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_HepG2,genome.size=20805),"
#  [40] "go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_ECC1,genome.size=20805),"
#  [41] "go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_GM12878,genome.size=20805),"
#  [42] "go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_H1hESC,genome.size=20805),"
#  [43] "go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_K562,genome.size=20805),"
#  [44] "go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_HCT116,genome.size=20805),"
#  [45] "go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_myocyte,genome.size=20805),"
#  [46] "go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_MCF7,genome.size=20805),"
#  [47] "go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_HepG2,genome.size=20805),"
#  [48] "go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_ECC1,genome.size=20805),"
#  [49] "go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_GM12878,genome.size=20805),"
#  [50] "go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_H1hESC,genome.size=20805),"
#  [51] "go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_K562,genome.size=20805),"
#  [52] "go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_HCT116,genome.size=20805),"
#  [53] "go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_myocyte,genome.size=20805),"
#  [54] "go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_MCF7,genome.size=20805),"
#  [55] "go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_HepG2,genome.size=20805),"
#  [56] "go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_ECC1,genome.size=20805),"
#  [57] "go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_GM12878,genome.size=20805),"
#  [58] "go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_H1hESC,genome.size=20805),"
#  [59] "go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_K562,genome.size=20805),"
#  [60] "go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_HCT116,genome.size=20805),"
#  [61] "go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_myocyte,genome.size=20805),"
#  [62] "go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_MCF7,genome.size=20805),"
#  [63] "go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_HepG2,genome.size=20805),"
#  [64] "go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_ECC1,genome.size=20805),"
#  [65] "go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_GM12878,genome.size=20805),"
#  [66] "go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_H1hESC,genome.size=20805),"
#  [67] "go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_K562,genome.size=20805),"
#  [68] "go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_HCT116,genome.size=20805),"
#  [69] "go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_myocyte,genome.size=20805),"
#  [70] "go.obj <- newGeneOverlap(encodeA$gene_195,encodeB$HNF4A_HepG2,genome.size=20805),"
#  [71] "go.obj <- newGeneOverlap(encodeA$gene_200,encodeB$HNF4A_HepG2,genome.size=20805),"
#  [72] "go.obj <- newGeneOverlap(encodeA$gene_2360,encodeB$HNF4A_HepG2,genome.size=20805),"
#  [73] "go.obj <- newGeneOverlap(encodeA$gene_1490,encodeB$TFAP2C_HeLaS3,genome.size=20805),"
#  [74] "go.obj <- newGeneOverlap(encodeA$gene_537,encodeB$PML_K562,genome.size=20805),"
#  [75] "go.obj <- newGeneOverlap(encodeA$gene_537,encodeB$PML_GM12878,genome.size=20805),"
#  [76] "go.obj <- newGeneOverlap(encodeA$gene_537,encodeB$PML_MCF7,genome.size=20805),"
#  [77] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_keratinocyte,genome.size=20805),"
#  [78] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_astrocyte,genome.size=20805),"
#  [79] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_mammaryepithelialcell,genome.size=20805),"
#  [80] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_myotube,genome.size=20805),"
#  [81] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_K562,genome.size=20805),"
#  [82] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_Tcellacutelymphoblasticleukemia,genome.size=20805),"
#  [83] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_skeletalmusclemyoblast,genome.size=20805),"
#  [84] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_fibroblastofdermis,genome.size=20805),"
#  [85] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_fibroblastoflung,genome.size=20805),"
#  [86] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_endothelialcellofumbilicalvein,genome.size=20805),"
#  [87] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_H1hESC,genome.size=20805),"
#  [88] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_HepG2,genome.size=20805),"
#  [89] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_GM12878,genome.size=20805),"
#  [90] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_HeLaS3,genome.size=20805),"
#  [91] "go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_Bcell,genome.size=20805),"
#  [92] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_keratinocyte,genome.size=20805),"
#  [93] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_astrocyte,genome.size=20805),"
#  [94] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_mammaryepithelialcell,genome.size=20805),"
#  [95] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_myotube,genome.size=20805),"
#  [96] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_K562,genome.size=20805),"
#  [97] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_Tcellacutelymphoblasticleukemia,genome.size=20805),"
#  [98] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_skeletalmusclemyoblast,genome.size=20805),"
#  [99] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_fibroblastofdermis,genome.size=20805),"
# [100] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_fibroblastoflung,genome.size=20805),"
# [101] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_endothelialcellofumbilicalvein,genome.size=20805),"
# [102] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_H1hESC,genome.size=20805),"
# [103] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_HepG2,genome.size=20805),"
# [104] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_GM12878,genome.size=20805),"
# [105] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_HeLaS3,genome.size=20805),"
# [106] "go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_Bcell,genome.size=20805),"
# [107] "go.obj <- newGeneOverlap(encodeA$gene_31,encodeB$SETDB1_K562,genome.size=20805),"
# [108] "go.obj <- newGeneOverlap(encodeA$gene_31,encodeB$SETDB1_U2OS,genome.size=20805),"
# [109] "go.obj <- newGeneOverlap(encodeA$gene_2205,encodeB$SETDB1_K562,genome.size=20805),"
# [110] "go.obj <- newGeneOverlap(encodeA$gene_2205,encodeB$SETDB1_U2OS,genome.size=20805),"
# [111] "go.obj <- newGeneOverlap(encodeA$gene_2412,encodeB$NR2F2_MCF7,genome.size=20805),"
# [112] "go.obj <- newGeneOverlap(encodeA$gene_2412,encodeB$NR2F2_HepG2,genome.size=20805),"
# [113] "go.obj <- newGeneOverlap(encodeA$gene_2412,encodeB$NR2F2_K562,genome.size=20805),"
# [114] "go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_GM12878,genome.size=20805),"
# [115] "go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_ECC1,genome.size=20805),"
# [116] "go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_K562,genome.size=20805),"
# [117] "go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_MCF7,genome.size=20805),"
# [118] "go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_HCT116,genome.size=20805),"
# [119] "go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_H1hESC,genome.size=20805),"
# [120] "go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_GM12878,genome.size=20805),"
# [121] "go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_ECC1,genome.size=20805),"
# [122] "go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_K562,genome.size=20805),"
# [123] "go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_MCF7,genome.size=20805),"
# [124] "go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_HCT116,genome.size=20805),"
# [125] "go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_H1hESC,genome.size=20805),"
# [126] "go.obj <- newGeneOverlap(encodeA$gene_559,encodeB$HDAC6_H1hESC,genome.size=20805),"
# [127] "go.obj <- newGeneOverlap(encodeA$gene_559,encodeB$HDAC6_K562,genome.size=20805),"
# [128] "go.obj <- newGeneOverlap(encodeA$gene_399,encodeB$HDAC6_H1hESC,genome.size=20805),"
# [129] "go.obj <- newGeneOverlap(encodeA$gene_399,encodeB$HDAC6_K562,genome.size=20805),"
# [130] "go.obj <- newGeneOverlap(encodeA$gene_2476,encodeB$STAT1_HeLaS3,genome.size=20805),"
# [131] "go.obj <- newGeneOverlap(encodeA$gene_2476,encodeB$STAT1_K562,genome.size=20805),"
# [132] "go.obj <- newGeneOverlap(encodeA$gene_2476,encodeB$STAT1_GM12878,genome.size=20805),"
# [133] "go.obj <- newGeneOverlap(encodeA$gene_1529,encodeB$STAT1_HeLaS3,genome.size=20805),"
# [134] "go.obj <- newGeneOverlap(encodeA$gene_1529,encodeB$STAT1_K562,genome.size=20805),"
# [135] "go.obj <- newGeneOverlap(encodeA$gene_1529,encodeB$STAT1_GM12878,genome.size=20805),"
# [136] "go.obj <- newGeneOverlap(encodeA$gene_1519,encodeB$STAT1_HeLaS3,genome.size=20805),"
# [137] "go.obj <- newGeneOverlap(encodeA$gene_1519,encodeB$STAT1_K562,genome.size=20805),"
# [138] "go.obj <- newGeneOverlap(encodeA$gene_1519,encodeB$STAT1_GM12878,genome.size=20805),"
# [139] "go.obj <- newGeneOverlap(encodeA$gene_2479,encodeB$STAT3_HeLaS3,genome.size=20805),"
# [140] "go.obj <- newGeneOverlap(encodeA$gene_2479,encodeB$STAT3_GM12878,genome.size=20805),"
# [141] "go.obj <- newGeneOverlap(encodeA$gene_2479,encodeB$STAT3_MCF10A,genome.size=20805),"
# [142] "go.obj <- newGeneOverlap(encodeA$gene_1522,encodeB$BATF_GM12878,genome.size=20805),"
# [143] "go.obj <- newGeneOverlap(encodeA$gene_1523,encodeB$BATF_GM12878,genome.size=20805),"
# [144] "go.obj <- newGeneOverlap(encodeA$gene_1527,encodeB$IRF4_GM12878,genome.size=20805),"
# [145] "go.obj <- newGeneOverlap(encodeA$gene_2774,encodeB$IRF4_GM12878,genome.size=20805),"
# [146] "go.obj <- newGeneOverlap(encodeA$gene_94,encodeB$HDAC1_K562,genome.size=20805),"
# [147] "go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_K562,genome.size=20805),"
# [148] "go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_HepG2,genome.size=20805),"
# [149] "go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_endothelialcellofumbilicalvein,genome.size=20805),"
# [150] "go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_HeLaS3,genome.size=20805),"
# [151] "go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_CH12.LX,genome.size=20805),"
# [152] "go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_H1hESC,genome.size=20805),"
# [153] "go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_K562,genome.size=20805),"
# [154] "go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_HepG2,genome.size=20805),"
# [155] "go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_endothelialcellofumbilicalvein,genome.size=20805),"
# [156] "go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_HeLaS3,genome.size=20805),"
# [157] "go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_CH12.LX,genome.size=20805),"
# [158] "go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_H1hESC,genome.size=20805),"
# [159] "go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_K562,genome.size=20805),"
# [160] "go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_HepG2,genome.size=20805),"
# [161] "go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_endothelialcellofumbilicalvein,genome.size=20805),"
# [162] "go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_HeLaS3,genome.size=20805),"
# [163] "go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_CH12.LX,genome.size=20805),"
# [164] "go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_H1hESC,genome.size=20805),"
# [165] "go.obj <- newGeneOverlap(encodeA$gene_1765,encodeB$RNF2_K562,genome.size=20805),"
# [166] "go.obj <- newGeneOverlap(encodeA$gene_1162,encodeB$GATA3_MCF7,genome.size=20805),"
# [167] "go.obj <- newGeneOverlap(encodeA$gene_1162,encodeB$GATA3_T47D,genome.size=20805),"
# [168] "go.obj <- newGeneOverlap(encodeA$gene_1162,encodeB$GATA3_SHSY5Y,genome.size=20805),"
# [169] "go.obj <- newGeneOverlap(encodeA$gene_1162,encodeB$GATA3_A549,genome.size=20805),"
# [170] "go.obj <- newGeneOverlap(encodeA$gene_1162,encodeB$GATA3_SKNSH,genome.size=20805),"
# [171] "go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_CH12.LX,genome.size=20805),"
# [172] "go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_HeLaS3,genome.size=20805),"
# [173] "go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_K562,genome.size=20805),"
# [174] "go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_MCF10A,genome.size=20805),"
# [175] "go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_myocyte,genome.size=20805),"
# [176] "go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_MELcellline,genome.size=20805),"
# [177] "go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_GM12878,genome.size=20805),"
# [178] "go.obj <- newGeneOverlap(encodeA$gene_2844,encodeB$HDAC2_H1hESC,genome.size=20805),"
# [179] "go.obj <- newGeneOverlap(encodeA$gene_2844,encodeB$HDAC2_K562,genome.size=20805),"
# [180] "go.obj <- newGeneOverlap(encodeA$gene_2844,encodeB$HDAC2_HepG2,genome.size=20805),"
# [181] "go.obj <- newGeneOverlap(encodeA$gene_2844,encodeB$HDAC2_MCF7,genome.size=20805),"
# [182] "go.obj <- newGeneOverlap(encodeA$gene_2197,encodeB$MYB_MELcellline,genome.size=20805),"
# [183] "go.obj <- newGeneOverlap(encodeA$gene_2380,encodeB$ZBTB7A_HepG2,genome.size=20805),"
# [184] "go.obj <- newGeneOverlap(encodeA$gene_2380,encodeB$ZBTB7A_ECC1,genome.size=20805),"
# [185] "go.obj <- newGeneOverlap(encodeA$gene_2380,encodeB$ZBTB7A_K562,genome.size=20805),"
# [186] "go.obj <- newGeneOverlap(encodeA$gene_430,encodeB$FOSL1_HCT116,genome.size=20805),"
# [187] "go.obj <- newGeneOverlap(encodeA$gene_430,encodeB$FOSL1_C2C12,genome.size=20805),"
# [188] "go.obj <- newGeneOverlap(encodeA$gene_430,encodeB$FOSL1_K562,genome.size=20805),"
# [189] "go.obj <- newGeneOverlap(encodeA$gene_430,encodeB$FOSL1_H1hESC,genome.size=20805),"
# [190] "go.obj <- newGeneOverlap(encodeA$gene_429,encodeB$FOSL1_HCT116,genome.size=20805),"
# [191] "go.obj <- newGeneOverlap(encodeA$gene_429,encodeB$FOSL1_C2C12,genome.size=20805),"
# [192] "go.obj <- newGeneOverlap(encodeA$gene_429,encodeB$FOSL1_K562,genome.size=20805),"
# [193] "go.obj <- newGeneOverlap(encodeA$gene_429,encodeB$FOSL1_H1hESC,genome.size=20805),"
# [194] "go.obj <- newGeneOverlap(encodeA$gene_3014,encodeB$NR3C1_HepG2,genome.size=20805),"
# [195] "go.obj <- newGeneOverlap(encodeA$gene_3014,encodeB$NR3C1_A549,genome.size=20805),"
# [196] "go.obj <- newGeneOverlap(encodeA$gene_3014,encodeB$NR3C1_ECC1,genome.size=20805),"
# [197] "go.obj <- newGeneOverlap(encodeA$gene_2544,encodeB$ATF2_H1hESC,genome.size=20805),"
# [198] "go.obj <- newGeneOverlap(encodeA$gene_2544,encodeB$ATF2_GM12878,genome.size=20805),"
# [199] "go.obj <- newGeneOverlap(encodeA$gene_2547,encodeB$IKZF1_GM12878,genome.size=20805),"
# [200] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_ECC1,genome.size=20805),"
# [201] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_HCT116,genome.size=20805),"
# [202] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_K562,genome.size=20805),"
# [203] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_SKNSH,genome.size=20805),"
# [204] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_HepG2,genome.size=20805),"
# [205] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_GM12878,genome.size=20805),"
# [206] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_NT2D1,genome.size=20805),"
# [207] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_GM12892,genome.size=20805),"
# [208] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_GM12891,genome.size=20805),"
# [209] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_A549,genome.size=20805),"
# [210] "go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_H1hESC,genome.size=20805),"
# [211] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_MELcellline,genome.size=20805),"
# [212] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_K562,genome.size=20805),"
# [213] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_endothelialcellofumbilicalvein,genome.size=20805),"
# [214] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_H1hESC,genome.size=20805),"
# [215] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_MCF7,genome.size=20805),"
# [216] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_A549,genome.size=20805),"
# [217] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_HeLaS3,genome.size=20805),"
# [218] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_GM12878,genome.size=20805),"
# [219] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_MCF10A,genome.size=20805),"
# [220] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_HepG2,genome.size=20805),"
# [221] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_CH12.LX,genome.size=20805),"
# [222] "go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_NB4,genome.size=20805),"
# [223] "go.obj <- newGeneOverlap(encodeA$gene_380,encodeB$CBX2_K562,genome.size=20805),"
# [224] "go.obj <- newGeneOverlap(encodeA$gene_381,encodeB$CBX2_K562,genome.size=20805),"
# [225] "go.obj <- newGeneOverlap(encodeA$gene_2143,encodeB$HSF1_HepG2,genome.size=20805),"
# [226] "go.obj <- newGeneOverlap(encodeA$gene_2613,encodeB$ESRRA_GM12878,genome.size=20805),"
# [227] "go.obj <- newGeneOverlap(encodeA$gene_2613,encodeB$ESRRA_HepG2,genome.size=20805),"
# [228] "go.obj <- newGeneOverlap(encodeA$gene_2159,encodeB$ESRRA_GM12878,genome.size=20805),"
# [229] "go.obj <- newGeneOverlap(encodeA$gene_2159,encodeB$ESRRA_HepG2,genome.size=20805),"
# [230] "go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_K562,genome.size=20805),"
# [231] "go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_GM12878,genome.size=20805),"
# [232] "go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_HepG2,genome.size=20805),"
# [233] "go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_H1hESC,genome.size=20805),"
# [234] "go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_SKNSH,genome.size=20805),"
# [235] "go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_HeLaS3,genome.size=20805),"
# [236] "go.obj <- newGeneOverlap(encodeA$gene_1332,encodeB$SUZ12_H1hESC,genome.size=20805),"
# [237] "go.obj <- newGeneOverlap(encodeA$gene_1332,encodeB$SUZ12_NT2D1,genome.size=20805),"
# [238] "go.obj <- newGeneOverlap(encodeA$gene_1332,encodeB$SUZ12_K562,genome.size=20805),"
# [239] "go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_G1EER4,genome.size=20805),"
# [240] "go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_erythroblast,genome.size=20805),"
# [241] "go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_MELcellline,genome.size=20805),"
# [242] "go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_megakaryocyte,genome.size=20805),"
# [243] "go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_K562,genome.size=20805),"
# [244] "go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_G1E,genome.size=20805),"
# [245] "go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_G1EER4,genome.size=20805),"
# [246] "go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_MELcellline,genome.size=20805),"
# [247] "go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_erythroblast,genome.size=20805),"
# [248] "go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_megakaryocyte,genome.size=20805),"
# [249] "go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_erythroblast,genome.size=20805),"
# [250] "go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_K562,genome.size=20805),"
# [251] "go.obj <- newGeneOverlap(encodeA$gene_2167,encodeB$TCF3_myocyte,genome.size=20805),"
# [252] "go.obj <- newGeneOverlap(encodeA$gene_2167,encodeB$TCF3_GM12878,genome.size=20805),"
# [253] "go.obj <- newGeneOverlap(encodeA$gene_2169,encodeB$TCF3_myocyte,genome.size=20805),"
# [254] "go.obj <- newGeneOverlap(encodeA$gene_2169,encodeB$TCF3_GM12878,genome.size=20805),"
# [255] "go.obj <- newGeneOverlap(encodeA$gene_2166,encodeB$FOXA2_HepG2,genome.size=20805),"
# [256] "go.obj <- newGeneOverlap(encodeA$gene_2166,encodeB$FOXA2_A549,genome.size=20805),"
# [257] "go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_H1hESC,genome.size=20805),"
# [258] "go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_MCF7,genome.size=20805),"
# [259] "go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_SKNSH,genome.size=20805),"
# [260] "go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_ECC1,genome.size=20805),"
# [261] "go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_A549,genome.size=20805),"
# [262] "go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_GM12878,genome.size=20805),"
# [263] "go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_myocyte,genome.size=20805),"

# %%
go.obj <- newGeneOverlap(encodeA$gene_2034,encodeB$TRIM28_HEK293,genome.size=20805)
print(testGeneOverlap(go.obj))
# Out:
# Detailed information about this GeneOverlap object:
# listA size=326, e.g. Rpl41 Rps14 Rpl37a
# listB size=2001, e.g. POLR2J4 WDR83OS KIAA1586
# Intersection size=1, e.g.
# Union size=2326, e.g. Rpl41 Rps14 Rpl37a
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18479 325
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0

# %%
go.obj <- newGeneOverlap(encodeA$gene_2032,encodeB$TRIM28_HEK293,genome.size=20805)

# %%
print(testGeneOverlap(go.obj))
# Out:
# Detailed information about this GeneOverlap object:
# listA size=280, e.g. Gm14025 Rps16 Rps23
# listB size=2001, e.g. POLR2J4 WDR83OS KIAA1586
# Intersection size=1, e.g.
# Union size=2280, e.g. Gm14025 Rps16 Rps23
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18525 279
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0

# %%
golist <-list(go.obj <- newGeneOverlap(encodeA$gene_2034,encodeB$TRIM28_U2OS,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2034,encodeB$TRIM28_HEK293,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2034,encodeB$TRIM28_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2033,encodeB$TRIM28_U2OS,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2033,encodeB$TRIM28_HEK293,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2033,encodeB$TRIM28_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2032,encodeB$TRIM28_U2OS,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2032,encodeB$TRIM28_HEK293,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2032,encodeB$TRIM28_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2430,encodeB$ESR1_T47D,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2430,encodeB$ESR1_ECC1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2898,encodeB$ESR1_T47D,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2898,encodeB$ESR1_ECC1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2714,encodeB$NR2C2_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2714,encodeB$NR2C2_HeLaS3,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2714,encodeB$NR2C2_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2714,encodeB$NR2C2_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2200,encodeB$NR2C2_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2200,encodeB$NR2C2_HeLaS3,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2200,encodeB$NR2C2_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2200,encodeB$NR2C2_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_MCF7,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_ECC1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_HCT116,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1157,encodeB$SRF_myocyte,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_MCF7,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_ECC1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_HCT116,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1158,encodeB$SRF_myocyte,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_MCF7,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_ECC1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_HCT116,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1185,encodeB$SRF_myocyte,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_MCF7,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_ECC1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_HCT116,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_175,encodeB$SRF_myocyte,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_MCF7,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_ECC1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_HCT116,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2884,encodeB$SRF_myocyte,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_MCF7,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_ECC1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_HCT116,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1238,encodeB$SRF_myocyte,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_195,encodeB$HNF4A_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_200,encodeB$HNF4A_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2360,encodeB$HNF4A_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1490,encodeB$TFAP2C_HeLaS3,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_537,encodeB$PML_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_537,encodeB$PML_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_537,encodeB$PML_MCF7,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_keratinocyte,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_astrocyte,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_mammaryepithelialcell,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_myotube,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_Tcellacutelymphoblasticleukemia,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_skeletalmusclemyoblast,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_fibroblastofdermis,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_fibroblastoflung,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_endothelialcellofumbilicalvein,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_HeLaS3,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_542,encodeB$EZH2_Bcell,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_keratinocyte,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_astrocyte,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_mammaryepithelialcell,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_myotube,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_Tcellacutelymphoblasticleukemia,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_skeletalmusclemyoblast,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_fibroblastofdermis,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_fibroblastoflung,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_endothelialcellofumbilicalvein,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_HeLaS3,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2664,encodeB$EZH2_Bcell,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_31,encodeB$SETDB1_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_31,encodeB$SETDB1_U2OS,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2205,encodeB$SETDB1_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2205,encodeB$SETDB1_U2OS,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2412,encodeB$NR2F2_MCF7,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2412,encodeB$NR2F2_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2412,encodeB$NR2F2_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_ECC1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_MCF7,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_HCT116,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_553,encodeB$EGR1_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_ECC1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_MCF7,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_HCT116,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_552,encodeB$EGR1_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_559,encodeB$HDAC6_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_559,encodeB$HDAC6_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_399,encodeB$HDAC6_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_399,encodeB$HDAC6_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2476,encodeB$STAT1_HeLaS3,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2476,encodeB$STAT1_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2476,encodeB$STAT1_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1529,encodeB$STAT1_HeLaS3,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1529,encodeB$STAT1_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1529,encodeB$STAT1_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1519,encodeB$STAT1_HeLaS3,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1519,encodeB$STAT1_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1519,encodeB$STAT1_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2479,encodeB$STAT3_HeLaS3,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2479,encodeB$STAT3_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2479,encodeB$STAT3_MCF10A,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1522,encodeB$BATF_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1523,encodeB$BATF_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1527,encodeB$IRF4_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2774,encodeB$IRF4_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_94,encodeB$HDAC1_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_endothelialcellofumbilicalvein,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_HeLaS3,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_CH12.LX,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1516,encodeB$JUN_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_endothelialcellofumbilicalvein,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_HeLaS3,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_CH12.LX,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_3073,encodeB$JUN_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_endothelialcellofumbilicalvein,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_HeLaS3,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_CH12.LX,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_321,encodeB$JUN_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1765,encodeB$RNF2_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1162,encodeB$GATA3_MCF7,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1162,encodeB$GATA3_T47D,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1162,encodeB$GATA3_SHSY5Y,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1162,encodeB$GATA3_A549,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1162,encodeB$GATA3_SKNSH,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_CH12.LX,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_HeLaS3,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_MCF10A,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_myocyte,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_MELcellline,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1167,encodeB$E2F4_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2844,encodeB$HDAC2_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2844,encodeB$HDAC2_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2844,encodeB$HDAC2_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2844,encodeB$HDAC2_MCF7,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2197,encodeB$MYB_MELcellline,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2380,encodeB$ZBTB7A_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2380,encodeB$ZBTB7A_ECC1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2380,encodeB$ZBTB7A_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_430,encodeB$FOSL1_HCT116,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_430,encodeB$FOSL1_C2C12,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_430,encodeB$FOSL1_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_430,encodeB$FOSL1_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_429,encodeB$FOSL1_HCT116,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_429,encodeB$FOSL1_C2C12,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_429,encodeB$FOSL1_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_429,encodeB$FOSL1_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_3014,encodeB$NR3C1_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_3014,encodeB$NR3C1_A549,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_3014,encodeB$NR3C1_ECC1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2544,encodeB$ATF2_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2544,encodeB$ATF2_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2547,encodeB$IKZF1_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_ECC1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_HCT116,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_SKNSH,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_NT2D1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_GM12892,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_GM12891,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_A549,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_76,encodeB$YY1_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_MELcellline,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_endothelialcellofumbilicalvein,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_MCF7,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_A549,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_HeLaS3,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_MCF10A,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_CH12.LX,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2553,encodeB$MYC_NB4,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_380,encodeB$CBX2_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_381,encodeB$CBX2_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2143,encodeB$HSF1_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2613,encodeB$ESRRA_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2613,encodeB$ESRRA_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2159,encodeB$ESRRA_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2159,encodeB$ESRRA_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_SKNSH,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2150,encodeB$NRF1_HeLaS3,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1332,encodeB$SUZ12_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1332,encodeB$SUZ12_NT2D1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1332,encodeB$SUZ12_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_G1EER4,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_erythroblast,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_MELcellline,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_megakaryocyte,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1447,encodeB$TAL1_G1E,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_G1EER4,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_MELcellline,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_erythroblast,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_megakaryocyte,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_erythroblast,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_1062,encodeB$GATA1_K562,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2167,encodeB$TCF3_myocyte,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2167,encodeB$TCF3_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2169,encodeB$TCF3_myocyte,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2169,encodeB$TCF3_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2166,encodeB$FOXA2_HepG2,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2166,encodeB$FOXA2_A549,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_H1hESC,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_MCF7,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_SKNSH,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_ECC1,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_A549,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_GM12878,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$gene_2168,encodeB$TCF12_myocyte,genome.size=20805))

for (go.obj in golist)
     print(testGeneOverlap(go.obj))
# Out:
# Detailed information about this GeneOverlap object:
# listA size=326, e.g. Rpl41 Rps14 Rpl37a
# listB size=2001, e.g. HEXIM2 FNBP4 POLR2J3
# Intersection size=1, e.g.
# Union size=2326, e.g. Rpl41 Rps14 Rpl37a
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18479 325
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=326, e.g. Rpl41 Rps14 Rpl37a
# listB size=2001, e.g. POLR2J4 WDR83OS KIAA1586
# Intersection size=1, e.g.
# Union size=2326, e.g. Rpl41 Rps14 Rpl37a
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18479 325
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=326, e.g. Rpl41 Rps14 Rpl37a
# listB size=2062, e.g. HEXIM2 HEXIM1 BTBD19
# Intersection size=1, e.g.
# Union size=2387, e.g. Rpl41 Rps14 Rpl37a
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18418 325
# inB   2061   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=294, e.g. Rps23 Rps14 Rpl8
# listB size=2001, e.g. HEXIM2 FNBP4 POLR2J3
# Intersection size=1, e.g.
# Union size=2294, e.g. Rps23 Rps14 Rpl8
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18511 293
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=294, e.g. Rps23 Rps14 Rpl8
# listB size=2001, e.g. POLR2J4 WDR83OS KIAA1586
# Intersection size=1, e.g.
# Union size=2294, e.g. Rps23 Rps14 Rpl8
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18511 293
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=294, e.g. Rps23 Rps14 Rpl8
# listB size=2062, e.g. HEXIM2 HEXIM1 BTBD19
# Intersection size=1, e.g.
# Union size=2355, e.g. Rps23 Rps14 Rpl8
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18450 293
# inB   2061   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=280, e.g. Gm14025 Rps16 Rps23
# listB size=2001, e.g. HEXIM2 FNBP4 POLR2J3
# Intersection size=1, e.g.
# Union size=2280, e.g. Gm14025 Rps16 Rps23
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18525 279
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=280, e.g. Gm14025 Rps16 Rps23
# listB size=2001, e.g. POLR2J4 WDR83OS KIAA1586
# Intersection size=1, e.g.
# Union size=2280, e.g. Gm14025 Rps16 Rps23
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18525 279
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=280, e.g. Gm14025 Rps16 Rps23
# listB size=2062, e.g. HEXIM2 HEXIM1 BTBD19
# Intersection size=1, e.g.
# Union size=2341, e.g. Gm14025 Rps16 Rps23
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18464 279
# inB   2061   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=93, e.g. Col3a1 Postn Mup19
# listB size=426, e.g. GAMT MED4 BTBD18
# Intersection size=1, e.g.
# Union size=518, e.g. Col3a1 Postn Mup19
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20287  92
# inB    425   1
# Overlapping p-value=0.85
# Odds ratio=0.5
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=93, e.g. Col3a1 Postn Mup19
# listB size=638, e.g. CDK18 HOMER2 BTBD19
# Intersection size=1, e.g.
# Union size=730, e.g. Col3a1 Postn Mup19
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20075  92
# inB    637   1
# Overlapping p-value=0.95
# Odds ratio=0.3
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=456, e.g. Rplp1 Rplp2 COX2
# listB size=426, e.g. GAMT MED4 BTBD18
# Intersection size=1, e.g.
# Union size=881, e.g. Rplp1 Rplp2 COX2
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19924 455
# inB    425   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=456, e.g. Rplp1 Rplp2 COX2
# listB size=638, e.g. CDK18 HOMER2 BTBD19
# Intersection size=1, e.g.
# Union size=1093, e.g. Rplp1 Rplp2 COX2
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19712 455
# inB    637   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=385, e.g. MIR622 LGMN KRT8
# listB size=1482, e.g. B3GALNT2 LINS TYW5
# Intersection size=37, e.g. PGD SLIRP PA2G4
# Union size=1830, e.g. MIR622 LGMN KRT8
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18975 348
# inB   1445  37
# Overlapping p-value=0.039
# Odds ratio=1.4
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=385, e.g. MIR622 LGMN KRT8
# listB size=1056, e.g. TYW5 CCZ1B WDR83OS
# Intersection size=30, e.g. PGD SLIRP G6PD
# Union size=1411, e.g. MIR622 LGMN KRT8
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19394 355
# inB   1026  30
# Overlapping p-value=0.013
# Odds ratio=1.6
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=385, e.g. MIR622 LGMN KRT8
# listB size=382, e.g. JMJD5 RPL22 LINC00094
# Intersection size=15, e.g. PGD SLIRP PSMA6
# Union size=752, e.g. MIR622 LGMN KRT8
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20053 370
# inB    367  15
# Overlapping p-value=5.3e-03
# Odds ratio=2.2
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=385, e.g. MIR622 LGMN KRT8
# listB size=594, e.g. ACOT8 RPL22 TYW5
# Intersection size=20, e.g. PGD SLIRP PSMA6
# Union size=959, e.g. MIR622 LGMN KRT8
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19846 365
# inB    574  20
# Overlapping p-value=7.7e-03
# Odds ratio=1.9
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=274, e.g. Cidea Cyp4a14 Cyp2a5
# listB size=1482, e.g. B3GALNT2 LINS TYW5
# Intersection size=1, e.g.
# Union size=1755, e.g. Cidea Cyp4a14 Cyp2a5
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19050 273
# inB   1481   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=274, e.g. Cidea Cyp4a14 Cyp2a5
# listB size=1056, e.g. TYW5 CCZ1B WDR83OS
# Intersection size=1, e.g.
# Union size=1329, e.g. Cidea Cyp4a14 Cyp2a5
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19476 273
# inB   1055   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=274, e.g. Cidea Cyp4a14 Cyp2a5
# listB size=382, e.g. JMJD5 RPL22 LINC00094
# Intersection size=1, e.g.
# Union size=655, e.g. Cidea Cyp4a14 Cyp2a5
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20150 273
# inB    381   1
# Overlapping p-value=0.99
# Odds ratio=0.2
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=274, e.g. Cidea Cyp4a14 Cyp2a5
# listB size=594, e.g. ACOT8 RPL22 TYW5
# Intersection size=1, e.g.
# Union size=867, e.g. Cidea Cyp4a14 Cyp2a5
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19938 273
# inB    593   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=228, e.g. Actg1 Dscaml1 Psat1
# listB size=1641, e.g. FRS2 C12ORF73 PRKAB2
# Intersection size=1, e.g.
# Union size=1868, e.g. Actg1 Dscaml1 Psat1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18937 227
# inB   1640   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=228, e.g. Actg1 Dscaml1 Psat1
# listB size=889, e.g. HEXIM2 SND1 NGDN
# Intersection size=1, e.g.
# Union size=1116, e.g. Actg1 Dscaml1 Psat1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19689 227
# inB    888   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=228, e.g. Actg1 Dscaml1 Psat1
# listB size=1603, e.g. MIR143HG FRS2 C12ORF73
# Intersection size=1, e.g.
# Union size=1830, e.g. Actg1 Dscaml1 Psat1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18975 227
# inB   1602   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=228, e.g. Actg1 Dscaml1 Psat1
# listB size=1987, e.g. ATE1 ENDOG HEXIM1
# Intersection size=1, e.g.
# Union size=2214, e.g. Actg1 Dscaml1 Psat1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18591 227
# inB   1986   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=228, e.g. Actg1 Dscaml1 Psat1
# listB size=1074, e.g. SND1 C20ORF29 TMEM85
# Intersection size=1, e.g.
# Union size=1301, e.g. Actg1 Dscaml1 Psat1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19504 227
# inB   1073   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=228, e.g. Actg1 Dscaml1 Psat1
# listB size=898, e.g. SND1 TMEM85 ZFYVE20
# Intersection size=1, e.g.
# Union size=1125, e.g. Actg1 Dscaml1 Psat1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19680 227
# inB    897   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=228, e.g. Actg1 Dscaml1 Psat1
# listB size=414, e.g. SND1 ISY1-RAB43 RPL22
# Intersection size=1, e.g.
# Union size=641, e.g. Actg1 Dscaml1 Psat1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20164 227
# inB    413   1
# Overlapping p-value=0.99
# Odds ratio=0.2
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=228, e.g. Actg1 Dscaml1 Psat1
# listB size=1669, e.g. ATE1 HEXIM2 LNPEP
# Intersection size=1, e.g.
# Union size=1896, e.g. Actg1 Dscaml1 Psat1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18909 227
# inB   1668   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=241, e.g. Actg1 Lgals1 Actb
# listB size=1641, e.g. FRS2 C12ORF73 PRKAB2
# Intersection size=1, e.g.
# Union size=1881, e.g. Actg1 Lgals1 Actb
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18924 240
# inB   1640   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=241, e.g. Actg1 Lgals1 Actb
# listB size=889, e.g. HEXIM2 SND1 NGDN
# Intersection size=1, e.g.
# Union size=1129, e.g. Actg1 Lgals1 Actb
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19676 240
# inB    888   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=241, e.g. Actg1 Lgals1 Actb
# listB size=1603, e.g. MIR143HG FRS2 C12ORF73
# Intersection size=1, e.g.
# Union size=1843, e.g. Actg1 Lgals1 Actb
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18962 240
# inB   1602   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=241, e.g. Actg1 Lgals1 Actb
# listB size=1987, e.g. ATE1 ENDOG HEXIM1
# Intersection size=1, e.g.
# Union size=2227, e.g. Actg1 Lgals1 Actb
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18578 240
# inB   1986   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=241, e.g. Actg1 Lgals1 Actb
# listB size=1074, e.g. SND1 C20ORF29 TMEM85
# Intersection size=1, e.g.
# Union size=1314, e.g. Actg1 Lgals1 Actb
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19491 240
# inB   1073   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=241, e.g. Actg1 Lgals1 Actb
# listB size=898, e.g. SND1 TMEM85 ZFYVE20
# Intersection size=1, e.g.
# Union size=1138, e.g. Actg1 Lgals1 Actb
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19667 240
# inB    897   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=241, e.g. Actg1 Lgals1 Actb
# listB size=414, e.g. SND1 ISY1-RAB43 RPL22
# Intersection size=1, e.g.
# Union size=654, e.g. Actg1 Lgals1 Actb
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20151 240
# inB    413   1
# Overlapping p-value=0.99
# Odds ratio=0.2
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=241, e.g. Actg1 Lgals1 Actb
# listB size=1669, e.g. ATE1 HEXIM2 LNPEP
# Intersection size=1, e.g.
# Union size=1909, e.g. Actg1 Lgals1 Actb
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18896 240
# inB   1668   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=222, e.g. Actg1 Lgals1 Actb
# listB size=1641, e.g. FRS2 C12ORF73 PRKAB2
# Intersection size=1, e.g.
# Union size=1862, e.g. Actg1 Lgals1 Actb
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18943 221
# inB   1640   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=222, e.g. Actg1 Lgals1 Actb
# listB size=889, e.g. HEXIM2 SND1 NGDN
# Intersection size=1, e.g.
# Union size=1110, e.g. Actg1 Lgals1 Actb
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19695 221
# inB    888   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=222, e.g. Actg1 Lgals1 Actb
# listB size=1603, e.g. MIR143HG FRS2 C12ORF73
# Intersection size=1, e.g.
# Union size=1824, e.g. Actg1 Lgals1 Actb
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18981 221
# inB   1602   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=222, e.g. Actg1 Lgals1 Actb
# listB size=1987, e.g. ATE1 ENDOG HEXIM1
# Intersection size=1, e.g.
# Union size=2208, e.g. Actg1 Lgals1 Actb
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18597 221
# inB   1986   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=222, e.g. Actg1 Lgals1 Actb
# listB size=1074, e.g. SND1 C20ORF29 TMEM85
# Intersection size=1, e.g.
# Union size=1295, e.g. Actg1 Lgals1 Actb
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19510 221
# inB   1073   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=222, e.g. Actg1 Lgals1 Actb
# listB size=898, e.g. SND1 TMEM85 ZFYVE20
# Intersection size=1, e.g.
# Union size=1119, e.g. Actg1 Lgals1 Actb
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19686 221
# inB    897   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=222, e.g. Actg1 Lgals1 Actb
# listB size=414, e.g. SND1 ISY1-RAB43 RPL22
# Intersection size=1, e.g.
# Union size=635, e.g. Actg1 Lgals1 Actb
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20170 221
# inB    413   1
# Overlapping p-value=0.99
# Odds ratio=0.2
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=222, e.g. Actg1 Lgals1 Actb
# listB size=1669, e.g. ATE1 HEXIM2 LNPEP
# Intersection size=1, e.g.
# Union size=1890, e.g. Actg1 Lgals1 Actb
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18915 221
# inB   1668   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=321, e.g. Xist Myl10 Ifi202b
# listB size=1641, e.g. FRS2 C12ORF73 PRKAB2
# Intersection size=1, e.g.
# Union size=1961, e.g. Xist Myl10 Ifi202b
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18844 320
# inB   1640   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=321, e.g. Xist Myl10 Ifi202b
# listB size=889, e.g. HEXIM2 SND1 NGDN
# Intersection size=1, e.g.
# Union size=1209, e.g. Xist Myl10 Ifi202b
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19596 320
# inB    888   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=321, e.g. Xist Myl10 Ifi202b
# listB size=1603, e.g. MIR143HG FRS2 C12ORF73
# Intersection size=1, e.g.
# Union size=1923, e.g. Xist Myl10 Ifi202b
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18882 320
# inB   1602   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=321, e.g. Xist Myl10 Ifi202b
# listB size=1987, e.g. ATE1 ENDOG HEXIM1
# Intersection size=1, e.g.
# Union size=2307, e.g. Xist Myl10 Ifi202b
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18498 320
# inB   1986   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=321, e.g. Xist Myl10 Ifi202b
# listB size=1074, e.g. SND1 C20ORF29 TMEM85
# Intersection size=1, e.g.
# Union size=1394, e.g. Xist Myl10 Ifi202b
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19411 320
# inB   1073   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=321, e.g. Xist Myl10 Ifi202b
# listB size=898, e.g. SND1 TMEM85 ZFYVE20
# Intersection size=1, e.g.
# Union size=1218, e.g. Xist Myl10 Ifi202b
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19587 320
# inB    897   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=321, e.g. Xist Myl10 Ifi202b
# listB size=414, e.g. SND1 ISY1-RAB43 RPL22
# Intersection size=1, e.g.
# Union size=734, e.g. Xist Myl10 Ifi202b
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20071 320
# inB    413   1
# Overlapping p-value=1
# Odds ratio=0.2
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=321, e.g. Xist Myl10 Ifi202b
# listB size=1669, e.g. ATE1 HEXIM2 LNPEP
# Intersection size=2, e.g. 2-Mar
# Union size=1988, e.g. Xist Myl10 Ifi202b
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18817 319
# inB   1667   2
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=293, e.g. Sparcl1 Tagln Cnn1
# listB size=1641, e.g. FRS2 C12ORF73 PRKAB2
# Intersection size=1, e.g.
# Union size=1933, e.g. Sparcl1 Tagln Cnn1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18872 292
# inB   1640   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=293, e.g. Sparcl1 Tagln Cnn1
# listB size=889, e.g. HEXIM2 SND1 NGDN
# Intersection size=2, e.g. 9-Sep
# Union size=1180, e.g. Sparcl1 Tagln Cnn1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19625 291
# inB    887   2
# Overlapping p-value=1
# Odds ratio=0.2
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=293, e.g. Sparcl1 Tagln Cnn1
# listB size=1603, e.g. MIR143HG FRS2 C12ORF73
# Intersection size=1, e.g.
# Union size=1895, e.g. Sparcl1 Tagln Cnn1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18910 292
# inB   1602   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=293, e.g. Sparcl1 Tagln Cnn1
# listB size=1987, e.g. ATE1 ENDOG HEXIM1
# Intersection size=1, e.g.
# Union size=2279, e.g. Sparcl1 Tagln Cnn1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18526 292
# inB   1986   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=293, e.g. Sparcl1 Tagln Cnn1
# listB size=1074, e.g. SND1 C20ORF29 TMEM85
# Intersection size=1, e.g.
# Union size=1366, e.g. Sparcl1 Tagln Cnn1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19439 292
# inB   1073   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=293, e.g. Sparcl1 Tagln Cnn1
# listB size=898, e.g. SND1 TMEM85 ZFYVE20
# Intersection size=1, e.g.
# Union size=1190, e.g. Sparcl1 Tagln Cnn1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19615 292
# inB    897   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=293, e.g. Sparcl1 Tagln Cnn1
# listB size=414, e.g. SND1 ISY1-RAB43 RPL22
# Intersection size=1, e.g.
# Union size=706, e.g. Sparcl1 Tagln Cnn1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20099 292
# inB    413   1
# Overlapping p-value=1
# Odds ratio=0.2
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=293, e.g. Sparcl1 Tagln Cnn1
# listB size=1669, e.g. ATE1 HEXIM2 LNPEP
# Intersection size=1, e.g.
# Union size=1961, e.g. Sparcl1 Tagln Cnn1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18844 292
# inB   1668   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=367, e.g. Actg1 Kxd1 Rps6-ps4
# listB size=1641, e.g. FRS2 C12ORF73 PRKAB2
# Intersection size=1, e.g.
# Union size=2007, e.g. Actg1 Kxd1 Rps6-ps4
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18798 366
# inB   1640   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=367, e.g. Actg1 Kxd1 Rps6-ps4
# listB size=889, e.g. HEXIM2 SND1 NGDN
# Intersection size=1, e.g.
# Union size=1255, e.g. Actg1 Kxd1 Rps6-ps4
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19550 366
# inB    888   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=367, e.g. Actg1 Kxd1 Rps6-ps4
# listB size=1603, e.g. MIR143HG FRS2 C12ORF73
# Intersection size=1, e.g.
# Union size=1969, e.g. Actg1 Kxd1 Rps6-ps4
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18836 366
# inB   1602   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=367, e.g. Actg1 Kxd1 Rps6-ps4
# listB size=1987, e.g. ATE1 ENDOG HEXIM1
# Intersection size=1, e.g.
# Union size=2353, e.g. Actg1 Kxd1 Rps6-ps4
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18452 366
# inB   1986   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=367, e.g. Actg1 Kxd1 Rps6-ps4
# listB size=1074, e.g. SND1 C20ORF29 TMEM85
# Intersection size=1, e.g.
# Union size=1440, e.g. Actg1 Kxd1 Rps6-ps4
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19365 366
# inB   1073   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=367, e.g. Actg1 Kxd1 Rps6-ps4
# listB size=898, e.g. SND1 TMEM85 ZFYVE20
# Intersection size=1, e.g.
# Union size=1264, e.g. Actg1 Kxd1 Rps6-ps4
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19541 366
# inB    897   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=367, e.g. Actg1 Kxd1 Rps6-ps4
# listB size=414, e.g. SND1 ISY1-RAB43 RPL22
# Intersection size=1, e.g.
# Union size=780, e.g. Actg1 Kxd1 Rps6-ps4
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20025 366
# inB    413   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=367, e.g. Actg1 Kxd1 Rps6-ps4
# listB size=1669, e.g. ATE1 HEXIM2 LNPEP
# Intersection size=1, e.g.
# Union size=2035, e.g. Actg1 Kxd1 Rps6-ps4
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18770 366
# inB   1668   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=526, e.g. Apoa1 Apoa2 Aldob
# listB size=2621, e.g. HEXIM2 MIR143HG BTBD19
# Intersection size=6, e.g. C3 F2 F11
# Union size=3141, e.g. Apoa1 Apoa2 Aldob
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 17664 520
# inB   2615   6
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=409, e.g. Pla2g2a Gm3776 Aldh1a1
# listB size=2621, e.g. HEXIM2 MIR143HG BTBD19
# Intersection size=1, e.g.
# Union size=3029, e.g. Pla2g2a Gm3776 Aldh1a1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 17776 408
# inB   2620   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=287, e.g. LOC544903 Fabp2 Sepp1
# listB size=2621, e.g. HEXIM2 MIR143HG BTBD19
# Intersection size=2, e.g. C3
# Union size=2906, e.g. LOC544903 Fabp2 Sepp1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 17899 285
# inB   2619   2
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=314, e.g. BC094435 Gpx1 Dppa3
# listB size=2001, e.g. RC3H2 FRS3 FRS2
# Intersection size=1, e.g.
# Union size=2314, e.g. BC094435 Gpx1 Dppa3
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18491 313
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=267, e.g. Bhmt Cyp2a5 Thrsp
# listB size=1439, e.g. C5ORF15 ZNF282 TMEM85
# Intersection size=1, e.g.
# Union size=1705, e.g. Bhmt Cyp2a5 Thrsp
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19100 266
# inB   1438   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=267, e.g. Bhmt Cyp2a5 Thrsp
# listB size=1180, e.g. POLR2J4 FAM108A1 CCZ1B
# Intersection size=1, e.g.
# Union size=1446, e.g. Bhmt Cyp2a5 Thrsp
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19359 266
# inB   1179   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=267, e.g. Bhmt Cyp2a5 Thrsp
# listB size=888, e.g. ENDOG FNBP1 TYW5
# Intersection size=1, e.g.
# Union size=1154, e.g. Bhmt Cyp2a5 Thrsp
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19651 266
# inB    887   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=266, e.g. Ctgf Postn Cdh11
# listB size=2001, e.g. MIR548D2 NIPSNAP3B BTBD18
# Intersection size=1, e.g.
# Union size=2266, e.g. Ctgf Postn Cdh11
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18539 265
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=266, e.g. Ctgf Postn Cdh11
# listB size=2001, e.g. SDR42E1 LOC386597 ESX1
# Intersection size=1, e.g.
# Union size=2266, e.g. Ctgf Postn Cdh11
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18539 265
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=266, e.g. Ctgf Postn Cdh11
# listB size=2001, e.g. NIPSNAP3B BTBD18 CACNA2D3
# Intersection size=1, e.g.
# Union size=2266, e.g. Ctgf Postn Cdh11
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18539 265
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=266, e.g. Ctgf Postn Cdh11
# listB size=2001, e.g. NIPSNAP3A NIPSNAP3B WDR83OS
# Intersection size=1, e.g.
# Union size=2266, e.g. Ctgf Postn Cdh11
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18539 265
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=266, e.g. Ctgf Postn Cdh11
# listB size=2001, e.g. HEXIM2 MIR143HG HEXIM1
# Intersection size=1, e.g.
# Union size=2266, e.g. Ctgf Postn Cdh11
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18539 265
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=266, e.g. Ctgf Postn Cdh11
# listB size=2001, e.g. NIPSNAP3A WDR83OS DHDH
# Intersection size=1, e.g.
# Union size=2266, e.g. Ctgf Postn Cdh11
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18539 265
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=266, e.g. Ctgf Postn Cdh11
# listB size=2001, e.g. HEXIM2 LOC386597 CACNA2D2
# Intersection size=1, e.g.
# Union size=2266, e.g. Ctgf Postn Cdh11
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18539 265
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=266, e.g. Ctgf Postn Cdh11
# listB size=2001, e.g. SDR42E1 WDR83OS DHDH
# Intersection size=1, e.g.
# Union size=2266, e.g. Ctgf Postn Cdh11
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18539 265
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=266, e.g. Ctgf Postn Cdh11
# listB size=2001, e.g. NIPSNAP3B LOC386597 CACNA2D2
# Intersection size=1, e.g.
# Union size=2266, e.g. Ctgf Postn Cdh11
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18539 265
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=266, e.g. Ctgf Postn Cdh11
# listB size=2001, e.g. NIPSNAP3A CACNA2D2 CACNA2D3
# Intersection size=1, e.g.
# Union size=2266, e.g. Ctgf Postn Cdh11
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18539 265
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=266, e.g. Ctgf Postn Cdh11
# listB size=2001, e.g. POLR2J4 ENDOG NIPSNAP3A
# Intersection size=1, e.g.
# Union size=2266, e.g. Ctgf Postn Cdh11
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18539 265
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=266, e.g. Ctgf Postn Cdh11
# listB size=2001, e.g. NIPSNAP3A CACNA2D1 DHDH
# Intersection size=1, e.g.
# Union size=2266, e.g. Ctgf Postn Cdh11
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18539 265
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=266, e.g. Ctgf Postn Cdh11
# listB size=2001, e.g. CACNA2D1 BTBD11 LARP4
# Intersection size=1, e.g.
# Union size=2266, e.g. Ctgf Postn Cdh11
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18539 265
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=266, e.g. Ctgf Postn Cdh11
# listB size=2001, e.g. KRTDAP CACNA2D3 MIR3917
# Intersection size=1, e.g.
# Union size=2266, e.g. Ctgf Postn Cdh11
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18539 265
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=266, e.g. Ctgf Postn Cdh11
# listB size=2001, e.g. CACNA2D2 BTBD11 RPL17-C18ORF32
# Intersection size=1, e.g.
# Union size=2266, e.g. Ctgf Postn Cdh11
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18539 265
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=340, e.g. TUBA1C LDHA H2AFZ
# listB size=2001, e.g. MIR548D2 NIPSNAP3B BTBD18
# Intersection size=15, e.g. RPSA PCNA SLIRP
# Union size=2326, e.g. TUBA1C LDHA H2AFZ
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18479 325
# inB   1986  15
# Overlapping p-value=1
# Odds ratio=0.4
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=340, e.g. TUBA1C LDHA H2AFZ
# listB size=2001, e.g. SDR42E1 LOC386597 ESX1
# Intersection size=19, e.g. CKS1B FTO CHCHD2
# Union size=2322, e.g. TUBA1C LDHA H2AFZ
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18483 321
# inB   1982  19
# Overlapping p-value=1
# Odds ratio=0.6
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=340, e.g. TUBA1C LDHA H2AFZ
# listB size=2001, e.g. NIPSNAP3B BTBD18 CACNA2D3
# Intersection size=24, e.g. ODC1 PHGDH ARL6IP1
# Union size=2317, e.g. TUBA1C LDHA H2AFZ
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18488 316
# inB   1977  24
# Overlapping p-value=0.96
# Odds ratio=0.7
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=340, e.g. TUBA1C LDHA H2AFZ
# listB size=2001, e.g. NIPSNAP3A NIPSNAP3B WDR83OS
# Intersection size=23, e.g. NME1 PHGDH CWC15
# Union size=2318, e.g. TUBA1C LDHA H2AFZ
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18487 317
# inB   1978  23
# Overlapping p-value=0.98
# Odds ratio=0.7
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=340, e.g. TUBA1C LDHA H2AFZ
# listB size=2001, e.g. HEXIM2 MIR143HG HEXIM1
# Intersection size=59, e.g. LDHA NME1 PHGDH
# Union size=2282, e.g. TUBA1C LDHA H2AFZ
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18523 281
# inB   1942  59
# Overlapping p-value=5.8e-06
# Odds ratio=2.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=340, e.g. TUBA1C LDHA H2AFZ
# listB size=2001, e.g. NIPSNAP3A WDR83OS DHDH
# Intersection size=58, e.g. TUBA1C NME1 RPSA
# Union size=2283, e.g. TUBA1C LDHA H2AFZ
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18522 282
# inB   1943  58
# Overlapping p-value=1.2e-05
# Odds ratio=2.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=340, e.g. TUBA1C LDHA H2AFZ
# listB size=2001, e.g. HEXIM2 LOC386597 CACNA2D2
# Intersection size=22, e.g. PHGDH TUBA1B TUBB4B
# Union size=2319, e.g. TUBA1C LDHA H2AFZ
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18486 318
# inB   1979  22
# Overlapping p-value=0.99
# Odds ratio=0.6
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=340, e.g. TUBA1C LDHA H2AFZ
# listB size=2001, e.g. SDR42E1 WDR83OS DHDH
# Intersection size=34, e.g. RPS3 TUBB4B RPS2
# Union size=2307, e.g. TUBA1C LDHA H2AFZ
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18498 306
# inB   1967  34
# Overlapping p-value=0.43
# Odds ratio=1.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=340, e.g. TUBA1C LDHA H2AFZ
# listB size=2001, e.g. NIPSNAP3B LOC386597 CACNA2D2
# Intersection size=27, e.g. SLIRP FTO UBE2T
# Union size=2314, e.g. TUBA1C LDHA H2AFZ
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18491 313
# inB   1974  27
# Overlapping p-value=0.88
# Odds ratio=0.8
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=340, e.g. TUBA1C LDHA H2AFZ
# listB size=2001, e.g. NIPSNAP3A CACNA2D2 CACNA2D3
# Intersection size=35, e.g. PTTG1 PRC1 HMGB1
# Union size=2306, e.g. TUBA1C LDHA H2AFZ
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18499 305
# inB   1966  35
# Overlapping p-value=0.36
# Odds ratio=1.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=340, e.g. TUBA1C LDHA H2AFZ
# listB size=2001, e.g. POLR2J4 ENDOG NIPSNAP3A
# Intersection size=41, e.g. NDUFAB1 PSMB4 RRM2
# Union size=2300, e.g. TUBA1C LDHA H2AFZ
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18505 299
# inB   1960  41
# Overlapping p-value=0.077
# Odds ratio=1.3
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=340, e.g. TUBA1C LDHA H2AFZ
# listB size=2001, e.g. NIPSNAP3A CACNA2D1 DHDH
# Intersection size=41, e.g. NME1 PHGDH CWC15
# Union size=2300, e.g. TUBA1C LDHA H2AFZ
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18505 299
# inB   1960  41
# Overlapping p-value=0.077
# Odds ratio=1.3
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=340, e.g. TUBA1C LDHA H2AFZ
# listB size=2001, e.g. CACNA2D1 BTBD11 LARP4
# Intersection size=34, e.g. NME1 SNRPB CFL1
# Union size=2307, e.g. TUBA1C LDHA H2AFZ
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18498 306
# inB   1967  34
# Overlapping p-value=0.43
# Odds ratio=1.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=340, e.g. TUBA1C LDHA H2AFZ
# listB size=2001, e.g. KRTDAP CACNA2D3 MIR3917
# Intersection size=41, e.g. NME1 PHGDH CWC15
# Union size=2300, e.g. TUBA1C LDHA H2AFZ
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18505 299
# inB   1960  41
# Overlapping p-value=0.077
# Odds ratio=1.3
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=340, e.g. TUBA1C LDHA H2AFZ
# listB size=2001, e.g. CACNA2D2 BTBD11 RPL17-C18ORF32
# Intersection size=17, e.g. CWC15 ARL6IP1 PBK
# Union size=2324, e.g. TUBA1C LDHA H2AFZ
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18481 323
# inB   1984  17
# Overlapping p-value=1
# Odds ratio=0.5
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=345, e.g. Gm5805 Ppia Pisd
# listB size=3068, e.g. RC3H2 KIAA1586 BTBD10
# Intersection size=1, e.g.
# Union size=3412, e.g. Gm5805 Ppia Pisd
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 17393 344
# inB   3067   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=345, e.g. Gm5805 Ppia Pisd
# listB size=2001, e.g. NIPSNAP3B RC3H2 PRKAB1
# Intersection size=1, e.g.
# Union size=2345, e.g. Gm5805 Ppia Pisd
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18460 344
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=307, e.g. Pou5f1 Tdgf1 Dppa5a
# listB size=3068, e.g. RC3H2 KIAA1586 BTBD10
# Intersection size=1, e.g.
# Union size=3374, e.g. Pou5f1 Tdgf1 Dppa5a
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 17431 306
# inB   3067   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=307, e.g. Pou5f1 Tdgf1 Dppa5a
# listB size=2001, e.g. NIPSNAP3B RC3H2 PRKAB1
# Intersection size=1, e.g.
# Union size=2307, e.g. Pou5f1 Tdgf1 Dppa5a
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18498 306
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=289, e.g. Myl7 Mup19 Clu
# listB size=617, e.g. EFCAB4A UNC13D LINS
# Intersection size=1, e.g.
# Union size=905, e.g. Myl7 Mup19 Clu
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19900 288
# inB    616   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=289, e.g. Myl7 Mup19 Clu
# listB size=149, e.g. ZNF563 AOC4 SMARCA1
# Intersection size=2, e.g. C3
# Union size=436, e.g. Myl7 Mup19 Clu
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20369 287
# inB    147   2
# Overlapping p-value=0.62
# Odds ratio=1.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=289, e.g. Myl7 Mup19 Clu
# listB size=1393, e.g. STARD3 SND1 ENDOG
# Intersection size=1, e.g.
# Union size=1681, e.g. Myl7 Mup19 Clu
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19124 288
# inB   1392   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=294, e.g. BC094435 Fth1 Pcdhb9
# listB size=2911, e.g. ATE1 SDR42E1 POLR2J4
# Intersection size=1, e.g.
# Union size=3204, e.g. BC094435 Fth1 Pcdhb9
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 17601 293
# inB   2910   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=294, e.g. BC094435 Fth1 Pcdhb9
# listB size=2346, e.g. ATE1 RC3H2 FRS3
# Intersection size=1, e.g.
# Union size=2639, e.g. BC094435 Fth1 Pcdhb9
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18166 293
# inB   2345   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=294, e.g. BC094435 Fth1 Pcdhb9
# listB size=1916, e.g. POLR2J3 FNBP1 CCZ1B
# Intersection size=1, e.g.
# Union size=2209, e.g. BC094435 Fth1 Pcdhb9
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18596 293
# inB   1915   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=294, e.g. BC094435 Fth1 Pcdhb9
# listB size=742, e.g. B3GALNT2 GLYCTK ZNF281
# Intersection size=1, e.g.
# Union size=1035, e.g. BC094435 Fth1 Pcdhb9
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19770 293
# inB    741   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=294, e.g. BC094435 Fth1 Pcdhb9
# listB size=1773, e.g. RC3H2 C20ORF196 FRS2
# Intersection size=1, e.g.
# Union size=2066, e.g. BC094435 Fth1 Pcdhb9
# Genome size=20805
# # Contingency Table:
#       notA inA
# ...
# notB 18497 307
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=375, e.g. Hsph1 Polr2k Ifng
# listB size=250, e.g. HES7 HSPA1L TYW3
# Intersection size=1, e.g.
# Union size=624, e.g. Hsph1 Polr2k Ifng
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20181 374
# inB    249   1
# Overlapping p-value=0.99
# Odds ratio=0.2
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=230, e.g. Hba-a1 Gsn Pdk4
# listB size=1024, e.g. POLR2J4 B3GALNT2 ENDOG
# Intersection size=1, e.g.
# Union size=1253, e.g. Hba-a1 Gsn Pdk4
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19552 229
# inB   1023   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=230, e.g. Hba-a1 Gsn Pdk4
# listB size=116, e.g. STARD7 TRAP1 HUS1
# Intersection size=1, e.g.
# Union size=345, e.g. Hba-a1 Gsn Pdk4
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20460 229
# inB    115   1
# Overlapping p-value=0.73
# Odds ratio=0.8
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=296, e.g. Lpl Umod Ly6a
# listB size=1024, e.g. POLR2J4 B3GALNT2 ENDOG
# Intersection size=1, e.g.
# Union size=1319, e.g. Lpl Umod Ly6a
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19486 295
# inB   1023   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=296, e.g. Lpl Umod Ly6a
# listB size=116, e.g. STARD7 TRAP1 HUS1
# Intersection size=1, e.g.
# Union size=411, e.g. Lpl Umod Ly6a
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20394 295
# inB    115   1
# Overlapping p-value=0.81
# Odds ratio=0.6
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=141, e.g. Mt2 Gnmt Hamp2
# listB size=2001, e.g. POLR2J2 FNBP4 POLR2J3
# Intersection size=1, e.g.
# Union size=2141, e.g. Mt2 Gnmt Hamp2
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18664 140
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=141, e.g. Mt2 Gnmt Hamp2
# listB size=2001, e.g. POLR2J2 ANKFY1 LARP4
# Intersection size=1, e.g.
# Union size=2141, e.g. Mt2 Gnmt Hamp2
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18664 140
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=141, e.g. Mt2 Gnmt Hamp2
# listB size=2001, e.g. POLR2J4 ENDOG POLR2J3
# Intersection size=1, e.g.
# Union size=2141, e.g. Mt2 Gnmt Hamp2
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18664 140
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=141, e.g. Mt2 Gnmt Hamp2
# listB size=2001, e.g. CASP8AP2 MIR3917 FAM158A
# Intersection size=1, e.g.
# Union size=2141, e.g. Mt2 Gnmt Hamp2
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18664 140
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=141, e.g. Mt2 Gnmt Hamp2
# listB size=2001, e.g. ENDOG FNBP4 POLR2J3
# Intersection size=1, e.g.
# Union size=2141, e.g. Mt2 Gnmt Hamp2
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18664 140
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=141, e.g. Mt2 Gnmt Hamp2
# listB size=2001, e.g. POLR2J4 ENDOG FNBP4
# Intersection size=1, e.g.
# Union size=2141, e.g. Mt2 Gnmt Hamp2
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18664 140
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=248, e.g. Tuba1a Tagln Tmsb4x
# listB size=2828, e.g. ENDOG ANKFY1 ESX1
# Intersection size=1, e.g.
# Union size=3075, e.g. Tuba1a Tagln Tmsb4x
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 17730 247
# inB   2827   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=248, e.g. Tuba1a Tagln Tmsb4x
# listB size=564, e.g. LOC441177 ESX1 CRAMP1L
# Intersection size=1, e.g.
# Union size=811, e.g. Tuba1a Tagln Tmsb4x
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19994 247
# inB    563   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=248, e.g. Tuba1a Tagln Tmsb4x
# listB size=2001, e.g. FNBP1 BTBD17 LARP6
# Intersection size=1, e.g.
# Union size=2248, e.g. Tuba1a Tagln Tmsb4x
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18557 247
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=190, e.g. Ctla2a Ctla2b Hbb-bh1
# listB size=811, e.g. 8430419L09RIK ANKFY1 DHDH
# Intersection size=1, e.g.
# Union size=1000, e.g. Ctla2a Ctla2b Hbb-bh1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19805 189
# inB    810   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=190, e.g. Ctla2a Ctla2b Hbb-bh1
# listB size=886, e.g. ATE1 8430419L09RIK ANKFY1
# Intersection size=1, e.g.
# Union size=1075, e.g. Ctla2a Ctla2b Hbb-bh1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19730 189
# inB    885   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=190, e.g. Ctla2a Ctla2b Hbb-bh1
# listB size=2291, e.g. ATE1 GM10432 BTBD19
# Intersection size=1, e.g.
# Union size=2480, e.g. Ctla2a Ctla2b Hbb-bh1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18325 189
# inB   2290   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=190, e.g. Ctla2a Ctla2b Hbb-bh1
# listB size=870, e.g. HEXIM2 STARD4 1700019O17RIK
# Intersection size=1, e.g.
# Union size=1059, e.g. Ctla2a Ctla2b Hbb-bh1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19746 189
# inB    869   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=190, e.g. Ctla2a Ctla2b Hbb-bh1
# listB size=2001, e.g. ENDOG FNBP4 ANKFY1
# Intersection size=1, e.g.
# Union size=2190, e.g. Ctla2a Ctla2b Hbb-bh1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18615 189
# inB   2000   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=190, e.g. Ctla2a Ctla2b Hbb-bh1
# listB size=0, e.g.
# Intersection size=0, e.g.
# Union size=190, e.g. Ctla2a Ctla2b Hbb-bh1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20615 190
# inB      0   0
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=91, e.g. AY036118 Actg1 Arl2bp
# listB size=3943, e.g. FNBP4 TEX30 FNBP1
# Intersection size=1, e.g.
# Union size=4033, e.g. AY036118 Actg1 Arl2bp
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 16772  90
# inB   3942   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=91, e.g. AY036118 Actg1 Arl2bp
# listB size=2995, e.g. HEXIM2 CASP8AP2 FNBP4
# Intersection size=1, e.g.
# Union size=3085, e.g. AY036118 Actg1 Arl2bp
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 17720  90
# inB   2994   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=91, e.g. AY036118 Actg1 Arl2bp
# listB size=0, e.g.
# Intersection size=0, e.g.
# Union size=91, e.g. AY036118 Actg1 Arl2bp
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20714  91
# inB      0   0
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=91, e.g. AY036118 Actg1 Arl2bp
# listB size=716, e.g. CDK19 GAMT HES7
# Intersection size=1, e.g.
# Union size=806, e.g. AY036118 Actg1 Arl2bp
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19999  90
# inB    715   1
# Overlapping p-value=0.96
# Odds ratio=0.3
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=91, e.g. AY036118 Actg1 Arl2bp
# listB size=0, e.g.
# Intersection size=0, e.g.
# Union size=91, e.g. AY036118 Actg1 Arl2bp
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20714  91
# inB      0   0
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=91, e.g. AY036118 Actg1 Arl2bp
# listB size=728, e.g. UNC13D NIPSNAP3A HEXIM1
# Intersection size=1, e.g.
# Union size=818, e.g. AY036118 Actg1 Arl2bp
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19987  90
# inB    727   1
# Overlapping p-value=0.96
# Odds ratio=0.3
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=222, e.g. Hist1h3i B230118H07Rik Hist1h4m
# listB size=1988, e.g. GM10432 BTBD17 B230219D22RIK
# Intersection size=2, e.g. 15-Sep
# Union size=2208, e.g. Hist1h3i B230118H07Rik Hist1h4m
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18597 220
# inB   1986   2
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=222, e.g. Hist1h3i B230118H07Rik Hist1h4m
# listB size=1414, e.g. SDR42E1 POLR2J4 B3GALNT2
# Intersection size=1, e.g.
# Union size=1635, e.g. Hist1h3i B230118H07Rik Hist1h4m
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19170 221
# inB   1413   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=429, e.g. Erdr1 Gm10260 Rps6-ps4
# listB size=1988, e.g. GM10432 BTBD17 B230219D22RIK
# Intersection size=2, e.g. AI467606
# Union size=2415, e.g. Erdr1 Gm10260 Rps6-ps4
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18390 427
# inB   1986   2
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=429, e.g. Erdr1 Gm10260 Rps6-ps4
# listB size=1414, e.g. SDR42E1 POLR2J4 B3GALNT2
# Intersection size=1, e.g.
# Union size=1842, e.g. Erdr1 Gm10260 Rps6-ps4
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 18963 428
# inB   1413   1
# Overlapping p-value=1
# Odds ratio=0.0
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=236, e.g. Cbr2 Hp Igfbp2
# listB size=350, e.g. TMEM194A RBFOX2 SMARCA1
# Intersection size=1, e.g.
# Union size=585, e.g. Cbr2 Hp Igfbp2
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20220 235
# inB    349   1
# Overlapping p-value=0.98
# Odds ratio=0.2
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=236, e.g. Cbr2 Hp Igfbp2
# listB size=1411, e.g. LINS CADM2 WDR83OS
# Intersection size=1, e.g.
# Union size=1646, e.g. Cbr2 Hp Igfbp2
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19159 235
# inB   1410   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=163, e.g. BC094435 H2afy Erdr1
# listB size=1159, e.g. ZNF282 RFX4 ZFYVE20
# Intersection size=1, e.g.
# Union size=1321, e.g. BC094435 H2afy Erdr1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19484 162
# inB   1158   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=163, e.g. BC094435 H2afy Erdr1
# listB size=105, e.g. CCDC159 WDR74 C20ORF197
# Intersection size=1, e.g.
# Union size=267, e.g. BC094435 H2afy Erdr1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 20538 162
# inB    104   1
# Overlapping p-value=0.56
# Odds ratio=1.2
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=163, e.g. BC094435 H2afy Erdr1
# listB size=858, e.g. MIR143HG ENDOG LUM
# Intersection size=1, e.g.
# Union size=1020, e.g. BC094435 H2afy Erdr1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19785 162
# inB    857   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=163, e.g. BC094435 H2afy Erdr1
# listB size=1286, e.g. STARD4 C20ORF29 TYW3
# Intersection size=1, e.g.
# Union size=1448, e.g. BC094435 H2afy Erdr1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19357 162
# inB   1285   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=163, e.g. BC094435 H2afy Erdr1
# listB size=1099, e.g. POLR2J4 ZNF285 C5ORF15
# Intersection size=1, e.g.
# Union size=1261, e.g. BC094435 H2afy Erdr1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19544 162
# inB   1098   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=163, e.g. BC094435 H2afy Erdr1
# listB size=1024, e.g. SDR42E1 POLR2J4 POLR2J3
# Intersection size=1, e.g.
# Union size=1186, e.g. BC094435 H2afy Erdr1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19619 162
# inB   1023   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
# Detailed information about this GeneOverlap object:
# listA size=163, e.g. BC094435 H2afy Erdr1
# listB size=1224, e.g. GM10432 BTBD17 4632428N05RIK
# Intersection size=1, e.g.
# Union size=1386, e.g. BC094435 H2afy Erdr1
# Genome size=20805
# # Contingency Table:
#       notA inA
# notB 19419 162
# inB   1223   1
# Overlapping p-value=1
# Odds ratio=0.1
# Overlap tested using Fisher's exact test (alternative=greater)
# Jaccard Index=0.0
