# %%
# Merge Creeds and Encode metadata file to identify the TF data overlaping between them.

# %%
import pandas as pd

# %%
# CREEDS metadata
df = pd.read_csv('/Users/lab/Desktop/creeds_metadata_ko.csv')
df.head()
# Out:
#           id                                       cell_type chdir_norm  \
# 0  gene_2005  liver tissue,  n-nitrosodiethylamine treatment        NaN
# 1  gene_2006   liver tissue, n-nitrosodiethylamine treatment        NaN
# 2  gene_2007   liver tissue, n-nitrosodiethylamine treatment        NaN
# 3  gene_2000            primary hepatocytes, HGF stimulation        NaN
# 4  gene_2001            primary hepatocytes, HGF stimulation        NaN
#
#                                             ctrl_ids curator   geo_id  \
# 0  GSM217220|GSM217222|GSM217224|GSM217234|GSM217235  Andrew  GSE8747
# 1  GSM217219|GSM217221|GSM217223|GSM217229|GSM217230  Andrew  GSE8747
# 2  GSM217201|GSM217203|GSM217205|GSM217207|GSM217209  Andrew  GSE8747
# 3  GSM100094|GSM100095|GSM100096|GSM100097|GSM100...  Andrew  GSE4451
# 4  GSM100100|GSM100101|GSM100102|GSM100103|GSM100...  Andrew  GSE4451
#
#   hs_gene_symbol mm_gene_symbol organism  \
# 0            MET            Met    mouse
# 1            MET            Met    mouse
# 2            MET            Met    mouse
# 3            MET            Met    mouse
# 4            MET            Met    mouse
#
#                                             pert_ids pert_type platform  \
# 0  GSM217225|GSM217227|GSM217236|GSM217237|GSM217238  knockout  GPL4200
# 1  GSM217226|GSM217228|GSM217231|GSM217232|GSM217233  knockout  GPL4200
# 2            GSM217211|GSM217213|GSM217216|GSM217218  knockout  GPL4200
# 3  GSM100088|GSM100089|GSM100090|GSM100091|GSM100...  knockout  GPL1536
# 4  GSM100051|GSM100053|GSM100106|GSM100107|GSM100...  knockout  GPL1536
#
#    version
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
# ENCODE data
#dfe = pd.read_csv('/Users/Carol/Desktop/arquivoNovo/ENCODE_2015_correction.csv',low_memory=False)
dfenc = pd.read_csv('/Users/lab/Desktop/encodes/arquivoNovo/mergedEncodeTSSs/clean/merged_enc2500.csvclean.csv', sep=',',low_memory=False)
dfenc.head()
#novo arquivo
# Out:
#   ARID1B_K562 ARID3A_HepG2   ARID3A_MCF7 ARID3A_K562 ARNT_K562 ATF1_K562  \
# 0      ATP5SL     LBX2-AS1       METTL25       SSBP1     TAF1A   FASTKD1
# 1        ARF5         PUS1           EPX     EIF2AK4    ZNF548    SNAP25
# 2   LINC01386       ZNF708    TIPARP-AS1       CUL4A     KDM5A  STAG3L5P
# 3    SLC16A13       ZNF614  LOC101928009    C12orf60    SNHG20     SNHG8
# 4    SLC39A13       ZC3H13         VSIG2        STX8   HCFC1R1     SRP14
#
#   ATF2_GM12878 ATF3_K562 ATF3_liver ATF3_liver.1     ...     ZNF384_K562  \
# 0       TRIM17  C16orf70    MIR4286       ZNF593     ...            PIGW
# 1         CGB1     SUMO3     DPAGT1        ZCRB1     ...      PTGES2-AS1
# 2       ODF3L1     NUBPL      RDH11    MIR3913-1     ...          YTHDC1
# 3         G6PD      GPAM      LCE2C         PLK3     ...            BRD2
# 4        TRIP6    ANGEL1  LINC01128       SNHG17     ...            COG8
#
#   ZNF384_HepG2 ZNF407_K562 ZNF592_MCF7 ZNF592_MCF7.1   ZNF687_MCF7  \
# 0        MIPEP      SLC2A5   DSCAM-AS1      FAM133DP  LOC101927272
# 1        FOXD2     METTL7B     C1QTNF6          COA4         NAA15
# 2         TUFM  HSPE1-MOB4        POP7         NAT14         FBXO6
# 3   SNORD114-7       PEX16       USP30         RAB4B           BRE
# 4        TAAR3     MIR7703    ATE1-AS1        ARFIP2         NEIL2
#
#   ZSCAN29_K562 ZZZ3_GM12878 ZZZ3_K562 ZZZ3_HeLaS3
# 0        DCAF6        REXO4     MYLPF        ISY1
# 1        NR2F1     C17orf75    CDKN1B        NREP
# 2      GATAD2A     MRPS31P5     ZGRF1    C17orf75
# 3      SEPT7P9    NME1-NME2  SLC25A25  ZBTB20-AS4
# 4         LRR1        TOP3B  SNORD104       BRWD3
#
# [5 rows x 948 columns]

# %%
enclist = dfenc.columns.tolist()
dfenc2 = pd.DataFrame(enclist)
dfenc2.columns = ['name']
dfenc2.head()
# Out:
#            name
# 0   ARID1B_K562
# 1  ARID3A_HepG2
# 2   ARID3A_MCF7
# 3   ARID3A_K562
# 4     ARNT_K562

# %%
dfenc2['hs_gene_symbol'] = dfenc2['name'].str.split('_').str[-2]
dfenc2.head()
# Out:
#            name hs_gene_symbol
# 0   ARID1B_K562         ARID1B
# 1  ARID3A_HepG2         ARID3A
# 2   ARID3A_MCF7         ARID3A
# 3   ARID3A_K562         ARID3A
# 4     ARNT_K562           ARNT

# %%
# merge both files - gene symbol -
final = pd.merge(df,dfenc2, how = 'inner', on =['hs_gene_symbol'])
final.head()
# Out:
#           id                    cell_type chdir_norm  \
# 0  gene_2034  CD4+ T cell, TCR stimulated        NaN
# 1  gene_2034  CD4+ T cell, TCR stimulated        NaN
# 2  gene_2034  CD4+ T cell, TCR stimulated        NaN
# 3  gene_2034  CD4+ T cell, TCR stimulated        NaN
# 4  gene_2033                  CD4+ T cell        NaN
#
#                                   ctrl_ids curator    geo_id hs_gene_symbol  \
# 0  GSM798461|GSM798462|GSM798463|GSM798464  Andrew  GSE32224         TRIM28
# 1  GSM798461|GSM798462|GSM798463|GSM798464  Andrew  GSE32224         TRIM28
# 2  GSM798461|GSM798462|GSM798463|GSM798464  Andrew  GSE32224         TRIM28
# 3  GSM798461|GSM798462|GSM798463|GSM798464  Andrew  GSE32224         TRIM28
# 4  GSM798457|GSM798458|GSM798459|GSM798460  Andrew  GSE32224         TRIM28
#
#   mm_gene_symbol organism                                 pert_ids pert_type  \
# 0         Trim28    mouse  GSM798469|GSM798470|GSM798471|GSM798472  knockout
# 1         Trim28    mouse  GSM798469|GSM798470|GSM798471|GSM798472  knockout
# 2         Trim28    mouse  GSM798469|GSM798470|GSM798471|GSM798472  knockout
# 3         Trim28    mouse  GSM798469|GSM798470|GSM798471|GSM798472  knockout
# 4         Trim28    mouse  GSM798465|GSM798466|GSM798467|GSM798468  knockout
#
#   platform  version           name
# 0  GPL7202        1    TRIM28_K562
# 1  GPL7202        1  TRIM28_HEK293
# 2  GPL7202        1    TRIM28_U2OS
# 3  GPL7202        1  TRIM28_K562.1
# 4  GPL7202        1    TRIM28_K562

# %%
dff = final[['id', 'hs_gene_symbol','name']]
dff
# Out:
#             id hs_gene_symbol                  name
# 0    gene_2034         TRIM28           TRIM28_K562
# 1    gene_2034         TRIM28         TRIM28_HEK293
# 2    gene_2034         TRIM28           TRIM28_U2OS
# 3    gene_2034         TRIM28         TRIM28_K562.1
# 4    gene_2033         TRIM28           TRIM28_K562
# 5    gene_2033         TRIM28         TRIM28_HEK293
# 6    gene_2033         TRIM28           TRIM28_U2OS
# 7    gene_2033         TRIM28         TRIM28_K562.1
# 8    gene_2032         TRIM28           TRIM28_K562
# 9    gene_2032         TRIM28         TRIM28_HEK293
# 10   gene_2032         TRIM28           TRIM28_U2OS
# 11   gene_2032         TRIM28         TRIM28_K562.1
# 12   gene_2031         TRIM24           TRIM24_K562
# 13   gene_2031         TRIM24         TRIM24_K562.1
# 14    gene_510          GATA4           GATA4_HepG2
# 15    gene_356          GATA4           GATA4_HepG2
# 16   gene_2656          GATA4           GATA4_HepG2
# 17   gene_1261         NFE2L2           NFE2L2_A549
# 18   gene_1261         NFE2L2          NFE2L2_HepG2
# 19   gene_1261         NFE2L2         NFE2L2_HeLaS3
# 20   gene_1260         NFE2L2           NFE2L2_A549
# 21   gene_1260         NFE2L2          NFE2L2_HepG2
# 22   gene_1260         NFE2L2         NFE2L2_HeLaS3
# 23   gene_1263         NFE2L2           NFE2L2_A549
# 24   gene_1263         NFE2L2          NFE2L2_HepG2
# 25   gene_1263         NFE2L2         NFE2L2_HeLaS3
# 26   gene_1262         NFE2L2           NFE2L2_A549
# 27   gene_1262         NFE2L2          NFE2L2_HepG2
# 28   gene_1262         NFE2L2         NFE2L2_HeLaS3
# 29   gene_1258         NFE2L2           NFE2L2_A549
# ..         ...            ...                   ...
# 221  gene_2613          ESRRA         ESRRA_GM12878
# 222  gene_2613          ESRRA            ESRRA_MCF7
# 223  gene_2613          ESRRA            ESRRA_K562
# 224  gene_2159          ESRRA            ESRRA_A549
# 225  gene_2159          ESRRA         ESRRA_GM12878
# 226  gene_2159          ESRRA            ESRRA_MCF7
# 227  gene_2159          ESRRA            ESRRA_K562
# 228  gene_2995          HNF1A           HNF1A_HepG2
# 229  gene_1051           MBD2             MBD2_MCF7
# 230  gene_2150           NRF1            NRF1_HepG2
# 231  gene_2150           NRF1            NRF1_SKNSH
# 232  gene_2150           NRF1           NRF1_HeLaS3
# 233  gene_2150           NRF1           NRF1_H1hESC
# 234  gene_2150           NRF1             NRF1_K562
# 235  gene_2150           NRF1          NRF1_GM12878
# 236  gene_2150           NRF1          NRF1_HepG2.1
# 237  gene_2150           NRF1           NRF1_K562.1
# 238  gene_2150           NRF1             NRF1_MCF7
# 239  gene_2150           NRF1           NRF1_K562.2
# 240  gene_2150           NRF1           NRF1_K562.3
# 241  gene_1332          SUZ12          SUZ12_H1hESC
# 242  gene_1332          SUZ12          SUZ12_NT2/D1
# 243  gene_1332          SUZ12         SUZ12_HEK293T
# 244  gene_1332          SUZ12            SUZ12_K562
# 245  gene_1332          SUZ12           SUZ12_HepG2
# 246  gene_1447           TAL1             TAL1_K562
# 247  gene_1062          GATA1            GATA1_K562
# 248  gene_1062          GATA1    GATA1_erythroblast
# 249  gene_1062          GATA1  GATA1_erythroblast.1
# 250  gene_1062          GATA1          GATA1_K562.1
#
# [251 rows x 3 columns]

# %%
dff['identification'] = dff[['hs_gene_symbol', 'name']].apply(lambda x: '_'.join(x), axis=1)
dff.duplicated()
dff.head()
#dff.to_csv()
# Out:
# /Users/lab/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#           id hs_gene_symbol           name        identification
# 0  gene_2034         TRIM28    TRIM28_K562    TRIM28_TRIM28_K562
# 1  gene_2034         TRIM28  TRIM28_HEK293  TRIM28_TRIM28_HEK293
# 2  gene_2034         TRIM28    TRIM28_U2OS    TRIM28_TRIM28_U2OS
# 3  gene_2034         TRIM28  TRIM28_K562.1  TRIM28_TRIM28_K562.1
# 4  gene_2033         TRIM28    TRIM28_K562    TRIM28_TRIM28_K562

# %%
# Sample IDs the overlap 
dff['sample'] = dff[['name','id']].apply(lambda x: '_'.join(x), axis=1)
dff.head()
# Out:
# /Users/lab/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#           id hs_gene_symbol           name        identification  \
# 0  gene_2034         TRIM28    TRIM28_K562    TRIM28_TRIM28_K562
# 1  gene_2034         TRIM28  TRIM28_HEK293  TRIM28_TRIM28_HEK293
# 2  gene_2034         TRIM28    TRIM28_U2OS    TRIM28_TRIM28_U2OS
# 3  gene_2034         TRIM28  TRIM28_K562.1  TRIM28_TRIM28_K562.1
# 4  gene_2033         TRIM28    TRIM28_K562    TRIM28_TRIM28_K562
#
#                     sample
# 0    TRIM28_K562_gene_2034
# 1  TRIM28_HEK293_gene_2034
# 2    TRIM28_U2OS_gene_2034
# 3  TRIM28_K562.1_gene_2034
# 4    TRIM28_K562_gene_2033

# %%
# Drop multiple columns keep only what it will be useful
sample = dff.drop(['hs_gene_symbol','name','identification'], axis=1)

sample.head()
# Out:
#           id                   sample
# 0  gene_2034    TRIM28_K562_gene_2034
# 1  gene_2034  TRIM28_HEK293_gene_2034
# 2  gene_2034    TRIM28_U2OS_gene_2034
# 3  gene_2034  TRIM28_K562.1_gene_2034
# 4  gene_2033    TRIM28_K562_gene_2033

# %%
# Acessing data # Defining overlap to be tested
# Create a dataframe for tested where row has list A| listB

# Append Columns to "matrix", 
go = []
for row in dff['id']:
    a = 'go.obj <- newGeneOverlap(encode$%s' %(row)
    go.append(a)
go = pd.DataFrame(go)
# go.head()

gob = []
for row in dff['identification']:
    b = 'creeds$%s'%(row) 
    gob.append(b)
gob = pd.DataFrame(gob)
# gob.head()

## Concatenayed Columns
gobjectko = pd.concat([go,gob],axis=1)
gobjectko.columns = ['A', 'B']
gobjectko.to_csv('gobjectko.csv',index=False) # save it to open in R in the other tab, since R stopped working here

gobjectko.head()
# Out:
#                                            A                            B
# 0  go.obj <- newGeneOverlap(encode$gene_2034    creeds$TRIM28_TRIM28_K562
# 1  go.obj <- newGeneOverlap(encode$gene_2034  creeds$TRIM28_TRIM28_HEK293
# 2  go.obj <- newGeneOverlap(encode$gene_2034    creeds$TRIM28_TRIM28_U2OS
# 3  go.obj <- newGeneOverlap(encode$gene_2034  creeds$TRIM28_TRIM28_K562.1
# 4  go.obj <- newGeneOverlap(encode$gene_2033    creeds$TRIM28_TRIM28_K562

# %% [markdown]
# # Overlap output

# %%
# Clean/ Organize/ Standardize output from gene overlap comparisons.

# %%
import re

# List of words to delete
delete = ['size','#','\n','Index',]

# Data to keep 
words = ['listA', 'listB','Intersection','Overlapping p-value', 'Odds ratio','Union','Jaccard Index']


rep = re.compile(r'|'.join(delete))
keep = re.compile(r'|'.join(words))

data = []
with open('/Users/Carol/Desktop/arquivoNovo/KO/overlapKOdn.txt') as f1:
    for line in f1:
        if keep.search(line):
            # replace all unwanted substrings
            line = rep.sub("", line.lstrip())     
            line=line.split('=')
#             print(line)
            data.append(line)


df = pd.DataFrame(data)

df.columns = ['ca', 'value']
df['value'] = df.value.str.split(',').str.get(0)  # split value column at the , and que left side of string


df.head()
# Out:
#                     ca value
# 0               listA    326
# 1               listB   2000
# 2        Intersection      0
# 3               Union   2326
# 4  Overlapping p-value     1

# %%
# Coisas que podem ser uteis
listA = df[df['ca'].str.contains("listA")]
listB = df[df['ca'].str.contains("listB")]
intersection = df[df['ca'].str.contains("Intersection")]
union = df[df['ca'].str.contains("Union")]
pval= df[df['ca'].str.contains("Overlapping p-value")]
odds= df[df['ca'].str.contains("Odds ratio")]
#jaccard= df[df['ca'].str.contains("Jaccard Index")]

# %%
# listA.columns = ['value','listA']
# listA = listA.T
# listA = listA.T
# listA1 = listA.reset_index(drop=True) # Reset index to be able to concatenate it easily
# listA1.head()

# %%
listA.columns = ['value','listA']
listA = listA.T
listA = listA.T
listA1 = listA.reset_index(drop=True) # Reset index to be able to concatenate it easily
listA1.head()

listB.columns = ['value','listB']
listB = listB.T
listB = listB.T
listB1 = listB.reset_index(drop=True)
listB1.head()

intersection.columns = ['value','intersection']
intersection = intersection.T
intersection = intersection.T
intersection1 = intersection.reset_index(drop=True)
intersection1.head()

union.columns = ['value','union']
union = union.T
union = union.T
union1 = union.reset_index(drop=True)
union1.head()

pval.columns = ['value','pval']
pval = pval.T
pval = pval.T
pval1 = pval.reset_index(drop=True)
pval1.head()

odds.columns = ['value','odds']
odds = odds.T
odds = odds.T
odds1 = odds.reset_index(drop=True)
odds1.head()

jaccard.columns = ['value','jaccard']
jaccard = jaccard.T
jaccard = jaccard.T
jaccard = jaccard.reset_index(drop=True)
#jaccard.head()

# %%
concat = pd.concat([sample,listA1,listB1,intersection1,union1,pval1,odds1],axis=1)
concat.head()
# Out:
#                     sample   value listA   value listB          value  \
# 0    TRIM28_U2OS_gene_2034  listA    326  listB   2000  Intersection
# 1  TRIM28_HEK293_gene_2034  listA    326  listB   2000  Intersection
# 2    TRIM28_K562_gene_2034  listA    326  listB   2000  Intersection
# 3    TRIM28_U2OS_gene_2033  listA    294  listB   2000  Intersection
# 4  TRIM28_HEK293_gene_2033  listA    294  listB   2000  Intersection
#
#   intersection   value union                value pval       value odds
# 0            0  Union   2326  Overlapping p-value    1  Odds ratio  0.0
# 1            0  Union   2326  Overlapping p-value    1  Odds ratio  0.0
# 2            0  Union   2326  Overlapping p-value    1  Odds ratio  0.0
# 3            0  Union   2294  Overlapping p-value    1  Odds ratio  0.0
# 4            0  Union   2294  Overlapping p-value    1  Odds ratio  0.0

# %%
clean = concat.drop('value',axis=1)
clean.head()
# Out:
#                     sample listA listB intersection union pval odds
# 0    TRIM28_U2OS_gene_2034   326  2000            0  2326    1  0.0
# 1  TRIM28_HEK293_gene_2034   326  2000            0  2326    1  0.0
# 2    TRIM28_K562_gene_2034   326  2000            0  2326    1  0.0
# 3    TRIM28_U2OS_gene_2033   294  2000            0  2294    1  0.0
# 4  TRIM28_HEK293_gene_2033   294  2000            0  2294    1  0.0
