# %%
library(GeneOverlap)

# %%
# Load library
library(GeneOverlap)

# Read in R tables

encodeA <- read.table('/Users/Carol/Desktop/arquivoNovo/mergedEncodeTSSs/clean/cleanpt/merged_enc9500pt.csv',sep=',', header=TRUE)

#na verdade e' o creeds
encodeB <- read.table('/Users/Carol/Desktop/arquivoNovo/creeds_full_up_gene_pronto_p_ir_list_overlap.csv',sep=',', header=TRUE)

#creedsup <- 'Users/Carol/Desktop/arquivoNovo/creeds_full_up_gene_pronto_p_ir_list_overlap.csv' 
#creedsdn <- 'Users/Carol/Desktop/arquivoNovo/creeds_full_dn_gene_pronto_p_ir_list_overlap.csv' 

gobject <- read.table('/Users/Carol/Desktop/arquivoNovo/gobject.csv',sep=',', header=TRUE)

# summary(gobject)
#nrow(gobject)

sapply(encodeA,length)
sapply(encodeB,length)
# Out:
#                                 ARID1B_K562
#                                        2000
#                                ARID3A_HepG2
#                                        2000
#                                ARID3A_MCF.7
#                                        2000
#                                 ARID3A_K562
#                                        2000
#                                   ARNT_K562
#                                        2000
#                                   ATF1_K562
#                                        2000
#                                ATF2_GM12878
#                                        2000
#                                   ATF3_K562
#                                        2000
#                                  ATF3_liver
#                                        2000
#                                ATF3_liver.1
#                                        2000
#                               BACH1_H1.hESC
# ...

# %%
library(GeneOverlap)

# %%
summary(gobject)
# Out:
#                                                   A
#  go.obj <- newGeneOverlap(encodeA$ARID1B_K562_hg19 :  1
#  go.obj <- newGeneOverlap(encodeA$ARID3A_HepG2_hg19:  1
#  go.obj <- newGeneOverlap(encodeA$ARID3A_K562_hg19 :  1
#  go.obj <- newGeneOverlap(encodeA$ARID3A_MCF7_hg19 :  1
#  go.obj <- newGeneOverlap(encodeA$ARNT_K562_hg19   :  1
#  go.obj <- newGeneOverlap(encodeA$ATF1_K562_hg19   :  1
#  (Other)                                           :929
#                          B
#  encodeB$ARID1B_K562_hg19 :  1
#  encodeB$ARID3A_HepG2_hg19:  1
#  encodeB$ARID3A_K562_hg19 :  1
#  encodeB$ARID3A_MCF7_hg19 :  1
#  encodeB$ARNT_K562_hg19   :  1
#  encodeB$ATF1_K562_hg19   :  1
#  (Other)                  :929

# %%
for (i in gobject) {
#  print  b <- paste(sprintf(gobject$A,gobject$A,gobject$B,genome.size=20805)
  save(b, file = "b.RData")
  write.table(b, file="mygenelist.txt")
  }
print b
# Out:
# Error in parse(text = x, srcfile = src): <text>:6:7: unexpected symbol
# 5:   }
# 6: print b
#          ^
# Traceback:

# %%
# install.packages('devtools')

# devtools::install_github('IRkernel/IRkernel')
# # or devtools::install_local('IRkernel-master.tar.gz')
# IRkernel::installspec()  # to register the kernel in the current R installation
# install.packages("multicore")

# %%
# List of overlap comparisons. Ufahhhh...

for (i in gobject) {
  b <- paste(sprintf('(%s,%s,genome.size=20805),',gobject$A,gobject$B))
  print(b)
 # write.table(b, "enc15vs16freeOverlapMap2.csv", quote=FALSE, row.names=F, col.names=FALSE, sep="\t")
  }
# Out:
#   [1] "(go.obj <- newGeneOverlap(encodeA$REST_H1hESC_hg19,encodeB$REST_H1hESC_hg19,genome.size=20805),"
#   [2] "(go.obj <- newGeneOverlap(encodeA$TAF1_HeLaS3_hg19,encodeB$TAF1_HeLaS3_hg19,genome.size=20805),"
#   [3] "(go.obj <- newGeneOverlap(encodeA$REST_HepG2_hg19,encodeB$REST_HepG2_hg19,genome.size=20805),"
#   [4] "(go.obj <- newGeneOverlap(encodeA$ZBTB7A_K562_hg19,encodeB$ZBTB7A_K562_hg19,genome.size=20805),"
#   [5] "(go.obj <- newGeneOverlap(encodeA$SIX5_K562_hg19,encodeB$SIX5_K562_hg19,genome.size=20805),"
#   [6] "(go.obj <- newGeneOverlap(encodeA$SIN3A_SKNSH_hg19,encodeB$SIN3A_SKNSH_hg19,genome.size=20805),"
#   [7] "(go.obj <- newGeneOverlap(encodeA$CBX3_K562_hg19,encodeB$CBX3_K562_hg19,genome.size=20805),"
#   [8] "(go.obj <- newGeneOverlap(encodeA$TRIM28_K562_hg19,encodeB$TRIM28_K562_hg19,genome.size=20805),"
#   [9] "(go.obj <- newGeneOverlap(encodeA$JUND_SKNSH_hg19,encodeB$JUND_SKNSH_hg19,genome.size=20805),"
# ...

# %%
# go.list <-read.table("mygenelist.txt")
# # for (go.obj in go.list) {
# #   testGeneOverlap(go.obj)
# #   }

# go.list

# %%
golist<-list(go.obj<-newGeneOverlap(encodeA$ZBTB7A_K562,encodeB$gene_2380,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$YY1_K562,encodeB$gene_76,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$YY1_K562,encodeB$gene_515,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$YY1_K562,encodeB$gene_2802,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$YY1_K562,encodeB$gene_1333,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_76,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_515,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_2802,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_1333,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_3099,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_3097,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_2034,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_2033,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_2032,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_3099,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_3097,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_2034,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_2033,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_2032,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_3099,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_3097,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_2034,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_2033,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_2032,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$TAL1_K562,encodeB$gene_1447,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SUZ12_K562,encodeB$gene_146,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SUZ12_K562,encodeB$gene_1332,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_85,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_3063,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_2479,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_2148,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_1790,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_2476,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1529,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1521,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1520,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1519,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SP1_K562,encodeB$gene_2219,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SP1_K562,encodeB$gene_2219,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SMC3_K562,encodeB$gene_1420,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SMC3_K562,encodeB$gene_1419,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SMC3_HepG2,encodeB$gene_1420,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SMC3_HepG2,encodeB$gene_1419,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SMC3_GM12878,encodeB$gene_1420,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SMC3_GM12878,encodeB$gene_1419,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SIRT6_K562,encodeB$gene_1117,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_826,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_3118,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_3038,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_1249,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SIN3A_A549,encodeB$gene_826,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SIN3A_A549,encodeB$gene_3118,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SIN3A_A549,encodeB$gene_3038,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SIN3A_A549,encodeB$gene_1249,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SETDB1_U2OS,encodeB$gene_31,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SETDB1_U2OS,encodeB$gene_2205,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SETDB1_K562,encodeB$gene_31,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$SETDB1_K562,encodeB$gene_2205,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_2201,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_2173,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_2172,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_2170,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_1765,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$REST_K562,encodeB$gene_1710,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$REST_K562,encodeB$gene_1331,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$REST_HepG2,encodeB$gene_1710,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$REST_HepG2,encodeB$gene_1331,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$REST_A549,encodeB$gene_1710,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$REST_A549,encodeB$gene_1331,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$RAD21_K562,encodeB$gene_2792,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$RAD21_K562,encodeB$gene_1330,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$RAD21_HepG2,encodeB$gene_2792,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$RAD21_HepG2,encodeB$gene_1330,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$RAD21_GM12878,encodeB$gene_2792,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$RAD21_GM12878,encodeB$gene_1330,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$RAD21_A549,encodeB$gene_2792,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$RAD21_A549,encodeB$gene_1330,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$NRF1_K562,encodeB$gene_2150,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$NRF1_HepG2,encodeB$gene_2150,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$NRF1_GM12878,encodeB$gene_2150,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$NR2C2_K562,encodeB$gene_2714,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$NR2C2_K562,encodeB$gene_2628,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$NR2C2_K562,encodeB$gene_2200,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$NR2C2_HepG2,encodeB$gene_2714,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$NR2C2_HepG2,encodeB$gene_2628,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$NR2C2_HepG2,encodeB$gene_2200,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$NR2C2_GM12878,encodeB$gene_2714,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$NR2C2_GM12878,encodeB$gene_2628,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$NR2C2_GM12878,encodeB$gene_2200,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$NFYB_K562,encodeB$gene_1342,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$NFYB_GM12878,encodeB$gene_1342,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$NFYA_K562,encodeB$gene_1341,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$NFYA_GM12878,encodeB$gene_1341,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$NELFE_K562,encodeB$gene_2796,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_754,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_753,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_752,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_751,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_750,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_712,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_359,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_2609,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_2553,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_2220,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_2206,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_2075,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1847,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1846,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1827,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1826,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1824,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1822,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1820,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1817,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1754,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1753,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_140,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_139,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_137,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_136,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1313,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1311,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1308,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1307,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1273,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1007,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_754,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_753,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_752,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_751,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_750,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_712,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_359,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_2609,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_2553,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_2220,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_2206,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_2075,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1847,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1846,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1827,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1826,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1824,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1822,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1820,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1817,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1754,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1753,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_140,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_139,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_137,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_136,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1313,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1311,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1308,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1307,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1273,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1007,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_754,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_753,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_752,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_751,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_750,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_712,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_359,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_2609,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_2553,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_2220,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_2206,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_2075,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1847,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1846,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1827,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1826,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1824,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1822,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1820,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1817,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1754,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1753,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_140,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_139,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_137,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_136,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1313,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1311,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1308,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1307,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1273,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1007,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_754,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_753,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_752,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_751,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_750,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_712,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_359,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_2609,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_2553,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_2220,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_2206,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_2075,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1847,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1846,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1827,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1826,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1824,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1822,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1820,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1817,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1754,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1753,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_140,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_139,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_137,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_136,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1313,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1311,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1308,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1307,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1273,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1007,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_754,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_753,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_752,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_751,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_750,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_712,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_359,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_2609,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_2553,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_2220,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_2206,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_2075,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1847,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1846,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1827,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1826,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1824,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1822,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1820,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1817,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1754,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1753,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_140,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_139,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_137,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_136,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1313,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1311,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1308,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1307,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1273,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1007,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$KDM1A_K562,encodeB$gene_484,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$KDM1A_K562,encodeB$gene_394,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$KDM1A_K562,encodeB$gene_3082,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$KDM1A_K562,encodeB$gene_302,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$JUND_T47D,encodeB$gene_2812,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$JUND_K562,encodeB$gene_2812,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$JUND_HepG2,encodeB$gene_2812,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$JUND_GM12878,encodeB$gene_2812,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$JUN_K562,encodeB$gene_321,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$JUN_K562,encodeB$gene_3073,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$JUN_K562,encodeB$gene_1516,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$JUN_K562,encodeB$gene_1505,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$JUN_HepG2,encodeB$gene_321,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$JUN_HepG2,encodeB$gene_3073,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$JUN_HepG2,encodeB$gene_1516,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$JUN_HepG2,encodeB$gene_1505,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$JUN_endothelialcellofumbilicalvein,encodeB$gene_321,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$JUN_endothelialcellofumbilicalvein,encodeB$gene_3073,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$JUN_endothelialcellofumbilicalvein,encodeB$gene_1516,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$JUN_endothelialcellofumbilicalvein,encodeB$gene_1505,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$IRF3_HepG2,encodeB$gene_2817,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$IRF3_GM12878,encodeB$gene_2817,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$IKZF1_GM12878,encodeB$gene_2547,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$IKZF1_GM12878,encodeB$gene_2259,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$IKZF1_GM12878,encodeB$gene_1730,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$HDAC2_K562,encodeB$gene_685,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$HDAC2_K562,encodeB$gene_2890,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$HDAC2_K562,encodeB$gene_2844,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$HDAC2_K562,encodeB$gene_1413,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$HDAC2_HepG2,encodeB$gene_685,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$HDAC2_HepG2,encodeB$gene_2890,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$HDAC2_HepG2,encodeB$gene_2844,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$HDAC2_HepG2,encodeB$gene_1413,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$HDAC1_K562,encodeB$gene_94,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$HDAC1_K562,encodeB$gene_1804,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$HDAC1_K562,encodeB$gene_1803,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$HDAC1_K562,encodeB$gene_1412,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$HDAC1_K562,encodeB$gene_1411,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$GTF2B_K562,encodeB$gene_2798,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$GATA1_K562,encodeB$gene_980,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$GATA1_K562,encodeB$gene_979,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$GATA1_K562,encodeB$gene_2658,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$GATA1_K562,encodeB$gene_108,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$GATA1_K562,encodeB$gene_1062,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_980,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_979,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_2658,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_108,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_1062,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_3051,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_2965,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_2963,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_2703,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_171,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ESRRA_GM12878,encodeB$gene_673,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ESRRA_GM12878,encodeB$gene_2821,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ESRRA_GM12878,encodeB$gene_2613,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ESRRA_GM12878,encodeB$gene_2159,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EP300_K562,encodeB$gene_2815,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EP300_K562,encodeB$gene_1746,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EP300_K562,encodeB$gene_1050,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EP300_HepG2,encodeB$gene_2815,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EP300_HepG2,encodeB$gene_1746,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EP300_HepG2,encodeB$gene_1050,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EP300_GM12878,encodeB$gene_2815,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EP300_GM12878,encodeB$gene_
genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$GATA1_K562,encodeB$gene_1062,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_980,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_979,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_2658,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_108,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_1062,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_3051,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_2965,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_2963,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_2703,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_171,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ESRRA_GM12878,encodeB$gene_673,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ESRRA_GM12878,encodeB$gene_2821,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ESRRA_GM12878,encodeB$gene_2613,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ESRRA_GM12878,encodeB$gene_2159,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EP300_K562,encodeB$gene_2815,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EP300_K562,encodeB$gene_1746,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EP300_K562,encodeB$gene_1050,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EP300_HepG2,encodeB$gene_2815,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EP300_HepG2,encodeB$gene_1746,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EP300_HepG2,encodeB$gene_1050,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EP300_GM12878,encodeB$gene_2815,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EP300_GM12878,encodeB$gene_1746,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EP300_GM12878,encodeB$gene_1050,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ELK1_K562,encodeB$gene_2865,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ELK1_K562,encodeB$gene_2863,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ELK1_GM12878,encodeB$gene_2865,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ELK1_GM12878,encodeB$gene_2863,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EBF1_GM12878,encodeB$gene_860,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EBF1_GM12878,encodeB$gene_859,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EBF1_GM12878,encodeB$gene_858,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$EBF1_GM12878,encodeB$gene_857,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$E2F6_K562,encodeB$gene_2807,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$E2F4_K562,encodeB$gene_1167,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$E2F4_GM12878,encodeB$gene_1167,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_WI38,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_spleen,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_retinalpigmentepithelialcell,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_pancreas,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_NB4,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_medulloblastoma,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_mammaryepithelialcell,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_lung,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_kidneyepithelialcell,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_kidney,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_keratinocyte,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_K562,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_HGPScell,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_HepG2,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_HEK293,encodeB$gene_124,genome.size=20805),
golist<-list((go.obj<-newGeneOverlap(encodeA$CTCF_HCT116,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM20000,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM19240,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM19239,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM19238,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM13977,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM13976,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM12892,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM12891,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM12878,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM12875,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM12874,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM12873,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM12872,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM12871,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM12870,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM12869,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM12868,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM12867,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM12866,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM12865,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM12864,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM12801,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM10266,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM10248,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_GM06990,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_foreskinfibroblast,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofvillousmesenchyme,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofupperlegskin,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastoftheaorticadventitia,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofskinofabdomen,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofpulmonaryartery,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofpedaldigitskin,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofmammarygland,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastoflung,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofgingiva,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_epithelialcellofproximaltubule,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_epithelialcellofesophagus,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_endothelialcellofumbilicalvein,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_choroidplexusepithelialcell,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_cardiacmusclecell,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_cardiacfibroblast,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_bronchialepithelialcell,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_brainmicrovascularendothelialcell,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_BE2C,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_astrocyteofthespinalcord,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_astrocyteofthecerebellum,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CTCF_A549,encodeB$gene_124,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$CBX3_K562,encodeB$gene_1374,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_65,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_529,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_148,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_1137,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_65,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_529,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_148,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_1137,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ATF2_GM12878,encodeB$gene_2544,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ARID3A_K562,encodeB$gene_1339,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ARID3A_K562,encodeB$gene_1338,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ARID3A_K562,encodeB$gene_1337,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ARID3A_HepG2,encodeB$gene_1339,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ARID3A_HepG2,encodeB$gene_1338,genome.size=20805),
(go.obj<-newGeneOverlap(encodeA$ARID3A_HepG2,encodeB$gene_1337,genome.size=20805))

for(go.objingolist)
print(testGeneOverlap(go.obj))
# Out:
# Error in parse(text = x, srcfile = src): <text>:2:76: unexpected ','
# 1: golist<-list(go.obj<-newGeneOverlap(encodeA$ZBTB7A_K562,encodeB$gene_2380,genome.size=20805),
# 2: (go.obj<-newGeneOverlap(encodeA$YY1_K562,encodeB$gene_76,genome.size=20805),
#                                                                               ^
# Traceback:

# %%
golist <-list(go.obj<- newGeneOverlap(encodeA$ZBTB7A_K562,encodeB$gene_2380,genome.size=20805),                        
(go.obj <- newGeneOverlap(encodeA$YY1_K562,encodeB$gene_76,genome.size=20805),                               
(go.obj <- newGeneOverlap(encodeA$YY1_K562,encodeB$gene_515,genome.size=20805),                              
(go.obj <- newGeneOverlap(encodeA$YY1_K562,encodeB$gene_2802,genome.size=20805),                             
(go.obj <- newGeneOverlap(encodeA$YY1_K562,encodeB$gene_1333,genome.size=20805),                             
(go.obj <- newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_76,genome.size=20805),                            
(go.obj <- newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_515,genome.size=20805),                           
(go.obj <- newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_2802,genome.size=20805),                          
(go.obj <- newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_1333,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_3099,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_3097,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_2034,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_2033,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_2032,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_3099,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_3097,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_2034,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_2033,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_2032,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_3099,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_3097,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_2034,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_2033,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_2032,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$TAL1_K562,encodeB$gene_1447,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$SUZ12_K562,encodeB$gene_146,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$SUZ12_K562,encodeB$gene_1332,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_85,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_3063,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_2479,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_2148,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_1790,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_2476,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1529,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1521,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1520,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1519,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$SP1_K562,encodeB$gene_2219,genome.size=20805),                             
go.obj <- newGeneOverlap(encodeA$SP1_K562,encodeB$gene_2219,genome.size=20805),                             
go.obj <- newGeneOverlap(encodeA$SMC3_K562,encodeB$gene_1420,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$SMC3_K562,encodeB$gene_1419,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$SMC3_HepG2,encodeB$gene_1420,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$SMC3_HepG2,encodeB$gene_1419,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$SMC3_GM12878,encodeB$gene_1420,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$SMC3_GM12878,encodeB$gene_1419,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$SIRT6_K562,encodeB$gene_1117,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_826,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_3118,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_3038,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_1249,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$SIN3A_A549,encodeB$gene_826,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$SIN3A_A549,encodeB$gene_3118,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$SIN3A_A549,encodeB$gene_3038,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$SIN3A_A549,encodeB$gene_1249,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$SETDB1_U2OS,encodeB$gene_31,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$SETDB1_U2OS,encodeB$gene_2205,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$SETDB1_K562,encodeB$gene_31,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$SETDB1_K562,encodeB$gene_2205,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_2201,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_2173,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_2172,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_2170,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_1765,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$REST_K562,encodeB$gene_1710,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$REST_K562,encodeB$gene_1331,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$REST_HepG2,encodeB$gene_1710,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$REST_HepG2,encodeB$gene_1331,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$REST_A549,encodeB$gene_1710,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$REST_A549,encodeB$gene_1331,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$RAD21_K562,encodeB$gene_2792,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$RAD21_K562,encodeB$gene_1330,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$RAD21_HepG2,encodeB$gene_2792,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$RAD21_HepG2,encodeB$gene_1330,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$RAD21_GM12878,encodeB$gene_2792,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$RAD21_GM12878,encodeB$gene_1330,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$RAD21_A549,encodeB$gene_2792,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$RAD21_A549,encodeB$gene_1330,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$NRF1_K562,encodeB$gene_2150,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$NRF1_HepG2,encodeB$gene_2150,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$NRF1_GM12878,encodeB$gene_2150,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$NR2C2_K562,encodeB$gene_2714,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$NR2C2_K562,encodeB$gene_2628,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$NR2C2_K562,encodeB$gene_2200,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$NR2C2_HepG2,encodeB$gene_2714,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$NR2C2_HepG2,encodeB$gene_2628,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$NR2C2_HepG2,encodeB$gene_2200,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$NR2C2_GM12878,encodeB$gene_2714,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$NR2C2_GM12878,encodeB$gene_2628,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$NR2C2_GM12878,encodeB$gene_2200,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA
encodeB$gene_124,genome.size=20805),                             
go.obj <- newGeneOverlap(encodeA$CTCF_kidneyepithelialcell,encodeB$gene_124,genome.size=20805),             
go.obj <- newGeneOverlap(encodeA$CTCF_kidney,encodeB$gene_124,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$CTCF_keratinocyte,encodeB$gene_124,genome.size=20805),                     
go.obj <- newGeneOverlap(encodeA$CTCF_K562,encodeB$gene_124,genome.size=20805),                             
go.obj <- newGeneOverlap(encodeA$CTCF_HGPScell,encodeB$gene_124,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$CTCF_HepG2,encodeB$gene_124,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$CTCF_HEK293,encodeB$gene_124,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$CTCF_HCT116,encodeB$gene_124,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$CTCF_GM20000,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM19240,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM19239,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM19238,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM13977,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM13976,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12892,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12891,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12878,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12875,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12874,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12873,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12872,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12871,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12870,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12869,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12868,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12867,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12866,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12865,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12864,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12801,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM10266,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM10248,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM06990,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_foreskinfibroblast,encodeB$gene_124,genome.size=20805),               
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastofvillousmesenchyme,encodeB$gene_124,genome.size=20805),    
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastofupperlegskin,encodeB$gene_124,genome.size=20805),         
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastoftheaorticadventitia,encodeB$gene_124,genome.size=20805),  
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastofskinofabdomen,encodeB$gene_124,genome.size=20805),        
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastofpulmonaryartery,encodeB$gene_124,genome.size=20805),      
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastofpedaldigitskin,encodeB$gene_124,genome.size=20805),       
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastofmammarygland,encodeB$gene_124,genome.size=20805),         
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastoflung,encodeB$gene_124,genome.size=20805),                 
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastofgingiva,encodeB$gene_124,genome.size=20805),              
go.obj <- newGeneOverlap(encodeA$CTCF_epithelialcellofproximaltubule,encodeB$gene_124,genome.size=20805),   
go.obj <- newGeneOverlap(encodeA$CTCF_epithelialcellofesophagus,encodeB$gene_124,genome.size=20805),        
go.obj <- newGeneOverlap(encodeA$CTCF_endothelialcellofumbilicalvein,encodeB$gene_124,genome.size=20805),   
go.obj <- newGeneOverlap(encodeA$CTCF_choroidplexusepithelialcell,encodeB$gene_124,genome.size=20805),      
go.obj <- newGeneOverlap(encodeA$CTCF_cardiacmusclecell,encodeB$gene_124,genome.size=20805),                
go.obj <- newGeneOverlap(encodeA$CTCF_cardiacfibroblast,encodeB$gene_124,genome.size=20805),                
go.obj <- newGeneOverlap(encodeA$CTCF_bronchialepithelialcell,encodeB$gene_124,genome.size=20805),          
go.obj <- newGeneOverlap(encodeA$CTCF_brainmicrovascularendothelialcell,encodeB$gene_124,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CTCF_BE2C,encodeB$gene_124,genome.size=20805),                             
go.obj <- newGeneOverlap(encodeA$CTCF_astrocyteofthespinalcord,encodeB$gene_124,genome.size=20805),         
go.obj <- newGeneOverlap(encodeA$CTCF_astrocyteofthecerebellum,encodeB$gene_124,genome.size=20805),         
go.obj <- newGeneOverlap(encodeA$CTCF_A549,encodeB$gene_124,genome.size=20805),                             
go.obj <- newGeneOverlap(encodeA$CBX3_K562,encodeB$gene_1374,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_65,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_529,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_148,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_1137,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_65,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_529,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_148,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_1137,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$ATF2_GM12878,encodeB$gene_2544,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$ARID3A_K562,encodeB$gene_1339,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$ARID3A_K562,encodeB$gene_1338,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$ARID3A_K562,encodeB$gene_1337,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$ARID3A_HepG2,encodeB$gene_1339,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$ARID3A_HepG2,encodeB$gene_1338,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$ARID3A_HepG2,encodeB$gene_1337,genome.size=20805),                         
(go.obj <- newGeneOverlap(encodeA$ZBTB7A_K562,encodeB$gene_2380,genome.size=20805),                          
(go.obj <- newGeneOverlap(encodeA$YY1_K562,encodeB$gene_76,genome.size=20805),                               
(go.obj <- newGeneOverlap(encodeA$YY1_K562,encodeB$gene_515,genome.size=20805),                              
(go.obj <- newGeneOverlap(encodeA$YY1_K562,encodeB$gene_2802,genome.size=20805),                             
(go.obj <- newGeneOverlap(encodeA$YY1_K562,encodeB$gene_1333,genome.size=20805),                             
(go.obj <- newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_76,genome.size=20805),                            
(go.obj <- newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_515,genome.size=20805),                           
(go.obj <- newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_2802,genome.size=20805),                          
(go.obj <- newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_1333,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_3099,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_3097,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_2034,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_2033,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_2032,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_3099,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_3097,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_2034,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_2033,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_2032,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_3099,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_3097,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_2034,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_2033,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_2032,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$TAL1_K562,encodeB$gene_1447,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$SUZ12_K562,encodeB$gene_146,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$SUZ12_K562,encodeB$gene_1332,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_85,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_3063,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_2479,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_2148,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_1790,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_2476,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1529,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1521,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1520,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1519,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$SP1_K562,encodeB$gene_2219,genome.size=20805),                             
go.obj <- newGeneOverlap(encodeA$SP1_K562,encodeB$gene_2219,genome.size=20805),                             
go.obj <- newGeneOverlap(encodeA$SMC3_K562,encodeB$gene_1420,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$SMC3_K562,encodeB$gene_1419,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$SMC3_HepG2,encodeB$gene_1420,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$SMC3_HepG2,encodeB$gene_1419,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$SMC3_GM12878,encodeB$gene_1420,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$SMC3_GM12878,encodeB$gene_1419,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$SIRT6_K562,encodeB$gene_1117,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_826,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_3118,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_3038,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_1249,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$SIN3A_A549,encodeB$gene
genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$EP300_GM12878,encodeB$gene_1050,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$ELK1_K562,encodeB$gene_2865,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$ELK1_K562,encodeB$gene_2863,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$ELK1_GM12878,encodeB$gene_2865,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$ELK1_GM12878,encodeB$gene_2863,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$EBF1_GM12878,encodeB$gene_860,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$EBF1_GM12878,encodeB$gene_859,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$EBF1_GM12878,encodeB$gene_858,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$EBF1_GM12878,encodeB$gene_857,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$E2F6_K562,encodeB$gene_2807,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$E2F4_K562,encodeB$gene_1167,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$E2F4_GM12878,encodeB$gene_1167,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$CTCF_WI38,encodeB$gene_124,genome.size=20805),                             
go.obj <- newGeneOverlap(encodeA$CTCF_spleen,encodeB$gene_124,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$CTCF_retinalpigmentepithelialcell,encodeB$gene_124,genome.size=20805),     
go.obj <- newGeneOverlap(encodeA$CTCF_pancreas,encodeB$gene_124,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$CTCF_NB4,encodeB$gene_124,genome.size=20805),                              
go.obj <- newGeneOverlap(encodeA$CTCF_medulloblastoma,encodeB$gene_124,genome.size=20805),                  
go.obj <- newGeneOverlap(encodeA$CTCF_mammaryepithelialcell,encodeB$gene_124,genome.size=20805),            
go.obj <- newGeneOverlap(encodeA$CTCF_lung,encodeB$gene_124,genome.size=20805),                             
go.obj <- newGeneOverlap(encodeA$CTCF_kidneyepithelialcell,encodeB$gene_124,genome.size=20805),             
go.obj <- newGeneOverlap(encodeA$CTCF_kidney,encodeB$gene_124,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$CTCF_keratinocyte,encodeB$gene_124,genome.size=20805),                     
go.obj <- newGeneOverlap(encodeA$CTCF_K562,encodeB$gene_124,genome.size=20805),                             
go.obj <- newGeneOverlap(encodeA$CTCF_HGPScell,encodeB$gene_124,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$CTCF_HepG2,encodeB$gene_124,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$CTCF_HEK293,encodeB$gene_124,genome.size=20805),                           
olist <-list((go.obj <- newGeneOverlap(encodeA$CTCF_HCT116,encodeB$gene_124,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$CTCF_GM20000,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM19240,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM19239,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM19238,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM13977,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM13976,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12892,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12891,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12878,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12875,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12874,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12873,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12872,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12871,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12870,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12869,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12868,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12867,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12866,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12865,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12864,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM12801,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM10266,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM10248,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_GM06990,encodeB$gene_124,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$CTCF_foreskinfibroblast,encodeB$gene_124,genome.size=20805),               
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastofvillousmesenchyme,encodeB$gene_124,genome.size=20805),    
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastofupperlegskin,encodeB$gene_124,genome.size=20805),         
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastoftheaorticadventitia,encodeB$gene_124,genome.size=20805),  
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastofskinofabdomen,encodeB$gene_124,genome.size=20805),        
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastofpulmonaryartery,encodeB$gene_124,genome.size=20805),      
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastofpedaldigitskin,encodeB$gene_124,genome.size=20805),       
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastofmammarygland,encodeB$gene_124,genome.size=20805),         
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastoflung,encodeB$gene_124,genome.size=20805),                 
go.obj <- newGeneOverlap(encodeA$CTCF_fibroblastofgingiva,encodeB$gene_124,genome.size=20805),              
go.obj <- newGeneOverlap(encodeA$CTCF_epithelialcellofproximaltubule,encodeB$gene_124,genome.size=20805),   
go.obj <- newGeneOverlap(encodeA$CTCF_epithelialcellofesophagus,encodeB$gene_124,genome.size=20805),        
go.obj <- newGeneOverlap(encodeA$CTCF_endothelialcellofumbilicalvein,encodeB$gene_124,genome.size=20805),   
go.obj <- newGeneOverlap(encodeA$CTCF_choroidplexusepithelialcell,encodeB$gene_124,genome.size=20805),      
go.obj <- newGeneOverlap(encodeA$CTCF_cardiacmusclecell,encodeB$gene_124,genome.size=20805),                
go.obj <- newGeneOverlap(encodeA$CTCF_cardiacfibroblast,encodeB$gene_124,genome.size=20805),                
go.obj <- newGeneOverlap(encodeA$CTCF_bronchialepithelialcell,encodeB$gene_124,genome.size=20805),          
go.obj <- newGeneOverlap(encodeA$CTCF_brainmicrovascularendothelialcell,encodeB$gene_124,genome.size=20805),
go.obj <- newGeneOverlap(encodeA$CTCF_BE2C,encodeB$gene_124,genome.size=20805),                             
go.obj <- newGeneOverlap(encodeA$CTCF_astrocyteofthespinalcord,encodeB$gene_124,genome.size=20805),         
go.obj <- newGeneOverlap(encodeA$CTCF_astrocyteofthecerebellum,encodeB$gene_124,genome.size=20805),         
go.obj <- newGeneOverlap(encodeA$CTCF_A549,encodeB$gene_124,genome.size=20805),                             
go.obj <- newGeneOverlap(encodeA$CBX3_K562,encodeB$gene_1374,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_65,genome.size=20805),                            
go.obj <- newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_529,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_148,genome.size=20805),                           
go.obj <- newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_1137,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_65,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_529,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_148,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_1137,genome.size=20805),                        
go.obj <- newGeneOverlap(encodeA$ATF2_GM12878,encodeB$gene_2544,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$ARID3A_K562,encodeB$gene_1339,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$ARID3A_K562,encodeB$gene_1338,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$ARID3A_K562,encodeB$gene_1337,genome.size=20805),                          
go.obj <- newGeneOverlap(encodeA$ARID3A_HepG2,encodeB$gene_1339,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$ARID3A_HepG2,encodeB$gene_1338,genome.size=20805),                         
go.obj <- newGeneOverlap(encodeA$ARID3A_HepG2,encodeB$gene_1337,genome.size=20805)) 
for (go.obj in golist)
 print(testGeneOverlap(go.obj))
    
    }
# Out:
# Error in parse(text = x, srcfile = src): <text>:2:78: unexpected ','
# 1: golist <-list(go.obj<- newGeneOverlap(encodeA$ZBTB7A_K562,encodeB$gene_2380,genome.size=20805),
# 2: (go.obj <- newGeneOverlap(encodeA$YY1_K562,encodeB$gene_76,genome.size=20805),
#                                                                                 ^
# Traceback:

# %%
go.obj<-newGeneOverlap(encodeA$SMC3_GM12878,encodeB$gene_1419,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIRT6_K562,encodeB$gene_1117,genome.size=20805)

# %%
golist<-list(go.obj<-newGeneOverlap(encodeA$ZBTB7A_K562,encodeB$gene_2380,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$YY1_K562,encodeB$gene_76,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$YY1_K562,encodeB$gene_515,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$YY1_K562,encodeB$gene_2802,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$YY1_K562,encodeB$gene_1333,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_76,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_515,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_2802,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_1333,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_3099,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_3097,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_2034,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_2033,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_2032,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_3099,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_3097,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_2034,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_2033,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_2032,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_3099,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_3097,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_2034,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_2033,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_2032,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TAL1_K562,encodeB$gene_1447,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SUZ12_K562,encodeB$gene_146,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SUZ12_K562,encodeB$gene_1332,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_85,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_3063,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_2479,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_2148,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_1790,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_2476,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1529,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1521,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1520,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1519,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SP1_K562,encodeB$gene_2219,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SP1_K562,encodeB$gene_2219,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SMC3_K562,encodeB$gene_1420,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SMC3_K562,encodeB$gene_1419,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SMC3_HepG2,encodeB$gene_1420,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SMC3_HepG2,encodeB$gene_1419,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SMC3_GM12878,encodeB$gene_1420,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SMC3_GM12878,encodeB$gene_1419,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIRT6_K562,encodeB$gene_1117,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_826,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_3118,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_3038,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_1249,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIN3A_A549,encodeB$gene_826,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIN3A_A549,encodeB$gene_3118,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIN3A_A549,encodeB$gene_3038,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIN3A_A549,encodeB$gene_1249,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SETDB1_U2OS,encodeB$gene_31,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SETDB1_U2OS,encodeB$gene_2205,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SETDB1_K562,encodeB$gene_31,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SETDB1_K562,encodeB$gene_2205,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_2201,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_2173,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_2172,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_2170,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_1765,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$REST_K562,encodeB$gene_1710,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$REST_K562,encodeB$gene_1331,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$REST_HepG2,encodeB$gene_1710,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$REST_HepG2,encodeB$gene_1331,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$REST_A549,encodeB$gene_1710,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$REST_A549,encodeB$gene_1331,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RAD21_K562,encodeB$gene_2792,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RAD21_K562,encodeB$gene_1330,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RAD21_HepG2,encodeB$gene_2792,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RAD21_HepG2,encodeB$gene_1330,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RAD21_GM12878,encodeB$gene_2792,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RAD21_GM12878,encodeB$gene_1330,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RAD21_A549,encodeB$gene_2792,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RAD21_A549,encodeB$gene_1330,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NRF1_K562,encodeB$gene_2150,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NRF1_HepG2,encodeB$gene_2150,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NRF1_GM12878,encodeB$gene_2150,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_K562,encodeB$gene_2714,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_K562,encodeB$gene_2628,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_K562,encodeB$gene_2200,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_HepG2,encodeB$gene_2714,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_HepG2,encodeB$gene_2628,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_HepG2,encodeB$gene_2200,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_GM12878,encodeB$gene_2714,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_GM12878,encodeB$gene_2628,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_GM12878,encodeB$gene_2200,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NFYB_K562,encodeB$gene_1342,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NFYB_GM12878,encodeB$gene_1342,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NFYA_K562,encodeB$gene_1341,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NFYA_GM12878,encodeB$gene_1341,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NELFE_K562,encodeB$gene_2796,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_752,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_751,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_750,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_712,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_359,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_2609,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_2553,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_2220,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_2206,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_2075,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1847,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1846,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1827,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1826,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1824,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1822,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1820,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1817,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_140,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_139,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_137,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_136,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1313,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1311,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1308,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1307,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1273,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1007,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_752,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_751,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_750,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_712,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_359,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_2609,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_2553,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_2220,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_2206,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_2075,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1847,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1846,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1827,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1826,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1824,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1822,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1820,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1817,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_140,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_139,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_137,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_136,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1313,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1311,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1308,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1307,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1273,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1007,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_752,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_751,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_750,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_712,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_359,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_2609,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_2553,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_2220,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_2206,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_2075,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1847,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1846,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1827,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1826,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1824,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1822,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1820,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1817,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_140,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_139,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_137,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_136,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1313,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1311,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1308,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1307,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1273,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1007,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_752,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_751,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_750,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_712,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_359,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_2609,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_2553,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_2220,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_2206,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_2075,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1847,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1846,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1827,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1826,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1824,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1822,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1820,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1817,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_140,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_139,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_137,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_136,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1313,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1311,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1308,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1307,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1273,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1007,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_752,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_751,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_750,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_712,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_359,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_2609,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_2553,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_2220,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_2206,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_2075,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1847,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1846,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1827,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1826,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1824,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1822,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1820,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1817,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_140,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_139,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_137,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_136,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1313,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1311,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1308,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1307,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1273,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1007,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$KDM1A_K562,encodeB$gene_484,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$KDM1A_K562,encodeB$gene_394,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$KDM1A_K562,encodeB$gene_3082,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$KDM1A_K562,encodeB$gene_302,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUND_T47D,encodeB$gene_2812,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUND_K562,encodeB$gene_2812,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUND_HepG2,encodeB$gene_2812,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUND_GM12878,encodeB$gene_2812,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_K562,encodeB$gene_321,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_K562,encodeB$gene_3073,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_K562,encodeB$gene_1516,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_K562,encodeB$gene_1505,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_HepG2,encodeB$gene_321,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_HepG2,encodeB$gene_3073,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_HepG2,encodeB$gene_1516,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_HepG2,encodeB$gene_1505,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_endothelialcellofumbilicalvein,encodeB$gene_321,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_endothelialcellofumbilicalvein,encodeB$gene_3073,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_endothelialcellofumbilicalvein,encodeB$gene_1516,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_endothelialcellofumbilicalvein,encodeB$gene_1505,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$IRF3_HepG2,encodeB$gene_2817,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$IRF3_GM12878,encodeB$gene_2817,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$IKZF1_GM12878,encodeB$gene_2547,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$IKZF1_GM12878,encodeB$gene_2259,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$IKZF1_GM12878,encodeB$gene_1730,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC2_K562,encodeB$gene_685,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC2_K562,encodeB$gene_2890,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC2_K562,encodeB$gene_2844,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC2_K562,encodeB$gene_1413,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC2_HepG2,encodeB$gene_685,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC2_HepG2,encodeB$gene_2890,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC2_HepG2,encodeB$gene_2844,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC2_HepG2,encodeB$gene_1413,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC1_K562,encodeB$gene_94,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC1_K562,encodeB$gene_1804,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC1_K562,encodeB$gene_1803,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC1_K562,encodeB$gene_1412,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC1_K562,encodeB$gene_1411,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GTF2B_K562,encodeB$gene_2798,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_K562,encodeB$gene_980,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_K562,encodeB$gene_979,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_K562,encodeB$gene_2658,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_K562,encodeB$gene_108,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_K562,encodeB$gene_1062,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_980,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_979,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_2658,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_108,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_1062,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_3051,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_2965,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_2963,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_2703,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_171,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ESRRA_GM12878,encodeB$gene_673,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ESRRA_GM12878,encodeB$gene_2821,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ESRRA_GM12878,encodeB$gene_2613,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ESRRA_GM12878,encodeB$gene_2159,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_K562,encodeB$gene_2815,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_K562,encodeB$gene_1746,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_K562,encodeB$gene_1050,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_HepG2,encodeB$gene_2815,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_HepG2,encodeB$gene_1746,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_HepG2,encodeB$gene_1050,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_GM12878,encodeB$gene_2815,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_GM12878,encodeB$gene_1746,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_GM12878,encodeB$gene_1050,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ELK1_K562,encodeB$gene_2865,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ELK1_K562,encodeB$gene_2863,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ELK1_GM12878,encodeB$gene_2865,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ELK1_GM12878,encodeB$gene_2863,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EBF1_GM12878,encodeB$gene_860,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EBF1_GM12878,encodeB$gene_859,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EBF1_GM12878,encodeB$gene_858,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EBF1_GM12878,encodeB$gene_857,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$E2F6_K562,encodeB$gene_2807,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$E2F4_K562,encodeB$gene_1167,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$E2F4_GM12878,encodeB$gene_1167,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_WI38,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_spleen,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_retinalpigmentepithelialcell,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_pancreas,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_NB4,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_medulloblastoma,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_mammaryepithelialcell,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_lung,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_kidneyepithelialcell,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_kidney,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_keratinocyte,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_K562,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_HGPScell,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_HepG2,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_HEK293,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_HCT116,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM20000,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM19240,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM19239,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM19238,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM13977,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM13976,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12892,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12891,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12878,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12875,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12874,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12873,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12872,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12871,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12870,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12869,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12868,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12867,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12866,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12865,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12864,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12801,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM10266,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM10248,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM06990,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_foreskinfibroblast,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofvillousmesenchyme,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofupperlegskin,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastoftheaorticadventitia,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofskinofabdomen,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofpulmonaryartery,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofpedaldigitskin,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofmammarygland,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastoflung,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofgingiva,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_epithelialcellofproximaltubule,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_epithelialcellofesophagus,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_endothelialcellofumbilicalvein,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_choroidplexusepithelialcell,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_cardiacmusclecell,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_cardiacfibroblast,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_bronchialepithelialcell,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_brainmicrovascularendothelialcell,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_BE2C,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_astrocyteofthespinalcord,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_astrocyteofthecerebellum,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_A549,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CBX3_K562,encodeB$gene_1374,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_65,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_529,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_148,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_1137,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_65,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_529,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_148,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_1137,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ATF2_GM12878,encodeB$gene_2544,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ARID3A_K562,encodeB$gene_1339,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ARID3A_K562,encodeB$gene_1338,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ARID3A_K562,encodeB$gene_1337,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ARID3A_HepG2,encodeB$gene_1339,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ARID3A_HepG2,encodeB$gene_1338,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ARID3A_HepG2,encodeB$gene_1337,genome.size=20805)
(go.obj<-newGeneOverlap(encodeA$ZBTB7A_K562,encodeB$gene_2380,genome.size=20805)
(go.obj<-newGeneOverlap(encodeA$YY1_K562,encodeB$gene_76,genome.size=20805)
(go.obj<-newGeneOverlap(encodeA$YY1_K562,encodeB$gene_515,genome.size=20805)
(go.obj<-newGeneOverlap(encodeA$YY1_K562,encodeB$gene_2802,genome.size=20805)
(go.obj<-newGeneOverlap(encodeA$YY1_K562,encodeB$gene_1333,genome.size=20805)
(go.obj<-newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_76,genome.size=20805)
(go.obj<-newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_515,genome.size=20805)
(go.obj<-newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_2802,genome.size=20805)
(go.obj<-newGeneOverlap(encodeA$YY1_GM12878,encodeB$gene_1333,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_3099,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_3097,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_2034,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_2033,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_U2OS,encodeB$gene_2032,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_3099,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_3097,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_2034,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_2033,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_K562,encodeB$gene_2032,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_3099,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_3097,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_2034,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_2033,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TRIM28_HEK293,encodeB$gene_2032,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$TAL1_K562,encodeB$gene_1447,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SUZ12_K562,encodeB$gene_146,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SUZ12_K562,encodeB$gene_1332,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_85,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_3063,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_2479,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_2148,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT3_GM12878,encodeB$gene_1790,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_2476,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1529,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1521,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1520,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$STAT1_GM12878,encodeB$gene_1519,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SP1_K562,encodeB$gene_2219,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SP1_K562,encodeB$gene_2219,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SMC3_K562,encodeB$gene_1420,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SMC3_K562,encodeB$gene_1419,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SMC3_HepG2,encodeB$gene_1420,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SMC3_HepG2,encodeB$gene_1419,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SMC3_GM12878,encodeB$gene_1420,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SMC3_GM12878,encodeB$gene_1419,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIRT6_K562,encodeB$gene_1117,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_826,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_3118,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_3038,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIN3A_GM12878,encodeB$gene_1249,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIN3A_A549,encodeB$gene_826,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIN3A_A549,encodeB$gene_3118,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIN3A_A549,encodeB$gene_3038,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SIN3A_A549,encodeB$gene_1249,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SETDB1_U2OS,encodeB$gene_31,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SETDB1_U2OS,encodeB$gene_2205,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SETDB1_K562,encodeB$gene_31,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$SETDB1_K562,encodeB$gene_2205,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_2201,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_2173,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_2172,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_2170,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RNF2_K562,encodeB$gene_1765,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$REST_K562,encodeB$gene_1710,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$REST_K562,encodeB$gene_1331,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$REST_HepG2,encodeB$gene_1710,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$REST_HepG2,encodeB$gene_1331,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$REST_A549,encodeB$gene_1710,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$REST_A549,encodeB$gene_1331,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RAD21_K562,encodeB$gene_2792,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RAD21_K562,encodeB$gene_1330,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RAD21_HepG2,encodeB$gene_2792,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RAD21_HepG2,encodeB$gene_1330,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RAD21_GM12878,encodeB$gene_2792,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RAD21_GM12878,encodeB$gene_1330,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RAD21_A549,encodeB$gene_2792,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$RAD21_A549,encodeB$gene_1330,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NRF1_K562,encodeB$gene_2150,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NRF1_HepG2,encodeB$gene_2150,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NRF1_GM12878,encodeB$gene_2150,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_K562,encodeB$gene_2714,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_K562,encodeB$gene_2628,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_K562,encodeB$gene_2200,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_HepG2,encodeB$gene_2714,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_HepG2,encodeB$gene_2628,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_HepG2,encodeB$gene_2200,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_GM12878,encodeB$gene_2714,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_GM12878,encodeB$gene_2628,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NR2C2_GM12878,encodeB$gene_2200,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NFYB_K562,encodeB$gene_1342,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NFYB_GM12878,encodeB$gene_1342,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NFYA_K562,encodeB$gene_1341,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NFYA_GM12878,encodeB$gene_1341,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$NELFE_K562,encodeB$gene_2796,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_752,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_751,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_750,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_712,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_359,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_2609,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_2553,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_2220,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_2206,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_2075,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1847,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1846,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1827,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1826,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1824,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1822,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1820,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1817,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_140,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_139,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_137,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_136,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1313,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1311,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1308,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1307,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1273,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_NB4,encodeB$gene_1007,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_752,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_751,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_750,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_712,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_359,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_2609,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_2553,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_2220,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_2206,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_2075,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1847,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1846,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1827,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1826,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1824,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1822,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1820,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1817,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_140,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_139,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_137,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_136,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1313,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1311,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1308,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1307,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1273,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_K562,encodeB$gene_1007,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_752,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_751,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_750,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_712,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_359,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_2609,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_2553,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_2220,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_2206,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_2075,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1847,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1846,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1827,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1826,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1824,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1822,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1820,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1817,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_140,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_139,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_137,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_136,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1313,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1311,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1308,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1307,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1273,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_HepG2,encodeB$gene_1007,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_752,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_751,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_750,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_712,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_359,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_2609,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_2553,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_2220,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_2206,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_2075,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1847,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1846,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1827,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1826,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1824,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1822,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1820,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1817,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_140,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_139,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_137,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_136,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1313,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1311,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1308,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1307,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1273,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_GM12878,encodeB$gene_1007,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_752,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_751,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_750,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_712,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_359,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_2609,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_2553,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_2220,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_2206,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_2075,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1847,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1846,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1827,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1826,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1824,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1822,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1820,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1817,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1754,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1753,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_140,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_139,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_137,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_136,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1313,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1311,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1308,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1307,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1273,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$MYC_endothelialcellofumbilicalvein,encodeB$gene_1007,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$KDM1A_K562,encodeB$gene_484,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$KDM1A_K562,encodeB$gene_394,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$KDM1A_K562,encodeB$gene_3082,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$KDM1A_K562,encodeB$gene_302,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUND_T47D,encodeB$gene_2812,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUND_K562,encodeB$gene_2812,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUND_HepG2,encodeB$gene_2812,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUND_GM12878,encodeB$gene_2812,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_K562,encodeB$gene_321,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_K562,encodeB$gene_3073,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_K562,encodeB$gene_1516,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_K562,encodeB$gene_1505,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_HepG2,encodeB$gene_321,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_HepG2,encodeB$gene_3073,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_HepG2,encodeB$gene_1516,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_HepG2,encodeB$gene_1505,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_endothelialcellofumbilicalvein,encodeB$gene_321,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_endothelialcellofumbilicalvein,encodeB$gene_3073,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_endothelialcellofumbilicalvein,encodeB$gene_1516,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$JUN_endothelialcellofumbilicalvein,encodeB$gene_1505,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$IRF3_HepG2,encodeB$gene_2817,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$IRF3_GM12878,encodeB$gene_2817,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$IKZF1_GM12878,encodeB$gene_2547,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$IKZF1_GM12878,encodeB$gene_2259,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$IKZF1_GM12878,encodeB$gene_1730,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC2_K562,encodeB$gene_685,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC2_K562,encodeB$gene_2890,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC2_K562,encodeB$gene_2844,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC2_K562,encodeB$gene_1413,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC2_HepG2,encodeB$gene_685,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC2_HepG2,encodeB$gene_2890,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC2_HepG2,encodeB$gene_2844,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC2_HepG2,encodeB$gene_1413,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC1_K562,encodeB$gene_94,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC1_K562,encodeB$gene_1804,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC1_K562,encodeB$gene_1803,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC1_K562,encodeB$gene_1412,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$HDAC1_K562,encodeB$gene_1411,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GTF2B_K562,encodeB$gene_2798,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_K562,encodeB$gene_980,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_K562,encodeB$gene_979,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_K562,encodeB$gene_2658,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_K562,encodeB$gene_108,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_K562,encodeB$gene_1062,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_980,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_979,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_2658,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_108,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$GATA1_erythroblast,encodeB$gene_1062,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_3051,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_2965,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_2963,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_2703,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$FOXA1_HepG2,encodeB$gene_171,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ESRRA_GM12878,encodeB$gene_673,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ESRRA_GM12878,encodeB$gene_2821,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ESRRA_GM12878,encodeB$gene_2613,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ESRRA_GM12878,encodeB$gene_2159,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_K562,encodeB$gene_2815,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_K562,encodeB$gene_1746,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_K562,encodeB$gene_1050,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_HepG2,encodeB$gene_2815,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_HepG2,encodeB$gene_1746,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_HepG2,encodeB$gene_1050,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_GM12878,encodeB$gene_2815,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_GM12878,encodeB$gene_1746,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EP300_GM12878,encodeB$gene_1050,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ELK1_K562,encodeB$gene_2865,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ELK1_K562,encodeB$gene_2863,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ELK1_GM12878,encodeB$gene_2865,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ELK1_GM12878,encodeB$gene_2863,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EBF1_GM12878,encodeB$gene_860,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EBF1_GM12878,encodeB$gene_859,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EBF1_GM12878,encodeB$gene_858,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$EBF1_GM12878,encodeB$gene_857,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$E2F6_K562,encodeB$gene_2807,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$E2F4_K562,encodeB$gene_1167,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$E2F4_GM12878,encodeB$gene_1167,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_WI38,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_spleen,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_retinalpigmentepithelialcell,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_pancreas,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_NB4,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_medulloblastoma,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_mammaryepithelialcell,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_lung,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_kidneyepithelialcell,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_kidney,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_keratinocyte,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_K562,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_HGPScell,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_HepG2,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_HEK293,encodeB$gene_124,genome.size=20805)
olist<-list((go.obj<-newGeneOverlap(encodeA$CTCF_HCT116,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM20000,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM19240,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM19239,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM19238,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM13977,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM13976,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12892,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12891,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12878,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12875,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12874,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12873,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12872,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12871,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12870,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12869,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12868,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12867,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12866,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12865,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12864,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM12801,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM10266,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM10248,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_GM06990,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_foreskinfibroblast,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofvillousmesenchyme,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofupperlegskin,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastoftheaorticadventitia,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofskinofabdomen,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofpulmonaryartery,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofpedaldigitskin,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofmammarygland,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastoflung,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_fibroblastofgingiva,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_epithelialcellofproximaltubule,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_epithelialcellofesophagus,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_endothelialcellofumbilicalvein,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_choroidplexusepithelialcell,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_cardiacmusclecell,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_cardiacfibroblast,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_bronchialepithelialcell,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_brainmicrovascularendothelialcell,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_BE2C,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_astrocyteofthespinalcord,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_astrocyteofthecerebellum,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CTCF_A549,encodeB$gene_124,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$CBX3_K562,encodeB$gene_1374,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_65,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_529,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_148,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$BRCA1_HepG2,encodeB$gene_1137,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_65,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_529,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_148,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$BRCA1_GM12878,encodeB$gene_1137,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ATF2_GM12878,encodeB$gene_2544,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ARID3A_K562,encodeB$gene_1339,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ARID3A_K562,encodeB$gene_1338,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ARID3A_K562,encodeB$gene_1337,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ARID3A_HepG2,encodeB$gene_1339,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ARID3A_HepG2,encodeB$gene_1338,genome.size=20805)
go.obj<-newGeneOverlap(encodeA$ARID3A_HepG2,encodeB$gene_1337,genome.size=20805)

for(go.obj in golist{}
print(testGeneOverlap(go.obj))
    }
# Out:
# Error in parse(text = x, srcfile = src): <text>:2:1: unexpected symbol
# 1: golist<-list(go.obj<-newGeneOverlap(encodeA$ZBTB7A_K562,encodeB$gene_2380,genome.size=20805)
# 2: go.obj
#    ^
# Traceback:
